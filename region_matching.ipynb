# %%
import geopandas as gpd
import numpy as np
# Замените на путь к вашему файлу
geojson_path = "OSMB-f1ec2d0019a5c0c4984f489cdc13d5d26a7949fd.geojson"

# Чтение GeoJSON
gdf = gpd.read_file(geojson_path)

# Посмотрим на доступные столбцы
print("Доступные столбцы:", gdf.columns)
# Out:
# Доступные столбцы: Index(['osm_id', 'name', 'name_en', 'boundary', 'admin_level',
#        'admin_centre_node_id', 'admin_centre_node_lat',
#        'admin_centre_node_lng', 'label_node_id', 'label_node_lat',
#        'label_node_lng', 'geometry'],
#       dtype='object')

# %%
# Если там есть столбец с названием региона, например 'name' или 'region', выведем уникальные значения
if 'name' in gdf.columns:
    print("Найденные регионы:")
    a = np.sort(gdf['name'].unique())
    [print(i) for i in a]
elif 'region' in gdf.columns:
    print("Найденные регионы:")
    a = np.sort(gdf['region'].unique())
    [print(i) for i in a]
else:
    print("Не удалось найти подходящий столбец с названием региона.")
# Out:
# Найденные регионы:
# Абай ауданы
# Айыртау ауданы
# Алтай ауданы
# Алтынсаринский район - Алтынсарин ауданы
# Амангелді ауданы
# Аршалы ауданы
# Арқалық Қ.Ә.
# Астана
# Астрахан ауданы
# Атбасар ауданы
# Аулиекольский район - Әулиекөл ауданы
# Аягөз ауданы
# Ақжар ауданы
# Ақкөл ауданы
# Ақсу Қ.Ә.
# Ақсуат ауданы
# Ақтоғай ауданы
# Аққайың ауданы
# Аққулы ауданы
# Баянауыл ауданы
# Бейімбет Майлин ауданы
# Бесқарағай ауданы
# Бородулиха ауданы
# Бурабай ауданы
# Біржан сал ауданы
# Бұланды ауданы
# Бұқар жырау ауданы
# Глубокое ауданы
# Денисов ауданы
# Егіндікөл ауданы
# Екібастұз Қ.Ә.
# Ерейментау ауданы
# Ертіс ауданы
# Есіл ауданы
# Жаксынский район - Жақсы ауданы
# Жамбыл ауданы
# Жангелдин ауданы
# Жарма ауданы
# Жарқайың ауданы
# Жаңасемей ауданы
# Железин ауданы
# Жітіқара ауданы
# Зеренді ауданы
# Катонқарағай ауданы
# Курчатов қалалық әкімшілігі
# Күршім ауданы
# Көкпекті ауданы
# Көкшетау Қ.Ә.
# Лисаковск Қ.Ә.
# Май ауданы
# Мамлют ауданы
# Марқакөл ауданы
# Мағжан Жұмабаев ауданы
# Мендыкаринский район - Меңдіқара ауданы
# Наурзумский район - Наурызым ауданы
# Нұра ауданы
# Осакаров ауданы
# Павлодар ауданы
# Павлодар Қ.Ә.
# Петропавл қ.а.
# Риддер қалалық әкімдігі
# Рудный Қ.Ә.
# Самар ауданы
# Сандықтау ауданы
# Саран Қ.Ә.
# Сарыкольский район - Сарыкөл ауданы
# Семей қалалық әкімшілігі
# Степногорск Қ.Ә.
# Тайынша ауданы
# Тарбағатай ауданы
# Теміртау Қ.Ә.
# Тереңкөл ауданы
# Тимирязев ауданы
# Успен ауданы
# Уәлиханов ауданы
# Федоров ауданы
# Целиноград ауданы
# Шал ақын ауданы
# Шарбақты ауданы
# Шахтинск Қ.Ә.
# Шемонаиха ауданы
# Шортанды ауданы
# Ғабит Мүсірепов ауданы
# Қамысты ауданы
# Қарабалық ауданы
# Қарасу ауданы
# Қарағанды Қ.Ә.
# Қарқаралы ауданы
# Қорғалжын ауданы
# Қостанай ауданы
# Қостанай Қ.Ә.
# Қосшы қалалық әкімдігі
# Қызылжар ауданы
# Үлкен Нарын ауданы
# Ұзынкөл ауданы
# Ұлан ауданы
# Өскемен қ.ә.

# %%
reverse_mapping = {
    "Амангельдинский": "Амангелді ауданы",
    "Абайский": "Абай ауданы",
    "Айыртауский": "Айыртау ауданы",
    "Есильский": "Есіл ауданы",
    "Акжарский": "Ақжар ауданы",
    "Уалихановский": "Уәлиханов ауданы",
    "Аккайынский": "Аққайың ауданы",
    "Аккольский": "Ақкөл ауданы",
    "Актогайский": "Ақтоғай ауданы",
    "Иртышский": "Ертіс ауданы",
    "Алтай": "Алтай ауданы",
    "Катон Карагай": "Катонқарағай ауданы",
    "Улкен Нарын": "Үлкен Нарын ауданы",
    "Бородулихинский": "Бородулиха ауданы",
    "Самарский": "Самар ауданы",
    "Аршалынский": "Аршалы ауданы",
    "Астраханский": "Астрахан ауданы",
    "Атбасарский": "Атбасар ауданы",
    "Беимбета Майлина": "Бейімбет Майлин ауданы",
    "Алтынсаринский": "Алтынсаринский район - Алтынсарин ауданы",
    "Бескарагайский": "Бесқарағай ауданы",
    "Шемонайхинский": "Шемонаиха ауданы",
    "Биржан Сал": "Біржан сал ауданы",
    "Буландынский": "Бұланды ауданы",
    "Бухар жырауский": "Бұқар жырау ауданы",
    "Г.Мусрепова": "Ғабит Мүсірепов ауданы",
    "Денисовский": "Денисов ауданы",
    "Житикаринский": "Жітіқара ауданы",
    "Камыстинский": "Қамысты ауданы",
    "Карасуский": "Қарасу ауданы",
    "Карасу": "Қарасу ауданы",
    "Мендыгаринский": "Мендыкаринский район - Меңдіқара ауданы",
    "Аркалыкский": "Арқалық Қ.Ә.",
    "Тарановский": "Бейімбет Майлин ауданы",
    "Егиндыкольский": "Егіндікөл ауданы",
    "Жаксынский": "Жаксынский район - Жақсы ауданы",
    "Жамбылский": "Жамбыл ауданы",
    "Жаркаинский": "Жарқайың ауданы",
    "Железинский": "Железин ауданы",
    "Зерендинский": "Зеренді ауданы",
    "Карабалыкский": "Қарабалық ауданы",
    "Костанайский": "Қостанай ауданы",
    "Коргалжынский": "Қорғалжын ауданы",
    "Кызылжарский": "Қызылжар ауданы",
    "Магжана Жумабаева": "Мағжан Жұмабаев ауданы",
    "Мамлютский": "Мамлют ауданы",
    "Сарыкольский": "Сарыкольский район - Сарыкөл ауданы",
    "Узункольский": "Ұзынкөл ауданы",
    "Нуринский": "Нұра ауданы",
    "Осакаровский": "Осакаров ауданы",
    "Павлодарская область": "Павлодар ауданы",
    "Сандыктау": "Сандықтау ауданы",
    "Бурабай ауданы": "Бурабай ауданы",
    "Тайыншинский": "Тайынша ауданы",
    "Теренкольский": "Тереңкөл ауданы",
    "Тимирязевский": "Тимирязев ауданы",
    "Шал Акына": "Шал ақын ауданы",
    "Шарбактинский": "Шарбақты ауданы",
    "Успенский": "Успен ауданы",
    "Целиноградский": "Целиноград ауданы",
    "Глубоковский": "Глубокое ауданы",
    "Шортандинский": "Шортанды ауданы",
    "Ерейментауский": "Ерейментау ауданы",
    "Аулиекольский": "Аулиекольский район - Әулиекөл ауданы",
    "Мендыкаринский": "Мендыкаринский район - Меңдіқара ауданы",
    "
    "Сафронов Александр Викторович",
    "Шадрин Виталий Вячеславович"
]

# %%
import requests
import json

TOKEN = "c611c2bab48335e36a4b59be460c57d2BF8416B73C4A65F2B8A88A5848E97CD4471F14C6"
BASE_URL = "https://hst-api.wialon.host/wialon/ajax.html"

def login(token):
    r = requests.get(BASE_URL, params={
        "svc": "token/login",
        "params": json.dumps({"token": token})
    })
    return r.json().get("eid")

def get_items(sid, item_type, flags):
    r = requests.get(BASE_URL, params={
        "svc": "core/search_items",
        "params": json.dumps({
            "spec": {
                "itemsType": item_type,
                "propName": "sys_name",
                "propValueMask": "*",
                "sortType": "sys_name"
            },
            "force": 1,
            "flags": flags,
            "from": 0,
            "to": 0
        }),
        "sid": sid
    })
    return r.json().get("items", [])

if __name__ == "__main__":
    SID = login(TOKEN)
    units = get_items(SID, "avl_unit", 1)
    if not units:
        print("Юниты не найдены.")
    else:
        print("Список юнитов:")
        for unit in units:
            print(f"{unit['id']}: {unit['nm']}")
# Out:
# Список юнитов:
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27910469: 352 Балгожа
# 27910381: 354 Кабимулдин
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27914968: 377 CR Абдрахманов
# 27915302: 380 Садвакасов
# 27910721: 381 CR Винницкий Ф
# 27915499: 383 Карташов
# 27911208: 386 Рак
# 27915429: 387 Тургумбаев
# 27909430: 403 Шпаковский
# 28974245: 415 AQ резерв
# 28131462: 416 Сералиев
# 28132922: 419 Абдиров
# 28014920: 428 AQ Нургалиев
# 28973928: 431 резерв
# 27914966: 435 Джиоев
# 28573142: 435 резерв
# 28666651: 443 AQ Кадырбек
# 28222684: 443 СО Садовский
# 28666387: 449 Темишев
# 28666526: 451 резерв
# 28014074: 452 BJ резерв
# 27909458: 452 CR Аскеров
# 28131410: 452 Құрман
# 28246259: 453 Мусин
# 28606589: 458 Кабимулдин
# 28243616: 459 Жаирбаев
# 28973874: 460 CO Сундетбаев
# 27915589: 460 Егоров
# 28606693: 461 Барон
# 28974276: 463 CO Шубин
# 28399015: 464 Кабдрахманов
# 28011473: 465 Кайратов
# 27780244: 467 Раков
# 28405611: 468 Кулбулдин
# 28011028: 469 резерв
# 27792707: 470 Вахнина
# 28243564: 471 Калиев
# 28666496: 472 CO резерв
# 28222776: 473 Ескатов
# 28113524: 475 CO Адомайтис
# 28973541: 476 Бойко
# 28569265: 477 Сериков
# 28573545: 478 Афанасьев
# 28973983: 479 CO Синяков
# 27780000: 480 CO  Шатохин
# 27780113: 481 CO Сейдыков
# 28574085: 482 Шаткенов
# 28113464: 483 Назарбек М
# 28014385: 484 Яцынович
# 28172278: 485 CO Солдатенков
# 28974125: 486 CO Усенов
# 28606770: 495 Мукушев
# 27916518: 522 Ниязов
# 27916552: 526 CQ Лобанова
# 27919664: 529 Григоренко
# 27919718: 536 Гаврилюк
# 28574445: 586 Нургалиев
# 27916381: 639 CQ Герасимов
# 27919696: 643 CQ Жакиенов
# 27916031: 652 Глазырин
# 27919840: 654 CQ Ключка
# 27919763: 655 Нурманов
# 27940698: 659  Мальцев
# 28014203: 667 СН Куташов
# 28974156: 668 CH Бородич
# 28172244: 673 Яковлев
# 27910072: 682 Кожебаев
# 27915367: 718 резерв
# 27909082: 726 Таукин
# 27915989: 739 Коржов
# 27916171: 759 CQ Анишкевич
# 27910284: 769 Охатов
# 27916258: 780 Турежанов
# 27916107: 783 Раимкулов
# 27916084: 787  Данчев
# 27916334: 845 Сафронов
# 28015162: 847 Есентаев
# 28014649: 848 Жанатаев
# 28973854: 853 BJ Зацепин
# 28172293: 854 BJ Кабдиев
# 28974038: 855 BJ Ибраев
# 28606816: 856 Перешивкин
# 27909654: 902 Каненов
# 27911157: 908 Хасанов
# 27914983: 915 CQ Соловьев
# 27910755: 932 Баймурзинов
# 27915093: 936 Муртазин
# 27909218: 947 Жуманазаров
# 27909147: 952 CQ Гугневич
# 27915282: 956 CQ Терещенко
# 27911240: 957 Толеубек
# 27915226: 970 CQ Шульц
# 27915747: 974 Лубянецкий
# 27909272: 986 Авижич
# 27915149: 997 Кализатов
# 27909773: Дауленов 357
# 27909883: Джексембаев 353

# %%
unit_id_to_name = {unit["id"]: unit["nm"] for unit in units}

# %%
# full_names          — список ФИО
# unit_id_to_name     — словарь {unit_id: unit_name}

name_to_unit = {}

for full in full_names:
    surname = full.split()[0]                         # берём фамилию
    # ищем любой unit_name, в котором встречается фамилия
    match = next((u for u in unit_id_to_name.values() if surname in u), None)
    name_to_unit[full] = match        # будет строка unit_name или None

# name_to_unit теперь выглядит так:
# {
#     "Иванов Иван Иванович": "Unit 123 — Иванов И.И.",
#     "Петров Пётр":          None,
#     ...
# }

# Если нужен только успешно сопоставленный под‑словарь:
matched = {k: v for k, v in name_to_unit.items() if v}
unmatched = [k for k, v in name_to_unit.items() if v is None]

# %%
import pandas as pd
df = pd.read_excel("Контакты Stratera.xlsx", sheet_name="Менеджеры по продажам районы")

df = df[['ФИО', 'Область', 'Район ']]

df.columns = ['FullName', 'Region', 'District']


import re
import pandas as pd

# регулярка: делим по ", "‑если‑она‑НЕ‑внутри‑скобок
split_pat = r',\s*(?![^()]*\))'          # negative‑lookahead: после запятой
                                         # нет закрывающей скобки до следующей открытой

df = (
    df.assign(District=df['District'].str.split(split_pat, regex=True))  # список
      .explode('District')                                               # строки
      .assign(District=lambda d: d['District'].str.strip())              # подчистить пробелы
      .reset_index(drop=True)
)

# %%
df
# Out:
#                             FullName           Region        District
# 0        Абдиров Бекбулат Кайратович  КСТ (Костанай)   Мендыгаринский
# 1        Абдиров Бекбулат Кайратович  КСТ (Костанай)     Узункольский
# 2        Абдиров Бекбулат Кайратович  КСТ (Костанай)     Костанайский
# 3        Абдиров Бекбулат Кайратович  КСТ (Костанай)   Алтынсаринский
# 4        Абдиров Бекбулат Кайратович  КСТ (Костанай)           Карасу
# ..                               ...              ...             ...
# 136          Шубин Глеб Владимирович   СКО (Кокшетау)     Г.Мусрепова
# 137         Шульц Николай Викторович   СКО (Кокшетау)       Есильский
# 138  Яковлев Александр Александрович     АКМ (Астана)      Аккольский
# 139      Яцынович Константин Юрьевич  АКМ (Караганда)    Осакаровский
# 140                              NaN              NaN             NaN
#
# [141 rows x 3 columns]

# %%
df = df[:-1]

# %%
matched
# Out:
# {'Барон Сергей Дмитриевич': '461 Барон',
#  'Кадырбек Куат': '443 AQ Кадырбек',
#  'Кайратов Батырхан Бейсенбайұлы': '465 Кайратов',
#  'Құрман Айдын Мұхитұлы': '452 Құрман',
#  'Куташов Виталий Николаевич': '667 СН Куташов',
#  'Назарбек Мәди Мейрамбекұлы': '483 Назарбек М',
#        'Таукин Канат Аблаевич', 'Темишев Нуржан Мейрамғалиұлы',
#        'Терещенко Александр Григорьевич', 'Тургумбаев Ильяс Аскарович',
#        'Турежанов Болат Агибаевич', 'Усенов Асанали Асхатович',
#        'Шаткенов Арлан Нурдаулетович', 'Шубин Глеб Владимирович',
#        'Шульц Николай Викторович', 'Яковлев Александр Александрович',
#        'Яцынович Константин Юрьевич'], dtype=object)

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3520\3833930409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

# %%
df["Region_mapped"] = df["District"].apply(
    lambda name: reverse_mapping.get(name, None)   # вернёт value или None
)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3520\1802737178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Region_mapped"] = df["District"].apply(

# %%
df.to_csv('manager_region.csv', index=False)

# %%
df = pd.read_csv('manager_region.csv')

region_dict = (
    df.groupby('Car_numb')['Region_mapped']
    .apply(lambda x: list(set(x)))
    .to_dict()
)

# %%
pd.set_option('display.max_rows', None)
df.sort_values(by = 'Car_numb')
# Out:
#                             FullName                  Region  \
# 23        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 25        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 26        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 24        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 7       Абдрахманов Алибек Канатович     СКО (Петропавловск)
# 8       Абдрахманов Алибек Канатович     СКО (Петропавловск)
# 9       Абдрахманов Алибек Канатович     СКО (Петропавловск)
# 110     Садвакасов Рустам Дмитриевич          ПВЛ (Павлодар)
# 79          Карташов Олег Валерьевич          СКО (Кокшетау)
# 78          Карташов Олег Валерьевич          СКО (Кокшетау)
# 108              Рак Егор Валерьевич          ПВЛ (Павлодар)
# 130       Тургумбаев Ильяс Аскарович           АКМ (Атбасар)
# 131       Тургумбаев Ильяс Аскарович           АКМ (Атбасар)
# 117        Сералиев Алишер Габитович         КСТ (Костанай)
# 116        Сералиев Алишер Габитович         КСТ (Костанай)
# 115        Сералиев Алишер Габитович         КСТ (Костанай)
# 6        Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 5        Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 4        Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 3        Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 2        Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 1        Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 0        Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 97      Нургалиев Данияр Рамазанович         КСТ (Костанай)
# 95      Нургалиев Данияр Рамазанович         КСТ (Костанай)
# 96      Нургалиев Данияр Рамазанович         КСТ (Костанай)
# 40      Джиоев Георгий Александрович          АКМ (Кокшетау)
# 72                     Кадырбек Куат            АКМ (Астана)
# 111       Садовский Игорь Валерьевич          СКО (Кокшетау)
# 128     Темишев Нуржан Мейрамғалиұлы            АКМ (Астана)
# 87             Құрман Айдын Мұхитұлы            АКМ (Астана)
# 92             Мусин Едіге Муратович  ВКО (Усть-Каменогорск)
# 91             Мусин Едіге Муратович  ВКО (Усть-Каменогорск)
# 93             Мусин Едіге Муратович  ВКО (Усть-Каменогорск)
# 66         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 71         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 70         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 68         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 67         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 69         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 50       Жаирбаев Даурен Беимбекович  ВКО (Усть-Каменогорск)
# 49       Жаирбаев Даурен Беимбекович  ВКО (Усть-Каменогорск)
# 48       Жаирбаев Даурен Беимбекович  ВКО (Усть-Каменогорск)
# 123    Сундетбаев Болат Муратбекович            АКМ (Астана)
# 27           Барон Сергей Дмитриевич            АКМ (Астана)
# 136          Шубин Глеб Владимирович          СКО (Кокшетау)
# 64      Кабдрахманов Асхат Канатович          АКМ (Кокшетау)
# 65      Кабдрахманов Асхат Канатович          АКМ (Кокшетау)
# 74    Кайратов Батырхан Бейсенбайұлы            АКМ (Астана)
# 73    Кайратов Батырхан Бейсенбайұлы            АКМ (Астана)
# 109           Раков Валерий Игоревич     СКО (Петропавловск)
# 84    Кулбулдин Бауыржан Мубаракович          СКО (Кокшетау)
# 31      Вахнина Виктория Анатольевна          СКО (Кокшетау)
# 75           Калиев Жанибек Омарович          АКМ (Кокшетау)
# 46          Ескатов Алишер Маратович         КСТ (Костанай)
# 45          Ескатов Алишер Маратович         КСТ (Костанай)
# 44          Ескатов Алишер Маратович         КСТ (Костанай)
# 47          Ескатов Алишер Маратович         КСТ (Костанай)
# 42          Ескатов Алишер Маратович         КСТ (Костанай)
# 43          Ескатов Алишер Маратович         КСТ (Костанай)
# 10      Адомайтис Евгений Валерьевич           АКМ (Атбасар)
# 29               Бойко Олег Игоревич          ПВЛ (Павлодар)
# 28               Бойко Олег Игоревич          ПВЛ (Павлодар)
# 120         Сериков Бахтияр Тлекович          ПВЛ (Павлодар)
# 119         Сериков Бахтияр Тлекович          ПВЛ (Павлодар)
# 118         Сериков Бахтияр Тлекович          ПВЛ (Павлодар)
# 15          Афанасьев Павел Павлович         АКМ (Караганда)
# 14          Афанасьев Павел Павлович         АКМ (Караганда)
# 121       Синяков Валерий Викторович           АКМ (Атбасар)
# 113       Сейдыков Максим Евгеньевич         АКМ (Караганда)
# 114       Сейдыков Максим Евгеньевич         АКМ (Караганда)
#
# 30            Г.Мусрепова      668 CH Бородич
# 138            Аккольский         673 Яковлев
# 127          Узункольский          726 Таукин
# 126         Аулиекольский          726 Таукин
# 125           Тарановский          726 Таукин
# 124           Федоровский          726 Таукин
# 83         Мендыкаринский          739 Коржов
# 82          Карабалыкский          739 Коржов
# 11             Карасуский    759 CQ Анишкевич
# 12           Сарыкольский    759 CQ Анишкевич
# 13         Алтынсаринский    759 CQ Анишкевич
# 101           Г.Мусрепова          769 Охатов
# 133         Уалихановский       780 Турежанов
# 132             Акжарский       780 Турежанов
# 106          Узункольский       783 Раимкулов
# 105        Мендыкаринский       783 Раимкулов
# 103          Костанайский       783 Раимкулов
# 104          Камыстинский       783 Раимкулов
# 102         Карабалыкский       783 Раимкулов
# 107           Денисовский       783 Раимкулов
# 112            Мамлютский        845 Сафронов
# 41              Шал Акына        847 Есентаев
# 56          Аулиекольский        848 Жанатаев
# 55             Карасуский        848 Жанатаев
# 59            Жаркаинский      853 BJ Зацепин
# 63   Павлодарская область      854 BJ Кабдиев
# 62           Узункольский       855 BJ Ибраев
# 60           Сарыкольский       855 BJ Ибраев
# 61          Житикаринский       855 BJ Ибраев
# 21       Беимбета Майлина     932 Баймурзинов
# 22         Мендыгаринский     932 Баймурзинов
# 19             Карасуский     932 Баймурзинов
# 20           Костанайский     932 Баймурзинов
# 16          Карабалыкский     932 Баймурзинов
# 17            Федоровский     932 Баймурзинов
# 18         Алтынсаринский     932 Баймурзинов
# 57            Федоровский     947 Жуманазаров
# 58          Аулиекольский     947 Жуманазаров
# 36             Жаксынский     952 CQ Гугневич
# 129           Жаркаинский    956 CQ Терещенко
# 137             Есильский        970 CQ Шульц
# 89           Сарыкольский      974 Лубянецкий
# 88           Узункольский      974 Лубянецкий
# 77         Бурабай ауданы       997 Кализатов
# 76              Сандыктау       997 Кализатов
# 37              Успенский        Дауленов 357
# 39           Глубоковский     Джексембаев 353
# 38         Шемонайхинский     Джексембаев 353
#
#                                 Region_mapped
# 23                             Денисов ауданы
# 25                               Арқалық Қ.Ә.
# 26                     Бейімбет Майлин ауданы
# 24    Мендыкаринский район - Меңдіқара ауданы
# 7                               Жамбыл ауданы
# 8                             Қызылжар ауданы
# 9                              Аққайың ауданы
# 110                           Шарбақты ауданы
# 79                                Есіл ауданы
# 78                             Айыртау ауданы
# 108                           Тереңкөл ауданы
# 130           Жаксынский район - Жақсы ауданы
# 131                               Есіл ауданы
# 117  Алтынсаринский район - Алтынсарин ауданы
# 116   Мендыкаринский район - Меңдіқара ауданы
# 115                           Қостанай ауданы
# 6                             Жітіқара ауданы
# 5                                Арқалық Қ.Ә.
# 4                               Қарасу ауданы
# 3    Алтынсаринский район - Алтынсарин ауданы
# 2                             Қостанай ауданы
# 1                              Ұзынкөл ауданы
# 0     Мендыкаринский район - Меңдіқара ауданы
# 97      Аулиекольский район - Әулиекөл ауданы
# 95        Сарыкольский район - Сарыкөл ауданы
# 96                             Ұзынкөл ауданы
# 40                           Сандықтау ауданы
# 72                            Астрахан ауданы
# 111                           Шал ақын ауданы
# 128                          Егіндікөл ауданы
# 87                              Аршалы ауданы
# 92                          Бородулиха ауданы
# 91                          Бесқарағай ауданы
# 93                           Шемонаиха ауданы
# 66                               Алтай ауданы
# 71                                Ұлан ауданы
# 70                               Самар ауданы
# 68                         Үлкен Нарын ауданы
# 67                        Катонқарағай ауданы
# 69                          Бородулиха ауданы
# 50                            Глубокое ауданы
# 49                          Бородулиха ауданы
# 48                          Бесқарағай ауданы
# 123                          Егіндікөл ауданы
# 27                            Осакаров ауданы
# 136                    Ғабит Мүсірепов ауданы
# 64                          Біржан сал ауданы
# 65                             Бурабай ауданы
# 74                            Астрахан ауданы
# 73                             Бұланды ауданы
# 109                          Тимирязев ауданы
# 84                           Уәлиханов ауданы
# 31                             Тайынша ауданы
# 75                             Зеренді ауданы
# 46        Сарыкольский район - Сарыкөл ауданы
# 45                             Қамысты ауданы
# 44                             Денисов ауданы
# 47                            Қостанай ауданы
# 42                     Бейімбет Майлин ауданы
# 43   Алтынсаринский район - Алтынсарин ауданы
# 10                             Атбасар ауданы
# 29                               Успен ауданы
# 28                            Шарбақты ауданы
# 120                            Железин ауданы
# 119                              Ертіс ауданы
# 118                            Ақтоғай ауданы
# 15                              Аршалы ауданы
# 14                            Осакаров ауданы
# 121                           Жарқайың ауданы
# 113                               Нұра ауданы
# 114                               Абай ауданы
# 135                          Қорғалжын ауданы
# 94                          Целиноград ауданы
# 139                           Осакаров ауданы
# 122                        Бұқар жырау ауданы
# 134                          Уәлиханов ауданы
# 90                             Аққайың ауданы
# 32                     Мағжан Жұмабаев ауданы
# 99                             Аққайың ауданы
# 100                    Мағжан Жұмабаев ауданы
# 98                            Қызылжар ауданы
# 33                                Есіл ауданы
# 54                           Амангелді ауданы
# 53   Алтынсаринский район - Алтынсарин ауданы
# 52      Аулиекольский район - Әулиекөл ауданы
# 51                            Қостанай ауданы
# 34                              Қарасу ауданы
# 35        Сарыкольский район - Сарыкөл ауданы
# 80                             Железин ауданы
# 81                            Тереңкөл ауданы
# 86                          Ерейментау ауданы
# 85                            Шортанды ауданы
# 30                     Ғабит Мүсірепов ауданы
# 138                              Ақкөл ауданы
# 127                            Ұзынкөл ауданы
# 126     Аулиекольский район - Әулиекөл ауданы
# 125                    Бейімбет Майлин ауданы
# 124                            Федоров ауданы
# 83    Мендыкаринский район - Меңдіқара ауданы
# 82                           Қарабалық ауданы
# 11                              Қарасу ауданы
# 12        Сарыкольский район - Сарыкөл ауданы
# 13   Алтынсаринский район - Алтынсарин ауданы
# 101                    Ғабит Мүсірепов ауданы
# 133                          Уәлиханов ауданы
# 132                              Ақжар ауданы
# 106                            Ұзынкөл ауданы
# 105   Мендыкаринский район - Меңдіқара ауданы
# 103                           Қостанай ауданы
# 104                            Қамысты ауданы
# 102                          Қарабалық ауданы
# 107                            Денисов ауданы
# 112                             Мамлют ауданы
# 41                            Шал ақын ауданы
# 56      Аулиекольский район - Әулиекөл ауданы
# 55                              Қарасу ауданы
# 59                            Жарқайың ауданы
# 63                            Павлодар ауданы
# 62                             Ұзынкөл ауданы
# 60        Сарыкольский район - Сарыкөл ауданы
# 61                            Жітіқара ауданы
# 21                     Бейімбет Майлин ауданы
# 22    Мендыкаринский район - Меңдіқара ауданы
# 19                              Қарасу ауданы
# 20                            Қостанай ауданы
# 16                           Қарабалық ауданы
# 17                             Федоров ауданы
# 18   Алтынсаринский район - Алтынсарин ауданы
# 57                             Федоров ауданы
# 58      Аулиекольский район - Әулиекөл ауданы
# 36            Жаксынский район - Жақсы ауданы
# 129                           Жарқайың ауданы
# 137                               Есіл ауданы
# 89        Сарыкольский район - Сарыкөл ауданы
# 88                             Ұзынкөл ауданы
# 77                             Бурабай ауданы
# 76                           Сандықтау ауданы
# 37                               Успен ауданы
# 39                            Глубокое ауданы
# 38                           Шемонаиха ауданы

# %%
df[['Car_numb', 'Region_mapped']]
# Out:
#                Car_numb                             Region_mapped
# 0           419 Абдиров   Мендыкаринский район - Меңдіқара ауданы
# 1           419 Абдиров                            Ұзынкөл ауданы
# 2           419 Абдиров                           Қостанай ауданы
# 3           419 Абдиров  Алтынсаринский район - Алтынсарин ауданы
# 4           419 Абдиров                             Қарасу ауданы
# 5           419 Абдиров                              Арқалық Қ.Ә.
# 6           419 Абдиров                           Жітіқара ауданы
# 7    377 CR Абдрахманов                             Жамбыл ауданы
# 8    377 CR Абдрахманов                           Қызылжар ауданы
# 9    377 CR Абдрахманов                            Аққайың ауданы
# 10     475 CO Адомайтис                            Атбасар ауданы
# 11     759 CQ Анишкевич                             Қарасу ауданы
# 12     759 CQ Анишкевич       Сарыкольский район - Сарыкөл ауданы
# 13     759 CQ Анишкевич  Алтынсаринский район - Алтынсарин ауданы
# 14        478 Афанасьев                           Осакаров ауданы
# 15        478 Афанасьев                             Аршалы ауданы
# 16      932 Баймурзинов                          Қарабалық ауданы
# 17      932 Баймурзинов                            Федоров ауданы
# 18      932 Баймурзинов  Алтынсаринский район - Алтынсарин ауданы
# 19      932 Баймурзинов                             Қарасу ауданы
# 20      932 Баймурзинов                           Қостанай ауданы
# 21      932 Баймурзинов                    Бейімбет Майлин ауданы
# 22      932 Баймурзинов   Мендыкаринский район - Меңдіқара ауданы
# 23          352 Балгожа                            Денисов ауданы
# 24          352 Балгожа   Мендыкаринский район - Меңдіқара ауданы
# 25          352 Балгожа                              Арқалық Қ.Ә.
# 26          352 Балгожа                    Бейімбет Майлин ауданы
# 27            461 Барон                           Осакаров ауданы
# 28            476 Бойко                           Шарбақты ауданы
# 29            476 Бойко                              Успен ауданы
# 30       668 CH Бородич                    Ғабит Мүсірепов ауданы
# 31          470 Вахнина                            Тайынша ауданы
# 32         536 Гаврилюк                    Мағжан Жұмабаев ауданы
# 33     639 CQ Герасимов                               Есіл ауданы
# 34         652 Глазырин                             Қарасу ауданы
# 35         652 Глазырин       Сарыкольский район - Сарыкөл ауданы
# 36      952 CQ Гугневич           Жаксынский район - Жақсы ауданы
# 37         Дауленов 357                              Успен ауданы
# 38      Джексембаев 353                          Шемонаиха ауданы
# 39      Джексембаев 353                           Глубокое ауданы
# 40           435 Джиоев                          Сандықтау ауданы
# 41         847 Есентаев                           Шал ақын ауданы
# 42          473 Ескатов                    Бейімбет Майлин ауданы
# 43          473 Ескатов  Алтынсаринский район - Алтынсарин ауданы
# 44          473 Ескатов                            Денисов ауданы
# 45          473 Ескатов                            Қамысты ауданы
# 46          473 Ескатов       Сарыкольский район - Сарыкөл ауданы
# 47          473 Ескатов                           Қостанай ауданы
# 48         459 Жаирбаев                         Бесқарағай ауданы
# 49         459 Жаирбаев                         Бородулиха ауданы
# 50         459 Жаирбаев                           Глубокое ауданы
# 51      643 CQ Жакиенов                           Қостанай ауданы
# 52      643 CQ Жакиенов     Аулиекольский район - Әулиекөл ауданы
# 53      643 CQ Жакиенов  Алтынсаринский район - Алтынсарин ауданы
# 54      643 CQ Жакиенов                          Амангелді ауданы
# 55         848 Жанатаев                             Қарасу ауданы
# 56         848 Жанатаев     Аулиекольский район - Әулиекөл ауданы
# 57      947 Жуманазаров                            Федоров ауданы
# 58      947 Жуманазаров     Аулиекольский район - Әулиекөл ауданы
# 59       853 BJ Зацепин                           Жарқайың ауданы
# 60        855 BJ Ибраев       Сарыкольский район - Сарыкөл ауданы
# 61        855 BJ Ибраев                           Жітіқара ауданы
# 62        855 BJ Ибраев                            Ұзынкөл ауданы
# 63       854 BJ Кабдиев                           Павлодар ауданы
# 64     464 Кабдрахманов                         Біржан сал ауданы
# 65     464 Кабдрахманов                            Бурабай ауданы
# 66       458 Кабимулдин                              Алтай ауданы
# 67       458 Кабимулдин                       Катонқарағай ауданы
# 68       458 Кабимулдин                        Үлкен Нарын ауданы
# 69       458 Кабимулдин                         Бородулиха ауданы
# 70       458 Кабимулдин                              Самар ауданы
# 71       458 Кабимулдин                               Ұлан ауданы
# 72      443 AQ Кадырбек                           Астрахан ауданы
# 73         465 Кайратов                            Бұланды ауданы
# 74         465 Кайратов                           Астрахан ауданы
# 75           471 Калиев                            Зеренді ауданы
# 76        997 Кализатов                          Сандықтау ауданы
# 77        997 Кализатов                            Бурабай ауданы
# 78         383 Карташов                            Айыртау ауданы
# 79         383 Карташов                               Есіл ауданы
# 80        654 CQ Ключка                            Железин ауданы
# 81        654 CQ Ключка                           Тереңкөл ауданы
# 82           739 Коржов                          Қарабалық ауданы
# 83           739 Коржов   Мендыкаринский район - Меңдіқара ауданы
# 84        468 Кулбулдин                          Уәлиханов ауданы
# 85       667 СН Куташов                           Шортанды ауданы
# 86       667 СН Куташов                         Ерейментау ауданы
# 87           452 Құрман                             Аршалы ауданы
# 88       974 Лубянецкий                            Ұзынкөл ауданы
# 89       974 Лубянецкий       Сарыкольский район - Сарыкөл ауданы
# 90          495 Мукушев                            Аққайың ауданы
# 91            453 Мусин                         Бесқарағай ауданы
# 92            453 Мусин                         Бородулиха ауданы
# 93            453 Мусин                          Шемонаиха ауданы
# 94       483 Назарбек М                         Целиноград ауданы
# 95     428 AQ Нургалиев       Сарыкольский район - Сарыкөл ауданы
# 96     428 AQ Нургалиев                            Ұзынкөл ауданы
# 97     428 AQ Нургалиев     Аулиекольский район - Әулиекөл ауданы
# 98        586 Нургалиев                           Қызылжар ауданы
# 99        586 Нургалиев                            Аққайың ауданы
# 100       586 Нургалиев                    Мағжан Жұмабаев ауданы
# 101          769 Охатов                    Ғабит Мүсірепов ауданы
# 102       783 Раимкулов                          Қарабалық ауданы
# 103       783 Раимкулов                           Қостанай ауданы
# 104       783 Раимкулов                            Қамысты ауданы
# 105       783 Раимкулов   Мендыкаринский район - Меңдіқара ауданы
# 106       783 Раимкулов                            Ұзынкөл ауданы
# 107       783 Раимкулов                            Денисов ауданы
# 108             386 Рак                           Тереңкөл ауданы
# 109           467 Раков                          Тимирязев ауданы
# 110      380 Садвакасов                           Шарбақты ауданы
# 111    443 СО Садовский                           Шал ақын ауданы
# 112        845 Сафронов                             Мамлют ауданы
# 113     481 CO Сейдыков                               Нұра ауданы
# 114     481 CO Сейдыков                               Абай ауданы
# 115        416 Сералиев                           Қостанай ауданы
# 116        416 Сералиев   Мендыкаринский район - Меңдіқара ауданы
# 117        416 Сералиев  Алтынсаринский район - Алтынсарин ауданы
# 118         477 Сериков                            Ақтоғай ауданы
# 119         477 Сериков                              Ертіс ауданы
# 120         477 Сериков                            Железин ауданы
# 121      479 CO Синяков                           Жарқайың ауданы
# 122  485 CO Солдатенков                        Бұқар жырау ауданы
# 123   460 CO Сундетбаев                          Егіндікөл ауданы
# 124          726 Таукин                            Федоров ауданы
# 125          726 Таукин                    Бейімбет Майлин ауданы
# 126          726 Таукин     Аулиекольский район - Әулиекөл ауданы
# 127          726 Таукин                            Ұзынкөл ауданы
# 128         449 Темишев                          Егіндікөл ауданы
# 129    956 CQ Терещенко                           Жарқайың ауданы
# 130      387 Тургумбаев           Жаксынский район - Жақсы ауданы
# 131      387 Тургумбаев                               Есіл ауданы
# 132       780 Турежанов                              Ақжар ауданы
# 133       780 Турежанов                          Уәлиханов ауданы
# 134       486 CO Усенов                          Уәлиханов ауданы
# 135        482 Шаткенов                          Қорғалжын ауданы
# 136        463 CO Шубин                    Ғабит Мүсірепов ауданы
# 137        970 CQ Шульц                               Есіл ауданы
# 138         673 Яковлев                              Ақкөл ауданы
# 139        484 Яцынович                           Осакаров ауданы

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

df["Region_mapped"] = df["District"].apply(
    lambda name: reverse_mapping.get(name, None)   # вернёт value или None
)

# %%
# Извлекаем фамилии из ФИО
known_surnames = set(name.split()[0] for name in full_names)

# Юниты, у которых не найдена фамилия в списке
not_matched_units = {}

for unit_id, unit_name in unit_id_to_name.items():
    found = False
    for surname in known_surnames:
        if surname in unit_name:
            found = True
            break
    if not found:
        not_matched_units[unit_id] = unit_name

# Результат
print(f"❌ Юниты без совпадений по фамилии: {len(not_matched_units)}")
for uid, uname in not_matched_units.items():
    print(f"{uid}: {uname}")
# Out:
# ❌ Юниты без совпадений по фамилии: 31
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27910721: 381 CR Винницкий Ф
# 27909430: 403 Шпаковский
# 28974245: 415 AQ резерв
# 28973928: 431 резерв
# 28573142: 435 резерв
# 28666526: 451 резерв
# 28014074: 452 BJ резерв
# 27909458: 452 CR Аскеров
# 27915589: 460 Егоров
# 28011028: 469 резерв
# 28666496: 472 CO резерв
# 27916518: 522 Ниязов
# 27916552: 526 CQ Лобанова
# 27919664: 529 Григоренко
# 27919763: 655 Нурманов
# 27940698: 659  Мальцев
# 27910072: 682 Кожебаев
# 27915367: 718 резерв
# 27916084: 787  Данчев
# 28606816: 856 Перешивкин
# 27909654: 902 Каненов
# 27911157: 908 Хасанов
# 27914983: 915 CQ Соловьев
# 27915093: 936 Муртазин
# 27911240: 957 Толеубек
# 27909272: 986 Авижич
