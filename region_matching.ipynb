# %%
import geopandas as gpd
import numpy as np
# Замените на путь к вашему файлу
geojson_path = "OSMB-f1ec2d0019a5c0c4984f489cdc13d5d26a7949fd.geojson"

# Чтение GeoJSON
gdf = gpd.read_file(geojson_path)

# Посмотрим на доступные столбцы
print("Доступные столбцы:", gdf.columns)
# Out:
# Доступные столбцы: Index(['osm_id', 'name', 'name_en', 'boundary', 'admin_level',
#        'admin_centre_node_id', 'admin_centre_node_lat',
#        'admin_centre_node_lng', 'label_node_id', 'label_node_lat',
#        'label_node_lng', 'geometry'],
#       dtype='object')

# %%
# Если там есть столбец с названием региона, например 'name' или 'region', выведем уникальные значения
if 'name' in gdf.columns:
    print("Найденные регионы:")
    a = np.sort(gdf['name'].unique())
    [print(i) for i in a]
elif 'region' in gdf.columns:
    print("Найденные регионы:")
    a = np.sort(gdf['region'].unique())
    [print(i) for i in a]
else:
    print("Не удалось найти подходящий столбец с названием региона.")
# Out:
# Найденные регионы:
# Абай ауданы
# Айыртау ауданы
# Алтай ауданы
# Алтынсаринский район - Алтынсарин ауданы
# Амангелді ауданы
# Аршалы ауданы
# Арқалық Қ.Ә.
# Астана
# Астрахан ауданы
# Атбасар ауданы
# Аулиекольский район - Әулиекөл ауданы
# Аягөз ауданы
# Ақжар ауданы
# Ақкөл ауданы
# Ақсу Қ.Ә.
# Ақсуат ауданы
# Ақтоғай ауданы
# Аққайың ауданы
# Аққулы ауданы
# Баянауыл ауданы
# Бейімбет Майлин ауданы
# Бесқарағай ауданы
# Бородулиха ауданы
# Бурабай ауданы
# Біржан сал ауданы
# Бұланды ауданы
# Бұқар жырау ауданы
# Глубокое ауданы
# Денисов ауданы
# Егіндікөл ауданы
# Екібастұз Қ.Ә.
# Ерейментау ауданы
# Ертіс ауданы
# Есіл ауданы
# Жаксынский район - Жақсы ауданы
# Жамбыл ауданы
# Жангелдин ауданы
# Жарма ауданы
# Жарқайың ауданы
# Жаңасемей ауданы
# Железин ауданы
# Жітіқара ауданы
# Зеренді ауданы
# Катонқарағай ауданы
# Курчатов қалалық әкімшілігі
# Күршім ауданы
# Көкпекті ауданы
# Көкшетау Қ.Ә.
# Лисаковск Қ.Ә.
# Май ауданы
# Мамлют ауданы
# Марқакөл ауданы
# Мағжан Жұмабаев ауданы
# Мендыкаринский район - Меңдіқара ауданы
# Наурзумский район - Наурызым ауданы
# Нұра ауданы
# Осакаров ауданы
# Павлодар ауданы
# Павлодар Қ.Ә.
# Петропавл қ.а.
# Риддер қалалық әкімдігі
# Рудный Қ.Ә.
# Самар ауданы
# Сандықтау ауданы
# Саран Қ.Ә.
# Сарыкольский район - Сарыкөл ауданы
# Семей қалалық әкімшілігі
# Степногорск Қ.Ә.
# Тайынша ауданы
# Тарбағатай ауданы
# Теміртау Қ.Ә.
# Тереңкөл ауданы
# Тимирязев ауданы
# Успен ауданы
# Уәлиханов ауданы
# Федоров ауданы
# Целиноград ауданы
# Шал ақын ауданы
# Шарбақты ауданы
# Шахтинск Қ.Ә.
# Шемонаиха ауданы
# Шортанды ауданы
# Ғабит Мүсірепов ауданы
# Қамысты ауданы
# Қарабалық ауданы
# Қарасу ауданы
# Қарағанды Қ.Ә.
# Қарқаралы ауданы
# Қорғалжын ауданы
# Қостанай ауданы
# Қостанай Қ.Ә.
# Қосшы қалалық әкімдігі
# Қызылжар ауданы
# Үлкен Нарын ауданы
# Ұзынкөл ауданы
# Ұлан ауданы
# Өскемен қ.ә.

# %%
reverse_mapping = {
    "Абайский": "Абай ауданы",
    "Айыртауский": "Айыртау ауданы",
    "Есильский": "Есіл ауданы",
    "Акжарский": "Ақжар ауданы",
    "Уалихановский": "Уәлиханов ауданы",
    "Аккайынский": "Аққайың ауданы",
    "Аккольский": "Ақкөл ауданы",
    "Актогайский": "Ақтоғай ауданы",
    "Иртышский": "Ертіс ауданы",
    "Алтай": "Алтай ауданы",
    "Катон Карагай": "Катонқарағай ауданы",
    "Улкен Нарын": "Үлкен Нарын ауданы",
    "Бородулихинский": "Бородулиха ауданы",
    "Самарский": "Самар ауданы",
    "Аршалынский": "Аршалы ауданы",
    "Астраханский": "Астрахан ауданы",
    "Атбасарский": "Атбасар ауданы",
    "Беимбета Майлина": "Бейімбет Майлин ауданы",
    "Алтынсаринский": "Алтынсаринский район - Алтынсарин ауданы",
    "Бескарагайский": "Бесқарағай ауданы",
    "Шемонайхинский": "Шемонаиха ауданы",
    "Биржан Сал": "Біржан сал ауданы",
    "Буландынский": "Бұланды ауданы",
    "Бухар жырауский": "Бұқар жырау ауданы",
    "Г.Мусрепова": "Ғабит Мүсірепов ауданы",
    "Денисовский": "Денисов ауданы",
    "Житикаринский": "Жітіқара ауданы",
    "Камыстинский": "Қамысты ауданы",
    "Карасуский": "Қарасу ауданы",
    "Карасу": "Қарасу ауданы",
    "Мендыгаринский": "Мендыкаринский район - Меңдіқара ауданы",
    "Аркалыкский": "Арқалық Қ.Ә.",
    "Тарановский": "Бейімбет Майлин ауданы",
    "Егиндыкольский": "Егіндікөл ауданы",
    "Жаксынский": "Жаксынский район - Жақсы ауданы",
    "Жамбылский": "Жамбыл ауданы",
    "Жаркаинский": "Жарқайың ауданы",
    "Железинский": "Железин ауданы",
    "Зерендинский": "Зеренді ауданы",
    "Карабалыкский": "Қарабалық ауданы",
    "Костанайский": "Қостанай ауданы",
    "Коргалжынский": "Қорғалжын ауданы",
    "Кызылжарский": "Қызылжар ауданы",
    "Магжана Жумабаева": "Мағжан Жұмабаев ауданы",
    "Мамлютский": "Мамлют ауданы",
    "Сарыкольский": "Сарыкольский район - Сарыкөл ауданы",
    "Узункольский": "Ұзынкөл ауданы",
    "Нуринский": "Нұра ауданы",
    "Осакаровский": "Осакаров ауданы",
    "Павлодарская область": "Павлодар ауданы",
    "Сандыктау": "Сандықтау ауданы",
    "Бурабай ауданы": "Бурабай ауданы",
    "Тайыншинский": "Тайынша ауданы",
    "Теренкольский": "Тереңкөл ауданы",
    "Тимирязевский": "Тимирязев ауданы",
    "Шал Акына": "Шал ақын ауданы",
    "Шарбактинский": "Шарбақты ауданы",
    "Успенский": "Успен ауданы",
    "Целиноградский": "Целиноград ауданы",
    "Глубоковский": "Глубокое ауданы",
    "Шортандинский": "Шортанды ауданы",
    "Ерейментауский": "Ерейментау ауданы",
    "Аулиекольский": "Аулиекольский район - Әулиекөл ауданы",
    "Мендыкаринский": "Мендыкаринский район - Меңдіқара ауданы",
    "
    "Шубин Глеб Владимирович",
    "Шульц Николай Викторович",
    "Абдрахманов Алибек Канатович",
    "Есентаев Дамир Мейрамович",
    "Нургалиев Еламан Кайратович",
    "Раков Валерий Игоревич",
    "Сафронов Александр Викторович",
    "Шадрин Виталий Вячеславович"
]

# %%
import requests
import json

TOKEN = "c611c2bab48335e36a4b59be460c57d270AC971D82FE3E8089C4E317B0ABFB855D254860"
BASE_URL = "https://hst-api.wialon.host/wialon/ajax.html"

def login(token):
    r = requests.get(BASE_URL, params={
        "svc": "token/login",
        "params": json.dumps({"token": token})
    })
    return r.json().get("eid")

def get_items(sid, item_type, flags):
    r = requests.get(BASE_URL, params={
        "svc": "core/search_items",
        "params": json.dumps({
            "spec": {
                "itemsType": item_type,
                "propName": "sys_name",
                "propValueMask": "*",
                "sortType": "sys_name"
            },
            "force": 1,
            "flags": flags,
            "from": 0,
            "to": 0
        }),
        "sid": sid
    })
    return r.json().get("items", [])

if __name__ == "__main__":
    SID = login(TOKEN)
    units = get_items(SID, "avl_unit", 1)
    if not units:
        print("Юниты не найдены.")
    else:
        print("Список юнитов:")
        for unit in units:
            print(f"{unit['id']}: {unit['nm']}")
# Out:
# Список юнитов:
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27910469: 352 Балгожа
# 27910381: 354 Кабимулдин
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27914968: 377 CR Абдрахманов
# 27915302: 380 Садвакасов
# 27910721: 381 CR Винницкий Ф
# 27915499: 383 Карташов
# 27911208: 386 Рак
# 27915429: 387 Тургумбаев
# 27909430: 403 Шпаковский
# 28974245: 415 AQ резерв
# 28131462: 416 Сералиев
# 28132922: 419 Абдиров
# 28014920: 428 AQ Нургалиев
# 28973928: 431 Шадрин
# 27914966: 435 Джиоев
# 28573142: 435 резерв
# 28666651: 443 AQ Кадырбек
# 28222684: 443 СО Садовский
# 28666387: 449 Темишев
# 28666526: 451 Бугаев
# 28014074: 452 BJ резерв
# 27909458: 452 CR Аскеров
# 28131410: 452 Құрман
# 28246259: 453 Мусин
# 28606589: 458 Кабимулдин
# 28243616: 459 Жаирбаев
# 28973874: 460 CO Сундетбаев
# 27915589: 460 Егоров
# 28606693: 461 Барон
# 28974276: 463 CO Шубин
# 28399015: 464 Кабдрахманов
# 28011473: 465 Кайратов
# 27780244: 467 Раков
# 28405611: 468 Кулбулдин
# 28011028: 469 Максимов
# 27792707: 470 Вахнина
# 28243564: 471 Калиев
# 28666496: 472 CO Қойгелді
# 28222776: 473 Ескатов
# 28113524: 475 CO Адомайтис
# 28973541: 476 Бойко
# 28569265: 477 Сериков
# 28573545: 478 Афанасьев
# 28973983: 479 CO Синяков
# 27780000: 480 CO  Шатохин
# 27780113: 481 CO Сейдыков
# 28574085: 482 Шаткенов
# 28113464: 483 Назарбек М
# 28014385: 484 Яцынович
# 28172278: 485 CO Солдатенков
# 28974125: 486 CO Усенов
# 28606770: 495 Мукушев
# 27916518: 522 Ниязов
# 27916552: 526 CQ Лобанова
# 27919664: 529 Григоренко
# 27919718: 536 Гаврилюк
# 28574445: 586 Нургалиев
# 27916381: 639 CQ Герасимов
# 27919696: 643 CQ Жакиенов
# 27916031: 652 Глазырин
# 27919840: 654 CQ Ключка
# 27919763: 655 Нурманов
# 27940698: 659  Мальцев
# 28014203: 667 СН Куташов
# 28974156: 668 CH Бородич
# 28172244: 673 Яковлев
# 27910072: 682 Кожебаев
# 27915367: 718 резерв
# 27909082: 726 Таукин
# 27915989: 739 Коржов
# 27916171: 759 CQ Анишкевич
# 27910284: 769 Охатов
# 27916258: 780 Турежанов
# 27916107: 783 Раимкулов
# 27916084: 787  Данчев
# 27916334: 845 Сафронов
# 28015162: 847 Есентаев
# 28014649: 848 Жанатаев
# 28973854: 853 BJ Зацепин
# 28172293: 854 BJ Кабдиев
# 28974038: 855 BJ Ибраев
# 28606816: 856 Перешивкин
# 27909654: 902 Каненов
# 27911157: 908 Хасанов
# 27914983: 915 CQ Соловьев
# 27910755: 932 Баймурзинов
# 27915093: 936 Муртазин
# 27909218: 947 Жуманазаров
# 27909147: 952 CQ Гугневич
# 27915282: 956 CQ Терещенко
# 27911240: 957 Толеубек
# 27915226: 970 CQ Шульц
# 27915747: 974 Лубянецкий
# 27909272: 986 Авижич
# 27915149: 997 Кализатов
# 27909773: Дауленов 357
# 27909883: Джексембаев 353

# %%
unit_id_to_name = {unit["id"]: unit["nm"] for unit in units}

# %%
# full_names          — список ФИО
# unit_id_to_name     — словарь {unit_id: unit_name}

name_to_unit = {}

for full in full_names:
    surname = full.split()[0]                         # берём фамилию
    # ищем любой unit_name, в котором встречается фамилия
    match = next((u for u in unit_id_to_name.values() if surname in u), None)
    name_to_unit[full] = match        # будет строка unit_name или None

# name_to_unit теперь выглядит так:
# {
#     "Иванов Иван Иванович": "Unit 123 — Иванов И.И.",
#     "Петров Пётр":          None,
#     ...
# }

# Если нужен только успешно сопоставленный под‑словарь:
matched = {k: v for k, v in name_to_unit.items() if v}
unmatched = [k for k, v in name_to_unit.items() if v is None]

# %%
import pandas as pd
df = pd.read_excel("Контакты Stratera.xlsx", sheet_name="Менеджеры по продажам районы")

df = df[['ФИО', 'Область', 'Район ']]

df.columns = ['FullName', 'Region', 'District']


import re
import pandas as pd

# регулярка: делим по ", "‑если‑она‑НЕ‑внутри‑скобок
split_pat = r',\s*(?![^()]*\))'          # negative‑lookahead: после запятой
                                         # нет закрывающей скобки до следующей открытой

df = (
    df.assign(District=df['District'].str.split(split_pat, regex=True))  # список
      .explode('District')                                               # строки
      .assign(District=lambda d: d['District'].str.strip())              # подчистить пробелы
      .reset_index(drop=True)
)

# %%
df = df[:-1]

# %%
matched
# Out:
# {'Барон Сергей Дмитриевич': '461 Барон',
#  'Бугаев Никита Сергеевич': '451 Бугаев',
#  'Кадырбек Куат': '443 AQ Кадырбек',
#  'Кайратов Батырхан Бейсенбайұлы': '465 Кайратов',
#  'Құрман Айдын Мұхитұлы': '452 Құрман',
#  'Куташов Виталий Николаевич': '667 СН Куташов',
#  'Назарбек Мәди Мейрамбекұлы': '483 Назарбек М',
#  'Сундетбаев Болат Муратбекович': '460 CO Сундетбаев',
#  'Темишев Нуржан Мейрамғалиұлы': '449 Темишев',
#  'Шаткенов Арлан Нурдаулетович': '482 Шаткенов',
#  'Яковлев Александр Александрович': '673 Яковлев',
#  'Адомайтис Евгений Валерьевич': '475 CO Адомайтис',
#        'Турежанов Болат Агибаевич', 'Бородич Николай Михайлович',
#        'Вахнина Виктория Анатольевна', 'Карташов Олег Валерьевич',
#        'Кулбулдин Бауыржан Мубаракович', 'Мукушев Асет Кайдарович',
#        'Охатов Жанат Еленулы', 'Садовский Игорь Валерьевич',
#        'Усенов Асанали Асхатович', 'Шубин Глеб Владимирович',
#        'Шульц Николай Викторович', 'Абдрахманов Алибек Канатович',
#        'Гаврилюк Сергей Васильевич', 'Есентаев Дамир Мейрамович',
#        'Нургалиев Еламан Кайратович', 'Раков Валерий Игоревич',
#        'Сафронов Александр Викторович', 'Шадрин Виталий Вячеславович'],
#       dtype=object)

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

# %%
df["Region_mapped"] = df["District"].apply(
    lambda name: reverse_mapping.get(name, None)   # вернёт value или None
)

# %%
df.to_csv('manager_region.csv', index=False)

# %%
df = pd.read_csv('manager_region.csv')

region_dict = (
    df.groupby('Car_numb')['Region_mapped']
    .apply(lambda x: list(set(x)))
    .to_dict()
)

# %%
pd.set_option('display.max_rows', None)
df.sort_values(by = 'Car_numb')
# Out:
#                             FullName                  Region  \
# 67        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 63        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 64        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 65        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 66        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 124     Абдрахманов Алибек Канатович     СКО (Петропавловск)
# 125     Абдрахманов Алибек Канатович     СКО (Петропавловск)
# 123     Абдрахманов Алибек Канатович     СКО (Петропавловск)
# 106     Садвакасов Рустам Дмитриевич          ПВЛ (Павлодар)
# 115         Карташов Олег Валерьевич          СКО (Кокшетау)
# 114         Карташов Олег Валерьевич          СКО (Кокшетау)
# 105              Рак Егор Валерьевич          ПВЛ (Павлодар)
# 20        Тургумбаев Ильяс Аскарович           АКМ (Атбасар)
# 21        Тургумбаев Ильяс Аскарович           АКМ (Атбасар)
# 93         Сералиев Алишер Габитович         КСТ (Костанай)
# 94         Сералиев Алишер Габитович         КСТ (Костанай)
# 48       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 54       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 53       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 52       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 51       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 50       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 49       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 47       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 87      Нургалиев Данияр Рамазанович         КСТ (Костанай)
# 88      Нургалиев Данияр Рамазанович         КСТ (Костанай)
# 133      Шадрин Виталий Вячеславович     СКО (Петропавловск)
# 134      Шадрин Виталий Вячеславович     СКО (Петропавловск)
# 29      Джиоев Георгий Александрович          АКМ (Кокшетау)
# 2                      Кадырбек Куат            АКМ (Астана)
# 119       Садовский Игорь Валерьевич          СКО (Кокшетау)
# 10      Темишев Нуржан Мейрамғалиұлы            АКМ (Астана)
# 1            Бугаев Никита Сергеевич            АКМ (Астана)
# 7              Құрман Айдын Мұхитұлы            АКМ (Астана)
# 46             Мусин Едіге Муратович  ВКО (Усть-Каменогорск)
# 45             Мусин Едіге Муратович  ВКО (Усть-Каменогорск)
# 44             Мусин Едіге Муратович  ВКО (Усть-Каменогорск)
# 39         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 40         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 41         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 42         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 43         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 37       Жаирбаев Даурен Беимбекович  ВКО (Усть-Каменогорск)
# 38       Жаирбаев Даурен Беимбекович  ВКО (Усть-Каменогорск)
# 9      Сундетбаев Болат Муратбекович            АКМ (Астана)
# 0            Барон Сергей Дмитриевич            АКМ (Астана)
# 121          Шубин Глеб Владимирович          СКО (Кокшетау)
# 31      Кабдрахманов Асхат Канатович          АКМ (Кокшетау)
# 30      Кабдрахманов Асхат Канатович          АКМ (Кокшетау)
# 3     Кайратов Батырхан Бейсенбайұлы            АКМ (Астана)
# 4     Кайратов Батырхан Бейсенбайұлы            АКМ (Астана)
# 131           Раков Валерий Игоревич     СКО (Петропавловск)
# 116   Кулбулдин Бауыржан Мубаракович          СКО (Кокшетау)
# 17     Максимов Станислав Валерьевич           АКМ (Атбасар)
# 113     Вахнина Виктория Анатольевна          СКО (Кокшетау)
# 32           Калиев Жанибек Омарович          АКМ (Кокшетау)
# 84          Қойгелді Женіс Даулетұлы         КСТ (Костанай)
# 83          Қойгелді Женіс Даулетұлы         КСТ (Костанай)
# 82          Қойгелді Женіс Даулетұлы         КСТ (Костанай)
# 81          Қойгелді Женіс Даулетұлы         КСТ (Костанай)
# 69          Ескатов Алишер Маратович         КСТ (Костанай)
# 70          Ескатов Алишер Маратович         КСТ (Костанай)
# 13      Адомайтис Евгений Валерьевич           АКМ (Атбасар)
# 99               Бойко Олег Игоревич          ПВЛ (Павлодар)
# 100              Бойко Олег Игоревич          ПВЛ (Павлодар)
# 107         Сериков Бахтияр Тлекович          ПВЛ (Павлодар)
#
# 128          Кызылжарский       586 Нургалиев
# 129           Аккайынский       586 Нургалиев
# 130     Магжана Жумабаева       586 Нургалиев
# 14              Есильский    639 CQ Герасимов
# 71           Костанайский     643 CQ Жакиенов
# 68             Карасуский        652 Глазырин
# 104         Теренкольский       654 CQ Ключка
# 103           Железинский       654 CQ Ключка
# 5           Шортандинский      667 СН Куташов
# 6          Ерейментауский      667 СН Куташов
# 112           Г.Мусрепова      668 CH Бородич
# 12             Аккольский         673 Яковлев
# 98           Узункольский          726 Таукин
# 96            Тарановский          726 Таукин
# 97          Аулиекольский          726 Таукин
# 95            Федоровский          726 Таукин
# 79          Карабалыкский          739 Коржов
# 80         Мендыкаринский          739 Коржов
# 57         Алтынсаринский    759 CQ Анишкевич
# 55             Карасуский    759 CQ Анишкевич
# 56           Сарыкольский    759 CQ Анишкевич
# 118           Г.Мусрепова          769 Охатов
# 111         Уалихановский       780 Турежанов
# 110             Акжарский       780 Турежанов
# 92         Мендыкаринский       783 Раимкулов
# 89          Карабалыкский       783 Раимкулов
# 90           Костанайский       783 Раимкулов
# 91           Камыстинский       783 Раимкулов
# 132            Мамлютский        845 Сафронов
# 127             Шал Акына        847 Есентаев
# 73          Аулиекольский        848 Жанатаев
# 72             Карасуский        848 Жанатаев
# 16            Жаркаинский      853 BJ Зацепин
# 102  Павлодарская область      854 BJ Кабдиев
# 76           Сарыкольский       855 BJ Ибраев
# 77          Житикаринский       855 BJ Ибраев
# 78           Узункольский       855 BJ Ибраев
# 60         Алтынсаринский     932 Баймурзинов
# 58          Карабалыкский     932 Баймурзинов
# 59            Федоровский     932 Баймурзинов
# 61             Карасуский     932 Баймурзинов
# 62           Костанайский     932 Баймурзинов
# 75          Аулиекольский     947 Жуманазаров
# 74            Федоровский     947 Жуманазаров
# 15             Жаксынский     952 CQ Гугневич
# 19            Жаркаинский    956 CQ Терещенко
# 122             Есильский        970 CQ Шульц
# 86           Сарыкольский      974 Лубянецкий
# 85           Узункольский      974 Лубянецкий
# 33              Сандыктау       997 Кализатов
# 34         Бурабай ауданы       997 Кализатов
# 101             Успенский        Дауленов 357
# 35         Шемонайхинский     Джексембаев 353
# 36           Глубоковский     Джексембаев 353
#
#                                 Region_mapped
# 67                     Бейімбет Майлин ауданы
# 63                             Денисов ауданы
# 64                              Қарасу ауданы
# 65    Мендыкаринский район - Меңдіқара ауданы
# 66                               Арқалық Қ.Ә.
# 124                           Қызылжар ауданы
# 125                            Аққайың ауданы
# 123                             Жамбыл ауданы
# 106                           Шарбақты ауданы
# 115                               Есіл ауданы
# 114                            Айыртау ауданы
# 105                           Тереңкөл ауданы
# 20            Жаксынский район - Жақсы ауданы
# 21                                Есіл ауданы
# 93                            Қостанай ауданы
# 94    Мендыкаринский район - Меңдіқара ауданы
# 48        Сарыкольский район - Сарыкөл ауданы
# 54                                        NaN
# 53                               Арқалық Қ.Ә.
# 52                              Қарасу ауданы
# 51   Алтынсаринский район - Алтынсарин ауданы
# 50                            Қостанай ауданы
# 49                             Ұзынкөл ауданы
# 47    Мендыкаринский район - Меңдіқара ауданы
# 87        Сарыкольский район - Сарыкөл ауданы
# 88                             Ұзынкөл ауданы
# 133                          Тимирязев ауданы
# 134                           Шал ақын ауданы
# 29                           Сандықтау ауданы
# 2                             Астрахан ауданы
# 119                           Шал ақын ауданы
# 10                           Егіндікөл ауданы
# 1                               Аршалы ауданы
# 7                               Аршалы ауданы
# 46                           Шемонаиха ауданы
# 45                          Бородулиха ауданы
# 44                          Бесқарағай ауданы
# 39                               Алтай ауданы
# 40                        Катонқарағай ауданы
# 41                         Үлкен Нарын ауданы
# 42                          Бородулиха ауданы
# 43                               Самар ауданы
# 37                          Бесқарағай ауданы
# 38                          Бородулиха ауданы
# 9                            Егіндікөл ауданы
# 0                             Осакаров ауданы
# 121                    Ғабит Мүсірепов ауданы
# 31                             Бурабай ауданы
# 30                          Біржан сал ауданы
# 3                              Бұланды ауданы
# 4                             Астрахан ауданы
# 131                          Тимирязев ауданы
# 116                          Уәлиханов ауданы
# 17                             Атбасар ауданы
# 113                            Тайынша ауданы
# 32                             Зеренді ауданы
# 84                     Бейімбет Майлин ауданы
# 83                             Денисов ауданы
# 82                            Жітіқара ауданы
# 81                             Қамысты ауданы
# 69                     Бейімбет Майлин ауданы
# 70   Алтынсаринский район - Алтынсарин ауданы
# 13                             Атбасар ауданы
# 99                            Шарбақты ауданы
# 100                              Успен ауданы
# 107                            Ақтоғай ауданы
# 108                              Ертіс ауданы
# 109                            Железин ауданы
# 23                              Аршалы ауданы
# 22                            Осакаров ауданы
# 18                            Жарқайың ауданы
# 27                                Абай ауданы
# 24                                Нұра ауданы
# 25                                Абай ауданы
# 11                           Қорғалжын ауданы
# 8                           Целиноград ауданы
# 28                            Осакаров ауданы
# 26                         Бұқар жырау ауданы
# 120                          Уәлиханов ауданы
# 117                            Аққайың ауданы
# 126                    Мағжан Жұмабаев ауданы
# 128                           Қызылжар ауданы
# 129                            Аққайың ауданы
# 130                    Мағжан Жұмабаев ауданы
# 14                                Есіл ауданы
# 71                            Қостанай ауданы
# 68                              Қарасу ауданы
# 104                           Тереңкөл ауданы
# 103                            Железин ауданы
# 5                             Шортанды ауданы
# 6                           Ерейментау ауданы
# 112                    Ғабит Мүсірепов ауданы
# 12                               Ақкөл ауданы
# 98                             Ұзынкөл ауданы
# 96                     Бейімбет Майлин ауданы
# 97      Аулиекольский район - Әулиекөл ауданы
# 95                             Федоров ауданы
# 79                           Қарабалық ауданы
# 80    Мендыкаринский район - Меңдіқара ауданы
# 57   Алтынсаринский район - Алтынсарин ауданы
# 55                              Қарасу ауданы
# 56        Сарыкольский район - Сарыкөл ауданы
# 118                    Ғабит Мүсірепов ауданы
# 111                          Уәлиханов ауданы
# 110                              Ақжар ауданы
# 92    Мендыкаринский район - Меңдіқара ауданы
# 89                           Қарабалық ауданы
# 90                            Қостанай ауданы
# 91                             Қамысты ауданы
# 132                             Мамлют ауданы
# 127                           Шал ақын ауданы
# 73      Аулиекольский район - Әулиекөл ауданы
# 72                              Қарасу ауданы
# 16                            Жарқайың ауданы
# 102                           Павлодар ауданы
# 76        Сарыкольский район - Сарыкөл ауданы
# 77                            Жітіқара ауданы
# 78                             Ұзынкөл ауданы
# 60   Алтынсаринский район - Алтынсарин ауданы
# 58                           Қарабалық ауданы
# 59                             Федоров ауданы
# 61                              Қарасу ауданы
# 62                            Қостанай ауданы
# 75      Аулиекольский район - Әулиекөл ауданы
# 74                             Федоров ауданы
# 15            Жаксынский район - Жақсы ауданы
# 19                            Жарқайың ауданы
# 122                               Есіл ауданы
# 86        Сарыкольский район - Сарыкөл ауданы
# 85                             Ұзынкөл ауданы
# 33                           Сандықтау ауданы
# 34                             Бурабай ауданы
# 101                              Успен ауданы
# 35                           Шемонаиха ауданы
# 36                            Глубокое ауданы

# %%
df[['Car_numb', 'Region_mapped']]
# Out:
#                Car_numb                             Region_mapped
# 0             461 Барон                           Осакаров ауданы
# 1            451 Бугаев                             Аршалы ауданы
# 2       443 AQ Кадырбек                           Астрахан ауданы
# 3          465 Кайратов                            Бұланды ауданы
# 4          465 Кайратов                           Астрахан ауданы
# 5        667 СН Куташов                           Шортанды ауданы
# 6        667 СН Куташов                         Ерейментау ауданы
# 7            452 Құрман                             Аршалы ауданы
# 8        483 Назарбек М                         Целиноград ауданы
# 9     460 CO Сундетбаев                          Егіндікөл ауданы
# 10          449 Темишев                          Егіндікөл ауданы
# 11         482 Шаткенов                          Қорғалжын ауданы
# 12          673 Яковлев                              Ақкөл ауданы
# 13     475 CO Адомайтис                            Атбасар ауданы
# 14     639 CQ Герасимов                               Есіл ауданы
# 15      952 CQ Гугневич           Жаксынский район - Жақсы ауданы
# 16       853 BJ Зацепин                           Жарқайың ауданы
# 17         469 Максимов                            Атбасар ауданы
# 18       479 CO Синяков                           Жарқайың ауданы
# 19     956 CQ Терещенко                           Жарқайың ауданы
# 20       387 Тургумбаев           Жаксынский район - Жақсы ауданы
# 21       387 Тургумбаев                               Есіл ауданы
# 22        478 Афанасьев                           Осакаров ауданы
# 23        478 Афанасьев                             Аршалы ауданы
# 24      481 CO Сейдыков                               Нұра ауданы
# 25      481 CO Сейдыков                               Абай ауданы
# 26   485 CO Солдатенков                        Бұқар жырау ауданы
# 27      480 CO  Шатохин                               Абай ауданы
# 28         484 Яцынович                           Осакаров ауданы
# 29           435 Джиоев                          Сандықтау ауданы
# 30     464 Кабдрахманов                         Біржан сал ауданы
# 31     464 Кабдрахманов                            Бурабай ауданы
# 32           471 Калиев                            Зеренді ауданы
# 33        997 Кализатов                          Сандықтау ауданы
# 34        997 Кализатов                            Бурабай ауданы
# 35      Джексембаев 353                          Шемонаиха ауданы
# 36      Джексембаев 353                           Глубокое ауданы
# 37         459 Жаирбаев                         Бесқарағай ауданы
# 38         459 Жаирбаев                         Бородулиха ауданы
# 39       458 Кабимулдин                              Алтай ауданы
# 40       458 Кабимулдин                       Катонқарағай ауданы
# 41       458 Кабимулдин                        Үлкен Нарын ауданы
# 42       458 Кабимулдин                         Бородулиха ауданы
# 43       458 Кабимулдин                              Самар ауданы
# 44            453 Мусин                         Бесқарағай ауданы
# 45            453 Мусин                         Бородулиха ауданы
# 46            453 Мусин                          Шемонаиха ауданы
# 47          419 Абдиров   Мендыкаринский район - Меңдіқара ауданы
# 48          419 Абдиров       Сарыкольский район - Сарыкөл ауданы
# 49          419 Абдиров                            Ұзынкөл ауданы
# 50          419 Абдиров                           Қостанай ауданы
# 51          419 Абдиров  Алтынсаринский район - Алтынсарин ауданы
# 52          419 Абдиров                             Қарасу ауданы
# 53          419 Абдиров                              Арқалық Қ.Ә.
# 54          419 Абдиров                                       NaN
# 55     759 CQ Анишкевич                             Қарасу ауданы
# 56     759 CQ Анишкевич       Сарыкольский район - Сарыкөл ауданы
# 57     759 CQ Анишкевич  Алтынсаринский район - Алтынсарин ауданы
# 58      932 Баймурзинов                          Қарабалық ауданы
# 59      932 Баймурзинов                            Федоров ауданы
# 60      932 Баймурзинов  Алтынсаринский район - Алтынсарин ауданы
# 61      932 Баймурзинов                             Қарасу ауданы
# 62      932 Баймурзинов                           Қостанай ауданы
# 63          352 Балгожа                            Денисов ауданы
# 64          352 Балгожа                             Қарасу ауданы
# 65          352 Балгожа   Мендыкаринский район - Меңдіқара ауданы
# 66          352 Балгожа                              Арқалық Қ.Ә.
# 67          352 Балгожа                    Бейімбет Майлин ауданы
# 68         652 Глазырин                             Қарасу ауданы
# 69          473 Ескатов                    Бейімбет Майлин ауданы
# 70          473 Ескатов  Алтынсаринский район - Алтынсарин ауданы
# 71      643 CQ Жакиенов                           Қостанай ауданы
# 72         848 Жанатаев                             Қарасу ауданы
# 73         848 Жанатаев     Аулиекольский район - Әулиекөл ауданы
# 74      947 Жуманазаров                            Федоров ауданы
# 75      947 Жуманазаров     Аулиекольский район - Әулиекөл ауданы
# 76        855 BJ Ибраев       Сарыкольский район - Сарыкөл ауданы
# 77        855 BJ Ибраев                           Жітіқара ауданы
# 78        855 BJ Ибраев                            Ұзынкөл ауданы
# 79           739 Коржов                          Қарабалық ауданы
# 80           739 Коржов   Мендыкаринский район - Меңдіқара ауданы
# 81      472 CO Қойгелді                            Қамысты ауданы
# 82      472 CO Қойгелді                           Жітіқара ауданы
# 83      472 CO Қойгелді                            Денисов ауданы
# 84      472 CO Қойгелді                    Бейімбет Майлин ауданы
# 85       974 Лубянецкий                            Ұзынкөл ауданы
# 86       974 Лубянецкий       Сарыкольский район - Сарыкөл ауданы
# 87     428 AQ Нургалиев       Сарыкольский район - Сарыкөл ауданы
# 88     428 AQ Нургалиев                            Ұзынкөл ауданы
# 89        783 Раимкулов                          Қарабалық ауданы
# 90        783 Раимкулов                           Қостанай ауданы
# 91        783 Раимкулов                            Қамысты ауданы
# 92        783 Раимкулов   Мендыкаринский район - Меңдіқара ауданы
# 93         416 Сералиев                           Қостанай ауданы
# 94         416 Сералиев   Мендыкаринский район - Меңдіқара ауданы
# 95           726 Таукин                            Федоров ауданы
# 96           726 Таукин                    Бейімбет Майлин ауданы
# 97           726 Таукин     Аулиекольский район - Әулиекөл ауданы
# 98           726 Таукин                            Ұзынкөл ауданы
# 99            476 Бойко                           Шарбақты ауданы
# 100           476 Бойко                              Успен ауданы
# 101        Дауленов 357                              Успен ауданы
# 102      854 BJ Кабдиев                           Павлодар ауданы
# 103       654 CQ Ключка                            Железин ауданы
# 104       654 CQ Ключка                           Тереңкөл ауданы
# 105             386 Рак                           Тереңкөл ауданы
# 106      380 Садвакасов                           Шарбақты ауданы
# 107         477 Сериков                            Ақтоғай ауданы
# 108         477 Сериков                              Ертіс ауданы
# 109         477 Сериков                            Железин ауданы
# 110       780 Турежанов                              Ақжар ауданы
# 111       780 Турежанов                          Уәлиханов ауданы
# 112      668 CH Бородич                    Ғабит Мүсірепов ауданы
# 113         470 Вахнина                            Тайынша ауданы
# 114        383 Карташов                            Айыртау ауданы
# 115        383 Карташов                               Есіл ауданы
# 116       468 Кулбулдин                          Уәлиханов ауданы
# 117         495 Мукушев                            Аққайың ауданы
# 118          769 Охатов                    Ғабит Мүсірепов ауданы
# 119    443 СО Садовский                           Шал ақын ауданы
# 120       486 CO Усенов                          Уәлиханов ауданы
# 121        463 CO Шубин                    Ғабит Мүсірепов ауданы
# 122        970 CQ Шульц                               Есіл ауданы
# 123  377 CR Абдрахманов                             Жамбыл ауданы
# 124  377 CR Абдрахманов                           Қызылжар ауданы
# 125  377 CR Абдрахманов                            Аққайың ауданы
# 126        536 Гаврилюк                    Мағжан Жұмабаев ауданы
# 127        847 Есентаев                           Шал ақын ауданы
# 128       586 Нургалиев                           Қызылжар ауданы
# 129       586 Нургалиев                            Аққайың ауданы
# 130       586 Нургалиев                    Мағжан Жұмабаев ауданы
# 131           467 Раков                          Тимирязев ауданы
# 132        845 Сафронов                             Мамлют ауданы
# 133          431 Шадрин                          Тимирязев ауданы
# 134          431 Шадрин                           Шал ақын ауданы

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

df["Region_mapped"] = df["District"].apply(
    lambda name: reverse_mapping.get(name, None)   # вернёт value или None
)

# %%
# Извлекаем фамилии из ФИО
known_surnames = set(name.split()[0] for name in full_names)

# Юниты, у которых не найдена фамилия в списке
not_matched_units = {}

for unit_id, unit_name in unit_id_to_name.items():
    found = False
    for surname in known_surnames:
        if surname in unit_name:
            found = True
            break
    if not found:
        not_matched_units[unit_id] = unit_name

# Результат
print(f"❌ Юниты без совпадений по фамилии: {len(not_matched_units)}")
for uid, uname in not_matched_units.items():
    print(f"{uid}: {uname}")
# Out:
# ❌ Юниты без совпадений по фамилии: 27
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27910721: 381 CR Винницкий Ф
# 27909430: 403 Шпаковский
# 28974245: 415 AQ резерв
# 28573142: 435 резерв
# 28014074: 452 BJ резерв
# 27909458: 452 CR Аскеров
# 27915589: 460 Егоров
# 27916518: 522 Ниязов
# 27916552: 526 CQ Лобанова
# 27919664: 529 Григоренко
# 27919763: 655 Нурманов
# 27940698: 659  Мальцев
# 27910072: 682 Кожебаев
# 27915367: 718 резерв
# 27916084: 787  Данчев
# 28606816: 856 Перешивкин
# 27909654: 902 Каненов
# 27911157: 908 Хасанов
# 27914983: 915 CQ Соловьев
# 27915093: 936 Муртазин
# 27911240: 957 Толеубек
# 27909272: 986 Авижич
