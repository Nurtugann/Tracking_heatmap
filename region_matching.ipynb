# %%
import geopandas as gpd
import numpy as np
# Замените на путь к вашему файлу
geojson_path = "OSMB-f1ec2d0019a5c0c4984f489cdc13d5d26a7949fd.geojson"

# Чтение GeoJSON
gdf = gpd.read_file(geojson_path)

# Посмотрим на доступные столбцы
print("Доступные столбцы:", gdf.columns)
# Out:
# Доступные столбцы: Index(['osm_id', 'name', 'name_en', 'boundary', 'admin_level',
#        'admin_centre_node_id', 'admin_centre_node_lat',
#        'admin_centre_node_lng', 'label_node_id', 'label_node_lat',
#        'label_node_lng', 'geometry'],
#       dtype='object')

# %%
# Если там есть столбец с названием региона, например 'name' или 'region', выведем уникальные значения
if 'name' in gdf.columns:
    print("Найденные регионы:")
    a = np.sort(gdf['name'].unique())
    [print(i) for i in a]
elif 'region' in gdf.columns:
    print("Найденные регионы:")
    a = np.sort(gdf['region'].unique())
    [print(i) for i in a]
else:
    print("Не удалось найти подходящий столбец с названием региона.")
# Out:
# Найденные регионы:
# Абай ауданы
# Айыртау ауданы
# Алтай ауданы
# Алтынсаринский район - Алтынсарин ауданы
# Амангелді ауданы
# Аршалы ауданы
# Арқалық Қ.Ә.
# Астана
# Астрахан ауданы
# Атбасар ауданы
# Аулиекольский район - Әулиекөл ауданы
# Аягөз ауданы
# Ақжар ауданы
# Ақкөл ауданы
# Ақсу Қ.Ә.
# Ақсуат ауданы
# Ақтоғай ауданы
# Аққайың ауданы
# Аққулы ауданы
# Баянауыл ауданы
# Бейімбет Майлин ауданы
# Бесқарағай ауданы
# Бородулиха ауданы
# Бурабай ауданы
# Біржан сал ауданы
# Бұланды ауданы
# Бұқар жырау ауданы
# Глубокое ауданы
# Денисов ауданы
# Егіндікөл ауданы
# Екібастұз Қ.Ә.
# Ерейментау ауданы
# Ертіс ауданы
# Есіл ауданы
# Жаксынский район - Жақсы ауданы
# Жамбыл ауданы
# Жангелдин ауданы
# Жарма ауданы
# Жарқайың ауданы
# Жаңасемей ауданы
# Железин ауданы
# Жітіқара ауданы
# Зеренді ауданы
# Катонқарағай ауданы
# Курчатов қалалық әкімшілігі
# Күршім ауданы
# Көкпекті ауданы
# Көкшетау Қ.Ә.
# Лисаковск Қ.Ә.
# Май ауданы
# Мамлют ауданы
# Марқакөл ауданы
# Мағжан Жұмабаев ауданы
# Мендыкаринский район - Меңдіқара ауданы
# Наурзумский район - Наурызым ауданы
# Нұра ауданы
# Осакаров ауданы
# Павлодар ауданы
# Павлодар Қ.Ә.
# Петропавл қ.а.
# Риддер қалалық әкімдігі
# Рудный Қ.Ә.
# Самар ауданы
# Сандықтау ауданы
# Саран Қ.Ә.
# Сарыкольский район - Сарыкөл ауданы
# Семей қалалық әкімшілігі
# Степногорск Қ.Ә.
# Тайынша ауданы
# Тарбағатай ауданы
# Теміртау Қ.Ә.
# Тереңкөл ауданы
# Тимирязев ауданы
# Успен ауданы
# Уәлиханов ауданы
# Федоров ауданы
# Целиноград ауданы
# Шал ақын ауданы
# Шарбақты ауданы
# Шахтинск Қ.Ә.
# Шемонаиха ауданы
# Шортанды ауданы
# Ғабит Мүсірепов ауданы
# Қамысты ауданы
# Қарабалық ауданы
# Қарасу ауданы
# Қарағанды Қ.Ә.
# Қарқаралы ауданы
# Қорғалжын ауданы
# Қостанай ауданы
# Қостанай Қ.Ә.
# Қосшы қалалық әкімдігі
# Қызылжар ауданы
# Үлкен Нарын ауданы
# Ұзынкөл ауданы
# Ұлан ауданы
# Өскемен қ.ә.

# %%
reverse_mapping = {
    "Амангельдинский": "Амангелді ауданы",
    "Абайский": "Абай ауданы",
    "Айыртауский": "Айыртау ауданы",
    "Есильский": "Есіл ауданы",
    "Акжарский": "Ақжар ауданы",
    "Уалихановский": "Уәлиханов ауданы",
    "Аккайынский": "Аққайың ауданы",
    "Аккольский": "Ақкөл ауданы",
    "Актогайский": "Ақтоғай ауданы",
    "Иртышский": "Ертіс ауданы",
    "Алтай": "Алтай ауданы",
    "Катон Карагай": "Катонқарағай ауданы",
    "Улкен Нарын": "Үлкен Нарын ауданы",
    "Бородулихинский": "Бородулиха ауданы",
    "Самарский": "Самар ауданы",
    "Аршалынский": "Аршалы ауданы",
    "Астраханский": "Астрахан ауданы",
    "Атбасарский": "Атбасар ауданы",
    "Беимбета Майлина": "Бейімбет Майлин ауданы",
    "Алтынсаринский": "Алтынсаринский район - Алтынсарин ауданы",
    "Бескарагайский": "Бесқарағай ауданы",
    "Шемонайхинский": "Шемонаиха ауданы",
    "Биржан Сал": "Біржан сал ауданы",
    "Буландынский": "Бұланды ауданы",
    "Бухар жырауский": "Бұқар жырау ауданы",
    "Г.Мусрепова": "Ғабит Мүсірепов ауданы",
    "Денисовский": "Денисов ауданы",
    "Житикаринский": "Жітіқара ауданы",
    "Камыстинский": "Қамысты ауданы",
    "Карасуский": "Қарасу ауданы",
    "Карасу": "Қарасу ауданы",
    "Мендыгаринский": "Мендыкаринский район - Меңдіқара ауданы",
    "Аркалыкский": "Арқалық Қ.Ә.",
    "Тарановский": "Бейімбет Майлин ауданы",
    "Егиндыкольский": "Егіндікөл ауданы",
    "Жаксынский": "Жаксынский район - Жақсы ауданы",
    "Жамбылский": "Жамбыл ауданы",
    "Жаркаинский": "Жарқайың ауданы",
    "Железинский": "Железин ауданы",
    "Зерендинский": "Зеренді ауданы",
    "Карабалыкский": "Қарабалық ауданы",
    "Костанайский": "Қостанай ауданы",
    "Коргалжынский": "Қорғалжын ауданы",
    "Кызылжарский": "Қызылжар ауданы",
    "Магжана Жумабаева": "Мағжан Жұмабаев ауданы",
    "Мамлютский": "Мамлют ауданы",
    "Сарыкольский": "Сарыкольский район - Сарыкөл ауданы",
    "Узункольский": "Ұзынкөл ауданы",
    "Нуринский": "Нұра ауданы",
    "Осакаровский": "Осакаров ауданы",
    "Павлодарская область": "Павлодар ауданы",
    "Сандыктау": "Сандықтау ауданы",
    "Бурабай ауданы": "Бурабай ауданы",
    "Тайыншинский": "Тайынша ауданы",
    "Теренкольский": "Тереңкөл ауданы",
    "Тимирязевский": "Тимирязев ауданы",
    "Шал Акына": "Шал ақын ауданы",
    "Шарбактинский": "Шарбақты ауданы",
    "Успенский": "Успен ауданы",
    "Шубин Глеб Владимирович",
    "Шульц Николай Викторович",
    "Абдрахманов Алибек Канатович",
    "Есентаев Дамир Мейрамович",
    "Нургалиев Еламан Кайратович",
    "Раков Валерий Игоревич",
    "Сафронов Александр Викторович",
    "Шадрин Виталий Вячеславович"
]

# %%
import requests
import json

TOKEN = "c611c2bab48335e36a4b59be460c57d2BF8416B73C4A65F2B8A88A5848E97CD4471F14C6"
BASE_URL = "https://hst-api.wialon.host/wialon/ajax.html"

def login(token):
    r = requests.get(BASE_URL, params={
        "svc": "token/login",
        "params": json.dumps({"token": token})
    })
    return r.json().get("eid")

def get_items(sid, item_type, flags):
    r = requests.get(BASE_URL, params={
        "svc": "core/search_items",
        "params": json.dumps({
            "spec": {
                "itemsType": item_type,
                "propName": "sys_name",
                "propValueMask": "*",
                "sortType": "sys_name"
            },
            "force": 1,
            "flags": flags,
            "from": 0,
            "to": 0
        }),
        "sid": sid
    })
    return r.json().get("items", [])

if __name__ == "__main__":
    SID = login(TOKEN)
    units = get_items(SID, "avl_unit", 1)
    if not units:
        print("Юниты не найдены.")
    else:
        print("Список юнитов:")
        for unit in units:
            print(f"{unit['id']}: {unit['nm']}")
# Out:
# Список юнитов:
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27910469: 352 Балгожа
# 27910381: 354 Кабимулдин
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27914968: 377 CR Абдрахманов
# 27915302: 380 Садвакасов
# 27910721: 381 CR Винницкий Ф
# 27915499: 383 Карташов
# 27911208: 386 Рак
# 27915429: 387 Тургумбаев
# 27909430: 403 Шпаковский
# 28974245: 415 AQ резерв
# 28131462: 416 Сералиев
# 28132922: 419 Абдиров
# 28014920: 428 AQ Нургалиев
# 28973928: 431 резерв
# 27914966: 435 Джиоев
# 28573142: 435 резерв
# 28666651: 443 AQ Кадырбек
# 28222684: 443 СО Садовский
# 28666387: 449 Темишев
# 28666526: 451 резерв
# 28014074: 452 BJ резерв
# 27909458: 452 CR Аскеров
# 28131410: 452 Құрман
# 28246259: 453 Мусин
# 28606589: 458 Кабимулдин
# 28243616: 459 Жаирбаев
# 28973874: 460 CO Сундетбаев
# 27915589: 460 Егоров
# 28606693: 461 Барон
# 28974276: 463 CO Шубин
# 28399015: 464 Кабдрахманов
# 28011473: 465 Кайратов
# 27780244: 467 Раков
# 28405611: 468 Кулбулдин
# 28011028: 469 резерв
# 27792707: 470 Вахнина
# 28243564: 471 Калиев
# 28666496: 472 CO резерв
# 28222776: 473 Ескатов
# 28113524: 475 CO Адомайтис
# 28973541: 476 Бойко
# 28569265: 477 Сериков
# 28573545: 478 Афанасьев
# 28973983: 479 CO Синяков
# 27780000: 480 CO  Шатохин
# 27780113: 481 CO Сейдыков
# 28574085: 482 Шаткенов
# 28113464: 483 Назарбек М
# 28014385: 484 Яцынович
# 28172278: 485 CO Солдатенков
# 28974125: 486 CO Усенов
# 28606770: 495 Мукушев
# 27916518: 522 Ниязов
# 27916552: 526 CQ Лобанова
# 27919664: 529 Григоренко
# 27919718: 536 Гаврилюк
# 28574445: 586 Нургалиев
# 27916381: 639 CQ Герасимов
# 27919696: 643 CQ Жакиенов
# 27916031: 652 Глазырин
# 27919840: 654 CQ Ключка
# 27919763: 655 Нурманов
# 27940698: 659  Мальцев
# 28014203: 667 СН Куташов
# 28974156: 668 CH Бородич
# 28172244: 673 Яковлев
# 27910072: 682 Кожебаев
# 27915367: 718 резерв
# 27909082: 726 Таукин
# 27915989: 739 Коржов
# 27916171: 759 CQ Анишкевич
# 27910284: 769 Охатов
# 27916258: 780 Турежанов
# 27916107: 783 Раимкулов
# 27916084: 787  Данчев
# 27916334: 845 Сафронов
# 28015162: 847 Есентаев
# 28014649: 848 Жанатаев
# 28973854: 853 BJ Зацепин
# 28172293: 854 BJ Кабдиев
# 28974038: 855 BJ Ибраев
# 28606816: 856 Перешивкин
# 27909654: 902 Каненов
# 27911157: 908 Хасанов
# 27914983: 915 CQ Соловьев
# 27910755: 932 Баймурзинов
# 27915093: 936 Муртазин
# 27909218: 947 Жуманазаров
# 27909147: 952 CQ Гугневич
# 27915282: 956 CQ Терещенко
# 27911240: 957 Толеубек
# 27915226: 970 CQ Шульц
# 27915747: 974 Лубянецкий
# 27909272: 986 Авижич
# 27915149: 997 Кализатов
# 27909773: Дауленов 357
# 27909883: Джексембаев 353

# %%
unit_id_to_name = {unit["id"]: unit["nm"] for unit in units}

# %%
# full_names          — список ФИО
# unit_id_to_name     — словарь {unit_id: unit_name}

name_to_unit = {}

for full in full_names:
    surname = full.split()[0]                         # берём фамилию
    # ищем любой unit_name, в котором встречается фамилия
    match = next((u for u in unit_id_to_name.values() if surname in u), None)
    name_to_unit[full] = match        # будет строка unit_name или None

# name_to_unit теперь выглядит так:
# {
#     "Иванов Иван Иванович": "Unit 123 — Иванов И.И.",
#     "Петров Пётр":          None,
#     ...
# }

# Если нужен только успешно сопоставленный под‑словарь:
matched = {k: v for k, v in name_to_unit.items() if v}
unmatched = [k for k, v in name_to_unit.items() if v is None]

# %%
import pandas as pd
df = pd.read_excel("Контакты Stratera.xlsx", sheet_name="Менеджеры по продажам районы")

df = df[['ФИО', 'Область', 'Район ']]

df.columns = ['FullName', 'Region', 'District']


import re
import pandas as pd

# регулярка: делим по ", "‑если‑она‑НЕ‑внутри‑скобок
split_pat = r',\s*(?![^()]*\))'          # negative‑lookahead: после запятой
                                         # нет закрывающей скобки до следующей открытой

df = (
    df.assign(District=df['District'].str.split(split_pat, regex=True))  # список
      .explode('District')                                               # строки
      .assign(District=lambda d: d['District'].str.strip())              # подчистить пробелы
      .reset_index(drop=True)
)

# %%
df
# Out:
#                            FullName               Region           District
# 0           Барон Сергей Дмитриевич         АКМ (Астана)       Осакаровский
# 1                     Кадырбек Куат         АКМ (Астана)       Астраханский
# 2    Кайратов Батырхан Бейсенбайұлы         АКМ (Астана)       Буландынский
# 3    Кайратов Батырхан Бейсенбайұлы         АКМ (Астана)       Астраханский
# 4        Куташов Виталий Николаевич         АКМ (Астана)      Шортандинский
# ..                              ...                  ...                ...
# 138     Нургалиев Еламан Кайратович  СКО (Петропавловск)        Аккайынский
# 139     Нургалиев Еламан Кайратович  СКО (Петропавловск)  Магжана Жумабаева
# 140          Раков Валерий Игоревич  СКО (Петропавловск)      Тимирязевский
# 141   Сафронов Александр Викторович  СКО (Петропавловск)         Мамлютский
# 142                             NaN                  NaN                NaN
#
# [143 rows x 3 columns]

# %%
df = df[:-1]

# %%
matched
# Out:
# {'Барон Сергей Дмитриевич': '461 Барон',
#        'Ключка Сергей Сергеевич', 'Рак Егор Валерьевич',
#        'Садвакасов Рустам Дмитриевич', 'Сериков Бахтияр Тлекович',
#        'Турежанов Болат Агибаевич', 'Бородич Николай Михайлович',
#        'Вахнина Виктория Анатольевна', 'Карташов Олег Валерьевич',
#        'Кулбулдин Бауыржан Мубаракович', 'Мукушев Асет Кайдарович',
#        'Охатов Жанат Еленулы', 'Садовский Игорь Валерьевич',
#        'Усенов Асанали Асхатович', 'Шубин Глеб Владимирович',
#        'Шульц Николай Викторович', 'Абдрахманов Алибек Канатович',
#        'Гаврилюк Сергей Васильевич', 'Есентаев Дамир Мейрамович',
#        'Нургалиев Еламан Кайратович', 'Раков Валерий Игоревич',
#        'Сафронов Александр Викторович'], dtype=object)

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10412\3833930409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

# %%
df["Region_mapped"] = df["District"].apply(
    lambda name: reverse_mapping.get(name, None)   # вернёт value или None
)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10412\1802737178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Region_mapped"] = df["District"].apply(

# %%
df.to_csv('manager_region.csv', index=False)

# %%
df = pd.read_csv('manager_region.csv')

region_dict = (
    df.groupby('Car_numb')['Region_mapped']
    .apply(lambda x: list(set(x)))
    .to_dict()
)

# %%
pd.set_option('display.max_rows', None)
df.sort_values(by = 'Car_numb')
# Out:
#                             FullName                  Region  \
# 63        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 64        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 65        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 66        Балгожа Рауан Еркебуланулы         КСТ (Костанай)
# 134     Абдрахманов Алибек Канатович     СКО (Петропавловск)
# 133     Абдрахманов Алибек Канатович     СКО (Петропавловск)
# 132     Абдрахманов Алибек Канатович     СКО (Петропавловск)
# 113     Садвакасов Рустам Дмитриевич          ПВЛ (Павлодар)
# 121         Карташов Олег Валерьевич          СКО (Кокшетау)
# 122         Карташов Олег Валерьевич          СКО (Кокшетау)
# 112              Рак Егор Валерьевич          ПВЛ (Павлодар)
# 19        Тургумбаев Ильяс Аскарович           АКМ (Атбасар)
# 18        Тургумбаев Ильяс Аскарович           АКМ (Атбасар)
# 99         Сералиев Алишер Габитович         КСТ (Костанай)
# 100        Сералиев Алишер Габитович         КСТ (Костанай)
# 101        Сералиев Алишер Габитович         КСТ (Костанай)
# 49       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 51       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 46       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 52       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 50       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 47       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 48       Абдиров Бекбулат Кайратович         КСТ (Костанай)
# 90      Нургалиев Данияр Рамазанович         КСТ (Костанай)
# 92      Нургалиев Данияр Рамазанович         КСТ (Костанай)
# 91      Нургалиев Данияр Рамазанович         КСТ (Костанай)
# 26      Джиоев Георгий Александрович          АКМ (Кокшетау)
# 1                      Кадырбек Куат            АКМ (Астана)
# 127       Садовский Игорь Валерьевич          СКО (Кокшетау)
# 9       Темишев Нуржан Мейрамғалиұлы            АКМ (Астана)
# 6              Құрман Айдын Мұхитұлы            АКМ (Астана)
# 45             Мусин Едіге Муратович  ВКО (Усть-Каменогорск)
# 44             Мусин Едіге Муратович  ВКО (Усть-Каменогорск)
# 43             Мусин Едіге Муратович  ВКО (Усть-Каменогорск)
# 42         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 37         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 38         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 39         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 40         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 41         Кабимулдин Руфат Асетович  ВКО (Усть-Каменогорск)
# 34       Жаирбаев Даурен Беимбекович  ВКО (Усть-Каменогорск)
# 35       Жаирбаев Даурен Беимбекович  ВКО (Усть-Каменогорск)
# 36       Жаирбаев Даурен Беимбекович  ВКО (Усть-Каменогорск)
# 8      Сундетбаев Болат Муратбекович            АКМ (Астана)
# 0            Барон Сергей Дмитриевич            АКМ (Астана)
# 130          Шубин Глеб Владимирович          СКО (Кокшетау)
# 28      Кабдрахманов Асхат Канатович          АКМ (Кокшетау)
# 27      Кабдрахманов Асхат Канатович          АКМ (Кокшетау)
# 3     Кайратов Батырхан Бейсенбайұлы            АКМ (Астана)
#
# 84          Житикаринский       855 BJ Ибраев
# 83           Сарыкольский       855 BJ Ибраев
# 61       Беимбета Майлина     932 Баймурзинов
# 62         Мендыгаринский     932 Баймурзинов
# 60           Костанайский     932 Баймурзинов
# 59             Карасуский     932 Баймурзинов
# 58         Алтынсаринский     932 Баймурзинов
# 57            Федоровский     932 Баймурзинов
# 56          Карабалыкский     932 Баймурзинов
# 82          Аулиекольский     947 Жуманазаров
# 81            Федоровский     947 Жуманазаров
# 14             Жаксынский     952 CQ Гугневич
# 17            Жаркаинский    956 CQ Терещенко
# 131             Есильский        970 CQ Шульц
# 88           Узункольский      974 Лубянецкий
# 89           Сарыкольский      974 Лубянецкий
# 30              Сандыктау       997 Кализатов
# 31         Бурабай ауданы       997 Кализатов
# 108             Успенский        Дауленов 357
# 32         Шемонайхинский     Джексембаев 353
# 33           Глубоковский     Джексембаев 353
#
#                                 Region_mapped
# 63                             Денисов ауданы
# 64    Мендыкаринский район - Меңдіқара ауданы
# 65                               Арқалық Қ.Ә.
# 66                     Бейімбет Майлин ауданы
# 134                            Аққайың ауданы
# 133                           Қызылжар ауданы
# 132                             Жамбыл ауданы
# 113                           Шарбақты ауданы
# 121                            Айыртау ауданы
# 122                               Есіл ауданы
# 112                           Тереңкөл ауданы
# 19                                Есіл ауданы
# 18            Жаксынский район - Жақсы ауданы
# 99                            Қостанай ауданы
# 100   Мендыкаринский район - Меңдіқара ауданы
# 101  Алтынсаринский район - Алтынсарин ауданы
# 49   Алтынсаринский район - Алтынсарин ауданы
# 51                               Арқалық Қ.Ә.
# 46    Мендыкаринский район - Меңдіқара ауданы
# 52                            Жітіқара ауданы
# 50                              Қарасу ауданы
# 47                             Ұзынкөл ауданы
# 48                            Қостанай ауданы
# 90        Сарыкольский район - Сарыкөл ауданы
# 92      Аулиекольский район - Әулиекөл ауданы
# 91                             Ұзынкөл ауданы
# 26                           Сандықтау ауданы
# 1                             Астрахан ауданы
# 127                           Шал ақын ауданы
# 9                            Егіндікөл ауданы
# 6                               Аршалы ауданы
# 45                           Шемонаиха ауданы
# 44                          Бородулиха ауданы
# 43                          Бесқарағай ауданы
# 42                                Ұлан ауданы
# 37                               Алтай ауданы
# 38                        Катонқарағай ауданы
# 39                         Үлкен Нарын ауданы
# 40                          Бородулиха ауданы
# 41                               Самар ауданы
# 34                          Бесқарағай ауданы
# 35                          Бородулиха ауданы
# 36                            Глубокое ауданы
# 8                            Егіндікөл ауданы
# 0                             Осакаров ауданы
# 130                    Ғабит Мүсірепов ауданы
# 28                             Бурабай ауданы
# 27                          Біржан сал ауданы
# 3                             Астрахан ауданы
# 2                              Бұланды ауданы
# 140                          Тимирязев ауданы
# 123                          Уәлиханов ауданы
# 124                            Бурабай ауданы
# 120                            Тайынша ауданы
# 29                             Зеренді ауданы
# 73        Сарыкольский район - Сарыкөл ауданы
# 74                            Қостанай ауданы
# 71                             Денисов ауданы
# 69                     Бейімбет Майлин ауданы
# 72                             Қамысты ауданы
# 70   Алтынсаринский район - Алтынсарин ауданы
# 12                             Атбасар ауданы
# 107                              Успен ауданы
# 106                           Шарбақты ауданы
# 114                            Ақтоғай ауданы
# 115                              Ертіс ауданы
# 116                            Железин ауданы
# 20                            Осакаров ауданы
# 21                              Аршалы ауданы
# 16                            Жарқайың ауданы
# 23                                Абай ауданы
# 22                                Нұра ауданы
# 10                           Қорғалжын ауданы
# 7                           Целиноград ауданы
# 25                            Осакаров ауданы
# 24                         Бұқар жырау ауданы
# 129                            Зеренді ауданы
# 128                          Уәлиханов ауданы
# 125                            Аққайың ауданы
# 135                    Мағжан Жұмабаев ауданы
# 139                    Мағжан Жұмабаев ауданы
# 138                            Аққайың ауданы
# 137                           Қызылжар ауданы
# 13                                Есіл ауданы
# 75                            Қостанай ауданы
# 76      Аулиекольский район - Әулиекөл ауданы
# 77   Алтынсаринский район - Алтынсарин ауданы
# 78                           Амангелді ауданы
# 68        Сарыкольский район - Сарыкөл ауданы
# 67                              Қарасу ауданы
# 111                           Тереңкөл ауданы
# 110                            Железин ауданы
# 5                           Ерейментау ауданы
# 4                             Шортанды ауданы
# 119                    Ғабит Мүсірепов ауданы
# 11                               Ақкөл ауданы
# 105                            Ұзынкөл ауданы
# 104     Аулиекольский район - Әулиекөл ауданы
# 103                    Бейімбет Майлин ауданы
# 102                            Федоров ауданы
# 87    Мендыкаринский район - Меңдіқара ауданы
# 86                           Қарабалық ауданы
# 53                              Қарасу ауданы
# 54        Сарыкольский район - Сарыкөл ауданы
# 55   Алтынсаринский район - Алтынсарин ауданы
# 126                    Ғабит Мүсірепов ауданы
# 117                              Ақжар ауданы
# 118                          Уәлиханов ауданы
# 97                             Ұзынкөл ауданы
# 96    Мендыкаринский район - Меңдіқара ауданы
# 95                             Қамысты ауданы
# 94                            Қостанай ауданы
# 93                           Қарабалық ауданы
# 98                             Денисов ауданы
# 141                             Мамлют ауданы
# 136                           Шал ақын ауданы
# 80      Аулиекольский район - Әулиекөл ауданы
# 79                              Қарасу ауданы
# 15                            Жарқайың ауданы
# 109                           Павлодар ауданы
# 85                             Ұзынкөл ауданы
# 84                            Жітіқара ауданы
# 83        Сарыкольский район - Сарыкөл ауданы
# 61                     Бейімбет Майлин ауданы
# 62    Мендыкаринский район - Меңдіқара ауданы
# 60                            Қостанай ауданы
# 59                              Қарасу ауданы
# 58   Алтынсаринский район - Алтынсарин ауданы
# 57                             Федоров ауданы
# 56                           Қарабалық ауданы
# 82      Аулиекольский район - Әулиекөл ауданы
# 81                             Федоров ауданы
# 14            Жаксынский район - Жақсы ауданы
# 17                            Жарқайың ауданы
# 131                               Есіл ауданы
# 88                             Ұзынкөл ауданы
# 89        Сарыкольский район - Сарыкөл ауданы
# 30                           Сандықтау ауданы
# 31                             Бурабай ауданы
# 108                              Успен ауданы
# 32                           Шемонаиха ауданы
# 33                            Глубокое ауданы

# %%
df[['Car_numb', 'Region_mapped']]
# Out:
#                Car_numb                             Region_mapped
# 0             461 Барон                           Осакаров ауданы
# 1       443 AQ Кадырбек                           Астрахан ауданы
# 2          465 Кайратов                            Бұланды ауданы
# 3          465 Кайратов                           Астрахан ауданы
# 4        667 СН Куташов                           Шортанды ауданы
# 5        667 СН Куташов                         Ерейментау ауданы
# 6            452 Құрман                             Аршалы ауданы
# 7        483 Назарбек М                         Целиноград ауданы
# 8     460 CO Сундетбаев                          Егіндікөл ауданы
# 9           449 Темишев                          Егіндікөл ауданы
# 10         482 Шаткенов                          Қорғалжын ауданы
# 11          673 Яковлев                              Ақкөл ауданы
# 12     475 CO Адомайтис                            Атбасар ауданы
# 13     639 CQ Герасимов                               Есіл ауданы
# 14      952 CQ Гугневич           Жаксынский район - Жақсы ауданы
# 15       853 BJ Зацепин                           Жарқайың ауданы
# 16       479 CO Синяков                           Жарқайың ауданы
# 17     956 CQ Терещенко                           Жарқайың ауданы
# 18       387 Тургумбаев           Жаксынский район - Жақсы ауданы
# 19       387 Тургумбаев                               Есіл ауданы
# 20        478 Афанасьев                           Осакаров ауданы
# 21        478 Афанасьев                             Аршалы ауданы
# 22      481 CO Сейдыков                               Нұра ауданы
# 23      481 CO Сейдыков                               Абай ауданы
# 24   485 CO Солдатенков                        Бұқар жырау ауданы
# 25         484 Яцынович                           Осакаров ауданы
# 26           435 Джиоев                          Сандықтау ауданы
# 27     464 Кабдрахманов                         Біржан сал ауданы
# 28     464 Кабдрахманов                            Бурабай ауданы
# 29           471 Калиев                            Зеренді ауданы
# 30        997 Кализатов                          Сандықтау ауданы
# 31        997 Кализатов                            Бурабай ауданы
# 32      Джексембаев 353                          Шемонаиха ауданы
# 33      Джексембаев 353                           Глубокое ауданы
# 34         459 Жаирбаев                         Бесқарағай ауданы
# 35         459 Жаирбаев                         Бородулиха ауданы
# 36         459 Жаирбаев                           Глубокое ауданы
# 37       458 Кабимулдин                              Алтай ауданы
# 38       458 Кабимулдин                       Катонқарағай ауданы
# 39       458 Кабимулдин                        Үлкен Нарын ауданы
# 40       458 Кабимулдин                         Бородулиха ауданы
# 41       458 Кабимулдин                              Самар ауданы
# 42       458 Кабимулдин                               Ұлан ауданы
# 43            453 Мусин                         Бесқарағай ауданы
# 44            453 Мусин                         Бородулиха ауданы
# 45            453 Мусин                          Шемонаиха ауданы
# 46          419 Абдиров   Мендыкаринский район - Меңдіқара ауданы
# 47          419 Абдиров                            Ұзынкөл ауданы
# 48          419 Абдиров                           Қостанай ауданы
# 49          419 Абдиров  Алтынсаринский район - Алтынсарин ауданы
# 50          419 Абдиров                             Қарасу ауданы
# 51          419 Абдиров                              Арқалық Қ.Ә.
# 52          419 Абдиров                           Жітіқара ауданы
# 53     759 CQ Анишкевич                             Қарасу ауданы
# 54     759 CQ Анишкевич       Сарыкольский район - Сарыкөл ауданы
# 55     759 CQ Анишкевич  Алтынсаринский район - Алтынсарин ауданы
# 56      932 Баймурзинов                          Қарабалық ауданы
# 57      932 Баймурзинов                            Федоров ауданы
# 58      932 Баймурзинов  Алтынсаринский район - Алтынсарин ауданы
# 59      932 Баймурзинов                             Қарасу ауданы
# 60      932 Баймурзинов                           Қостанай ауданы
# 61      932 Баймурзинов                    Бейімбет Майлин ауданы
# 62      932 Баймурзинов   Мендыкаринский район - Меңдіқара ауданы
# 63          352 Балгожа                            Денисов ауданы
# 64          352 Балгожа   Мендыкаринский район - Меңдіқара ауданы
# 65          352 Балгожа                              Арқалық Қ.Ә.
# 66          352 Балгожа                    Бейімбет Майлин ауданы
# 67         652 Глазырин                             Қарасу ауданы
# 68         652 Глазырин       Сарыкольский район - Сарыкөл ауданы
# 69          473 Ескатов                    Бейімбет Майлин ауданы
# 70          473 Ескатов  Алтынсаринский район - Алтынсарин ауданы
# 71          473 Ескатов                            Денисов ауданы
# 72          473 Ескатов                            Қамысты ауданы
# 73          473 Ескатов       Сарыкольский район - Сарыкөл ауданы
# 74          473 Ескатов                           Қостанай ауданы
# 75      643 CQ Жакиенов                           Қостанай ауданы
# 76      643 CQ Жакиенов     Аулиекольский район - Әулиекөл ауданы
# 77      643 CQ Жакиенов  Алтынсаринский район - Алтынсарин ауданы
# 78      643 CQ Жакиенов                          Амангелді ауданы
# 79         848 Жанатаев                             Қарасу ауданы
# 80         848 Жанатаев     Аулиекольский район - Әулиекөл ауданы
# 81      947 Жуманазаров                            Федоров ауданы
# 82      947 Жуманазаров     Аулиекольский район - Әулиекөл ауданы
# 83        855 BJ Ибраев       Сарыкольский район - Сарыкөл ауданы
# 84        855 BJ Ибраев                           Жітіқара ауданы
# 85        855 BJ Ибраев                            Ұзынкөл ауданы
# 86           739 Коржов                          Қарабалық ауданы
# 87           739 Коржов   Мендыкаринский район - Меңдіқара ауданы
# 88       974 Лубянецкий                            Ұзынкөл ауданы
# 89       974 Лубянецкий       Сарыкольский район - Сарыкөл ауданы
# 90     428 AQ Нургалиев       Сарыкольский район - Сарыкөл ауданы
# 91     428 AQ Нургалиев                            Ұзынкөл ауданы
# 92     428 AQ Нургалиев     Аулиекольский район - Әулиекөл ауданы
# 93        783 Раимкулов                          Қарабалық ауданы
# 94        783 Раимкулов                           Қостанай ауданы
# 95        783 Раимкулов                            Қамысты ауданы
# 96        783 Раимкулов   Мендыкаринский район - Меңдіқара ауданы
# 97        783 Раимкулов                            Ұзынкөл ауданы
# 98        783 Раимкулов                            Денисов ауданы
# 99         416 Сералиев                           Қостанай ауданы
# 100        416 Сералиев   Мендыкаринский район - Меңдіқара ауданы
# 101        416 Сералиев  Алтынсаринский район - Алтынсарин ауданы
# 102          726 Таукин                            Федоров ауданы
# 103          726 Таукин                    Бейімбет Майлин ауданы
# 104          726 Таукин     Аулиекольский район - Әулиекөл ауданы
# 105          726 Таукин                            Ұзынкөл ауданы
# 106           476 Бойко                           Шарбақты ауданы
# 107           476 Бойко                              Успен ауданы
# 108        Дауленов 357                              Успен ауданы
# 109      854 BJ Кабдиев                           Павлодар ауданы
# 110       654 CQ Ключка                            Железин ауданы
# 111       654 CQ Ключка                           Тереңкөл ауданы
# 112             386 Рак                           Тереңкөл ауданы
# 113      380 Садвакасов                           Шарбақты ауданы
# 114         477 Сериков                            Ақтоғай ауданы
# 115         477 Сериков                              Ертіс ауданы
# 116         477 Сериков                            Железин ауданы
# 117       780 Турежанов                              Ақжар ауданы
# 118       780 Турежанов                          Уәлиханов ауданы
# 119      668 CH Бородич                    Ғабит Мүсірепов ауданы
# 120         470 Вахнина                            Тайынша ауданы
# 121        383 Карташов                            Айыртау ауданы
# 122        383 Карташов                               Есіл ауданы
# 123       468 Кулбулдин                          Уәлиханов ауданы
# 124       468 Кулбулдин                            Бурабай ауданы
# 125         495 Мукушев                            Аққайың ауданы
# 126          769 Охатов                    Ғабит Мүсірепов ауданы
# 127    443 СО Садовский                           Шал ақын ауданы
# 128       486 CO Усенов                          Уәлиханов ауданы
# 129       486 CO Усенов                            Зеренді ауданы
# 130        463 CO Шубин                    Ғабит Мүсірепов ауданы
# 131        970 CQ Шульц                               Есіл ауданы
# 132  377 CR Абдрахманов                             Жамбыл ауданы
# 133  377 CR Абдрахманов                           Қызылжар ауданы
# 134  377 CR Абдрахманов                            Аққайың ауданы
# 135        536 Гаврилюк                    Мағжан Жұмабаев ауданы
# 136        847 Есентаев                           Шал ақын ауданы
# 137       586 Нургалиев                           Қызылжар ауданы
# 138       586 Нургалиев                            Аққайың ауданы
# 139       586 Нургалиев                    Мағжан Жұмабаев ауданы
# 140           467 Раков                          Тимирязев ауданы
# 141        845 Сафронов                             Мамлют ауданы

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

df["Region_mapped"] = df["District"].apply(
    lambda name: reverse_mapping.get(name, None)   # вернёт value или None
)

# %%
# Извлекаем фамилии из ФИО
known_surnames = set(name.split()[0] for name in full_names)

# Юниты, у которых не найдена фамилия в списке
not_matched_units = {}

for unit_id, unit_name in unit_id_to_name.items():
    found = False
    for surname in known_surnames:
        if surname in unit_name:
            found = True
            break
    if not found:
        not_matched_units[unit_id] = unit_name

# Результат
print(f"❌ Юниты без совпадений по фамилии: {len(not_matched_units)}")
for uid, uname in not_matched_units.items():
    print(f"{uid}: {uname}")
# Out:
# ❌ Юниты без совпадений по фамилии: 31
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27910721: 381 CR Винницкий Ф
# 27909430: 403 Шпаковский
# 28974245: 415 AQ резерв
# 28973928: 431 резерв
# 28573142: 435 резерв
# 28666526: 451 резерв
# 28014074: 452 BJ резерв
# 27909458: 452 CR Аскеров
# 27915589: 460 Егоров
# 28011028: 469 резерв
# 28666496: 472 CO резерв
# 27916518: 522 Ниязов
# 27916552: 526 CQ Лобанова
# 27919664: 529 Григоренко
# 27919763: 655 Нурманов
# 27940698: 659  Мальцев
# 27910072: 682 Кожебаев
# 27915367: 718 резерв
# 27916084: 787  Данчев
# 28606816: 856 Перешивкин
# 27909654: 902 Каненов
# 27911157: 908 Хасанов
# 27914983: 915 CQ Соловьев
# 27915093: 936 Муртазин
# 27911240: 957 Толеубек
# 27909272: 986 Авижич
