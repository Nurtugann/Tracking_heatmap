# %%
import geopandas as gpd

# Замените на путь к вашему файлу
geojson_path = "OSMB-f1ec2d0019a5c0c4984f489cdc13d5d26a7949fd.geojson"

# Чтение GeoJSON
gdf = gpd.read_file(geojson_path)

# Посмотрим на доступные столбцы
print("Доступные столбцы:", gdf.columns)

# Если там есть столбец с названием региона, например 'name' или 'region', выведем уникальные значения
if 'name' in gdf.columns:
    print("Найденные регионы:")
    print(gdf['name'].unique())
elif 'region' in gdf.columns:
    print("Найденные регионы:")
    print(gdf['region'].unique())
else:
    print("Не удалось найти подходящий столбец с названием региона.")
# Out:
# Доступные столбцы: Index(['osm_id', 'name', 'name_en', 'boundary', 'admin_level',
#        'admin_centre_node_id', 'admin_centre_node_lat',
#        'admin_centre_node_lng', 'label_node_id', 'label_node_lat',
#        'label_node_lng', 'geometry'],
#       dtype='object')
# Найденные регионы:
# ['Марқакөл ауданы' 'Қосшы қалалық әкімдігі' 'Самар ауданы'
#  'Қарқаралы ауданы' 'Нұра ауданы' 'Осакаров ауданы' 'Абай ауданы'
#  'Бұқар жырау ауданы' 'Екібастұз Қ.Ә.' 'Шарбақты ауданы' 'Успен ауданы'
#  'Ақсу Қ.Ә.' 'Павлодар ауданы' 'Ертіс ауданы' 'Ақтоғай ауданы'
#  'Курчатов қалалық әкімшілігі' 'Степногорск Қ.Ә.' 'Сандықтау ауданы'
#  'Бұланды ауданы' 'Бурабай ауданы' 'Біржан сал ауданы' 'Ерейментау ауданы'
#  'Целиноград ауданы' 'Егіндікөл ауданы' 'Астрахан ауданы'
#  'Жарқайың ауданы' 'Атбасар ауданы' 'Жаксынский район - Жақсы ауданы'
#  'Зеренді ауданы' 'Ақкөл ауданы' 'Есіл ауданы' 'Шемонаиха ауданы'
#  'Ұлан ауданы' 'Тарбағатай ауданы' 'Көкпекті ауданы' 'Катонқарағай ауданы'
# ...

# %%
"""Аккольский
Аршалынский
Аршалынский
Астраханский 
Буландынский, Астраханский 
Егиндыкольский 
Егиндыкольский 
Коргалжынский 
Осакаровский 
Целиноградский 
Шортандинский, Ерейментауский
Атбасарский 
Атбасарский 
Есильский 
Жаксынский
Жаксынский, Есильский 
Жаркаинский 
Жаркаинский 
Жаркаинский 
Абайский
Бухар жырауский
Нуринский
Осакаровский район
Осакаровский район
Биржан Сал
Зерендинский
Сандыктау
Сандыктау, Бурабай ауданы
Алтай, Катон Карагай, Улкен нарын, Бородулихинский, Самарский
Бескарагайский, Бородулихинский, Шемонайхинский
Бесқарағайский и Бородулихинский
Шемонайхинский, Глубоковский
Шемонайхинский, Глубоковский
Беимбета Майлина, Алтынсаринский
Денисовский, Житикаринский, Камыстинский
Денисовский, Карасуский, Мендыгаринский, Аркалыкский, Тарановский
Камыстинский, Житикаринский, Денисовский, Беимбета Майлина
Карабалыкский район, Мендыкаринский ( Алешинский сельский округ)
Карабалыкский, Костанайский, Камыстинский, Мендыкаринский
Карабалыкский, Федоровский, Алтынсаринский, Карасуский, Костанайский
Карасуский район
Карасуский,  Аулиекольский
Карасуский,Сарыкольский, Алтынсаринский
Костанайский
Костанайский, Мендыгаринский 
Мендыгаринский, Сарыкольский, Узынкольский, Костанайский, Алтынсаринский, Карасу, г.Аркалык
Сарыкольский , Узункольский
Сарыкольский, Житикаринский, Узункольский
Узункольский, Сарыкольский
Федоровский, Аулекольский
Федоровский, Тарановский,  Ауликольский, Узункольский
Актогайский, Иртышский
Железинский
Павлодарская область
Теренкольский
Успенский
Шарбактинский
Щербакты, Успенка
Акжарский, Уалихановский
Айыртауский, Есильский
Аккайынский
Г.Мусрепова
Г.Мусрепова
Г.Мусрепова
Есильский
Тайыншинский
Уалихановский
Уалихановский
Шал Акына
Жамбылский
Кызылжарский, Аккайынский
Мамлютский 
Тимирязевский
Тимирязевский, Шал Акына
Шал Акына
р-н Магжана Жумабаева"""

# %%
russian_to_geojson_sorted = {
    "Абайский": "Абай ауданы",
    "Айыртауский": "Айыртау ауданы",
    "Акжарский": "Ақжар ауданы",
    "Аккайынский": "Аққайың ауданы",
    "Аккольский": "Ақкөл ауданы",
    "Аккулинский": "Аққулы ауданы",
    "Алтайский": "Алтай ауданы",
    "Алтай": "Алтай ауданы",
    "Алтынсаринский": "Алтынсаринский район - Алтынсарин ауданы",
    "Амангельдинский": "Амангелді ауданы",
    "Аркалык": "Арқалық Қ.Ә.",
    "г.Аркалык": "Арқалық Қ.Ә.",
    "Аркалыкский": "Арқалық Қ.Ә.",
    "Аршалынский": "Аршалы ауданы",
    "Астраханский": "Астрахан ауданы",
    "Атбасарский": "Атбасар ауданы",
    "Аулиекольский": "Аулиекольский район - Әулиекөл ауданы",
    "Аулекольский": "Аулиекольский район - Әулиекөл ауданы",
    "Ауликольский": "Аулиекольский район - Әулиекөл ауданы",
    "Аягозский": "Аягөз ауданы",
    "Баянаульский": "Баянауыл ауданы",
    "Биржан Сал": "Біржан сал ауданы",
    "Бескарагайский": "Бесқарағай ауданы",
    "Бесқарағайский": "Бесқарағай ауданы",
    "Бородулихинский": "Бородулиха ауданы",
    "Буландынский": "Бұланды ауданы",
    "Бухар жырауский": "Бұқар жырау ауданы",
    "Бурабайский": "Бурабай ауданы",
    "Глубоковский": "Глубокое ауданы",
    "Денисовский": "Денисов ауданы",
    "Егиндыкольский": "Егіндікөл ауданы",
    "Ерейментауский": "Ерейментау ауданы",
    "Есильский": "Есіл ауданы",
    "Жаксынский": "Жаксынский район - Жақсы ауданы",
    "Жамбылский": "Жамбыл ауданы",
    "Жаркаинский": "Жарқайың ауданы",
    "Жарминский": "Жарма ауданы",
    "Железинский": "Железин ауданы",
    "Житикаринский": "Жітіқара ауданы",
    "Зерендинский": "Зеренді ауданы",
    "Камыстинский": "Қамысты ауданы",
    "Катон-Карагайский": "Катонқарағай ауданы",
    "Катон-Карагай": "Катонқарағай ауданы",
    "Карабалыкский": "Қарабалық ауданы",
    "Карагандинский": "Қарағанды Қ.Ә.",
    "Карасуский": "Қарасу ауданы",
    "Карасуский район": "Қарасу ауданы",
    "Коргалжынский": "Қорғалжын ауданы",
    "Курчумский": "Күршім ауданы",
    "Кокпектинский": "Көкпекті ауданы",
    "Кокшетауский": "Көкшетау Қ.Ә.",
    "Костанайский": "Қостанай ауданы",
    "Кызылжарский": "Қызылжар ауданы",
    "Лисаковск": "Лисаковск Қ.Ә.",
    "Майлинский": "Бейімбет Майлин ауданы",
    "Беимбета Майлина": "Бейімбет Майлин ауданы",
    "Майский": "Май ауданы",
    "Мамлютский": "Мамлют ауданы",
    "Мендыгаринский": "Мендыкаринский район - Меңдіқара ауданы",
    "Мендыкаринский": "Мендыкаринский район - Меңдіқара ауданы",
    "Мендыкаринский ( Алешинский сельский округ)": "Мендыкаринский район - Меңдіқара ауданы",
    "Мусрепова": "Ғабит Мүсірепов ауданы",
    "Г.Мусрепова": "Ғабит Мүсірепов ауданы",
    "Наурзумский": "Наурзумский район - Наурызым ауданы",
    "Осакаровский": "Осакаров ауданы",
    "Павлодарский": "Павлодар Қ.Ә.",
    "Павлодарская область": "Павлодар ауданы",
    "Петропавловск": "Петропавл қ.а.",
    "Риддер": "Риддер қалалық әкімдігі",
    "Рудный": "Рудный Қ.Ә.",
    "Сандыктау": "Сандықтау ауданы",
    "Сарыкольский": "Сарыкольский район - Сарыкөл ауданы",
    "Семей": "Семей қалалық әкімшілігі",
    "Темиртауский": "Теміртау Қ.Ә.",
    "Тайыншинский": "Тайынша ауданы",
    "Теренкольский": "Тереңкөл ауданы",
    "Тимирязевский": "Тимирязев ауданы",
    "Уалихановский": "Уәлиханов ауданы",
    "Узункольский": "Ұзынкөл ауданы",
    "Узынкольский": "Ұзынкөл ауданы",
    "Уланский": "Ұлан ауданы",
    "Усть-Каменогорск": "Өскемен қ.ә.",
    "Федоровский": "Федоров ауданы",
    "Шал Акына": "Шал ақын ауданы",
    "Шахтинский": "Шахтинск Қ.Ә.",
    "Шемонайхинский": "Шемонаиха ауданы",
    "Шортандинский": "Шортанды ауданы"
}

# Целиноградский 
# Нуринский
# Улкен Нарын
# Самарский
# Тарановский
# Актогайский, Иртышский
# Успенский
# Шарбактинский
# Щербакты, Успенка
# р-н Магжана Жумабаева

# %%
full_names = [
    "Барон Сергей Дмитриевич",
    "Бугаев Никита Сергеевич",
    "Кадырбек Куат",
    "Кайратов Батырхан Бейсенбайұлы",
    "Құрман Айдын Мұхитұлы",
    "Куташов Виталий Николаевич",
    "Назарбек Мәди Мейрамбекұлы",
    "Сундетбаев Болат Муратбекович",
    "Темишев Нуржан Мейрамғалиұлы",
    "Шаткенов Арлан Нурдаулетович",
    "Яковлев Александр Александрович",
    "Адомайтис Евгений Валерьевич",
    "Герасимов Виталий Валерьевич",
    "Гугневич Евгений Павлович",
    "Зацепин Алексей Иванович",
    "Максимов Станислав Валерьевич",
    "Синяков Валерий Викторович",
    "Терещенко Александр Григорьевич",
    "Тургумбаев Ильяс Аскарович",
    "Афанасьев Павел Павлович",
    "Сейдыков Максим Евгеньевич",
    "Солдатенков Артем Викторович",
    "Шатохин Дмитрий Александрович",
    "Яцынович Константин Юрьевич",
    "Джиоев Георгий Александрович",
    "Кабдрахманов Асхат Канатович",
    "Калиев Жанибек Омарович",
    "Кализатов Бауыржан Канатович",
    "Джексембаев Ринат Каденович",
    "Жаирбаев Даурен Беимбекович",
    "Кабимулдин Руфат Асетович",
    "Клиновицкий Андрей Александрович",
    "Мусин Едіге Муратович",
    "Абдиров Бекбулат Кайратович",
    "Әмірбек Жанибек Адильбекович",
    "Анишкевич Владислав Сергеевич",
    "Баймурзинов Рустем Муратович",
    "Балгожа Рауан Еркебуланулы",
    "Глазырин Вячеслав Александрович",
    "Ескатов Алишер Маратович",
    "Жакиенов Данияр Берикович",
    "Жанатаев Нияз Маликович",
    "Жуманазаров Азамат Габитович",
    "Ибраев Акежан Аулиханович",
    "Коржов Дмитрий Александрович",
    "Қойгелді Женіс Даулетұлы",
    "Лубянецкий Алексей Петрович",
    "Нургалиев Данияр Рамазанович",
    "Раимкулов Олжас Адыльбекович",
    "Сералиев Алишер Габитович",
    "Таукин Канат Аблаевич",
    "Бойко Олег Игоревич",
    "Дауленов Азамат Айтжанович",
    "Кабдиев Болатбек Рымханович",
    "Ключка Сергей Сергеевич",
    "Рак Егор Валерьевич",
    "Садвакасов Рустам Дмитриевич",
    "Сериков Бахтияр Тлекович",
    "Гаврилюк Сергей Васильевич",
    "Бородич Николай Михайлович",
    "Вахнина Виктория Анатольевна",
    "Карташов Олег Валерьевич",
    "Кулбулдин Бауыржан Мубаракович",
    "Мукушев Асет Кайдарович",
    "Охатов Жанат Еленулы",
    "Садовский Игорь Валерьевич",
    "Турежанов Болат Агибаевич",
    "Усенов Асанали Асхатович",
    "Шубин Глеб Владимирович",
    "Шульц Николай Викторович",
    "Абдрахманов Алибек Канатович",
    "Есентаев Дамир Мейрамович",
    "Нургалиев Еламан Кайратович",
    "Раков Валерий Игоревич",
    "Сафронов Александр Викторович",
    "Шадрин Виталий Вячеславович"
]

# %%
import requests
import json

TOKEN = "c611c2bab48335e36a4b59be460c57d2DC99601D0C49777B24DFE07B7614A2826A62C393"
BASE_URL = "https://hst-api.wialon.host/wialon/ajax.html"

def login(token):
    r = requests.get(BASE_URL, params={
        "svc": "token/login",
        "params": json.dumps({"token": token})
    })
    return r.json().get("eid")

def get_items(sid, item_type, flags):
    r = requests.get(BASE_URL, params={
        "svc": "core/search_items",
        "params": json.dumps({
            "spec": {
                "itemsType": item_type,
                "propName": "sys_name",
                "propValueMask": "*",
                "sortType": "sys_name"
            },
            "force": 1,
            "flags": flags,
            "from": 0,
            "to": 0
        }),
        "sid": sid
    })
    return r.json().get("items", [])

if __name__ == "__main__":
    SID = login(TOKEN)
    units = get_items(SID, "avl_unit", 1)
    if not units:
        print("Юниты не найдены.")
    else:
        print("Список юнитов:")
        for unit in units:
            print(f"{unit['id']}: {unit['nm']}")
# Out:
# Список юнитов:
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27910469: 352 Балгожа
# 27910381: 354 Кабимулдин
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27914968: 377 CR Абдрахманов
# 27915302: 380 Садвакасов
# 27910721: 381 CR Винницкий Ф
# 27915499: 383 Карташов
# 27911208: 386 Рак
# 27915429: 387 Тургумбаев
# 27909430: 403 Шпаковский
# 28974245: 415 AQ Әмірбек
# 28131462: 416 Сералиев
# 28132922: 419 Абдиров
# 28014920: 428 AQ Нургалиев
# 28973928: 431 Шадрин
# 27914966: 435 Джиоев
# 28573142: 435 резерв
# 28666651: 443 AQ Кадырбек
# 28222684: 443 СО Садовский
# 28666387: 449 Темишев
# 28666526: 451 Бугаев
# 28014074: 452 BJ Сериков
# 27909458: 452 CR Аскеров
# 28131410: 452 Құрман
# 28246259: 453 Мусин
# 28606589: 458 Кабимулдин
# 28243616: 459 Жаирбаев
# 28973874: 460 CO Сундетбаев
# 27915589: 460 Егоров
# 28606693: 461 Барон
# 28974276: 463 CO Шубин
# 28399015: 464 Кабдрахманов
# 28011473: 465 Кайратов
# ...

# %%
unit_id_to_name = {unit["id"]: unit["nm"] for unit in units}

# %%
# full_names          — список ФИО
# unit_id_to_name     — словарь {unit_id: unit_name}

name_to_unit = {}

for full in full_names:
    surname = full.split()[0]                         # берём фамилию
    # ищем любой unit_name, в котором встречается фамилия
    match = next((u for u in unit_id_to_name.values() if surname in u), None)
    name_to_unit[full] = match        # будет строка unit_name или None

# name_to_unit теперь выглядит так:
# {
#     "Иванов Иван Иванович": "Unit 123 — Иванов И.И.",
#     "Петров Пётр":          None,
#     ...
# }

# Если нужен только успешно сопоставленный под‑словарь:
matched = {k: v for k, v in name_to_unit.items() if v}
unmatched = [k for k, v in name_to_unit.items() if v is None]

# %%
import pandas as pd
df = pd.read_excel("Контакты Stratera (2).xlsx", sheet_name="Менеджеры по продажам районы")


df.drop(['Должность', 'Стаж работы', 'Телефон', '№'], inplace=True, axis=1)
df.columns = ['FullName', 'Region', 'District']


import re
import pandas as pd

# регулярка: делим по ", "‑если‑она‑НЕ‑внутри‑скобок
split_pat = r',\s*(?![^()]*\))'          # negative‑lookahead: после запятой
                                         # нет закрывающей скобки до следующей открытой

df = (
    df.assign(District=df['District'].str.split(split_pat, regex=True))  # список
      .explode('District')                                               # строки
      .assign(District=lambda d: d['District'].str.strip())              # подчистить пробелы
      .reset_index(drop=True)
)

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

df["Region_mapped"] = df["District"].apply(
    lambda name: russian_to_geojson_sorted.get(name, None)   # вернёт value или None
)

# %%
df.to_csv('manager_region.csv', index=False)

# %%
df = pd.read_csv('manager_region.csv')

region_dict = (
    df.groupby('Car_numb')['Region_mapped']
    .apply(lambda x: list(set(x)))
    .to_dict()
)

# %%
region_dict
# Out:
# {'352 Балгожа': ['Қарасу ауданы', nan, 'Денисов ауданы'],
#  '354 Кабимулдин': [nan, 'Бородулиха ауданы'],
#  '377 CR Абдрахманов': ['Жамбыл ауданы'],
#  '380 Садвакасов': [nan],
#  '383 Карташов': ['Есіл ауданы', 'Айыртау ауданы'],
#  '386 Рак': ['Тереңкөл ауданы'],
#  '387 Тургумбаев': ['Есіл ауданы', 'Жаксынский район - Жақсы ауданы'],
#  '415 AQ Әмірбек': ['Жітіқара ауданы', 'Денисов ауданы', 'Қамысты ауданы'],
#  '416 Сералиев': ['Қостанай ауданы', nan],
#  '419 Абдиров': ['Қостанай ауданы',
#   'Сарыкольский район - Сарыкөл ауданы',
#   nan,
#   'Алтынсаринский район - Алтынсарин ауданы'],
#  '428 AQ Нургалиев': ['Аққайың ауданы',
#   'Сарыкольский район - Сарыкөл ауданы',
#   'Қызылжар ауданы',
#   'Ұзынкөл ауданы'],
#  '431 Шадрин': ['Шал ақын ауданы', 'Тимирязев ауданы'],
#  '435 Джиоев': ['Сандықтау ауданы'],
#  '443 AQ Кадырбек': ['Астрахан ауданы'],
#  '443 СО Садовский': ['Шал ақын ауданы'],
#  '449 Темишев': ['Егіндікөл ауданы'],
#  '451 Бугаев': ['Аршалы ауданы'],
# ...

# %%
pd.set_option('display.max_rows', None)
df.sort_values(by = 'Car_numb')
# Out:
#                              FullName                         Region  \
# 35         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 36         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 37         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 38         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 39         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 13          Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 12          Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 11          Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 9           Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 10          Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 47       Абдрахманов Алибек Канатович            СКО (Петропавловск)
# 121      Садвакасов Рустам Дмитриевич                 ПВЛ (Павлодар)
# 2            Карташов Олег Валерьевич                 СКО (Кокшетау)
# ...

# %%
df[['Car_numb', 'Region_mapped']]
# Out:
# {'Car_numb': {0: '480 CO  Шатохин',
#   1: '383 Карташов',
#   2: '383 Карташов',
#   3: '780 Турежанов',
#   4: '780 Турежанов',
#   5: '495 Мукушев',
#   6: '673 Яковлев',
#   7: '452 BJ Сериков',
#   8: '452 BJ Сериков',
#   9: '354 Кабимулдин',
#   10: '354 Кабимулдин',
#   11: '354 Кабимулдин',
#   12: '354 Кабимулдин',
#   13: '354 Кабимулдин',
#   14: '451 Бугаев',
#   15: '452 Құрман',
#   16: '443 AQ Кадырбек',
#   17: '475 CO Адомайтис',
#   18: '469 Максимов',
#   19: '473 Ескатов',
#   20: '473 Ескатов',
#   21: '453 Мусин',
#   22: '453 Мусин',
#   23: '453 Мусин',
#   24: '459 Жаирбаев',
#   25: '464 Кабдрахманов',
#   26: '465 Кайратов',
#   27: '465 Кайратов',
#   28: '485 CO Солдатенков',
#   29: '668 CH Бородич',
#   30: '769 Охатов',
#   31: '463 CO Шубин',
#   32: '415 AQ Әмірбек',
#   33: '415 AQ Әмірбек',
#   34: '415 AQ Әмірбек',
#   35: '352 Балгожа',
#   36: '352 Балгожа',
#   37: '352 Балгожа',
#   38: '352 Балгожа',
#   39: '352 Балгожа',
# ...

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

df["Region_mapped"] = df["District"].apply(
    lambda name: russian_to_geojson_sorted.get(name, None)   # вернёт value или None
)

# %%
# Извлекаем фамилии из ФИО
known_surnames = set(name.split()[0] for name in full_names)

# Юниты, у которых не найдена фамилия в списке
not_matched_units = {}

for unit_id, unit_name in unit_id_to_name.items():
    found = False
    for surname in known_surnames:
        if surname in unit_name:
            found = True
            break
    if not found:
        not_matched_units[unit_id] = unit_name

# Результат
print(f"❌ Юниты без совпадений по фамилии: {len(not_matched_units)}")
for uid, uname in not_matched_units.items():
    print(f"{uid}: {uname}")
# Out:
# ❌ Юниты без совпадений по фамилии: 25
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27910721: 381 CR Винницкий Ф
# 27909430: 403 Шпаковский
# 28573142: 435 резерв
# 27909458: 452 CR Аскеров
# 27915589: 460 Егоров
# 27916518: 522 Ниязов
# 27916552: 526 CQ Лобанова
# 27919664: 529 Григоренко
# 27919763: 655 Нурманов
# 27940698: 659  Мальцев
# 27910072: 682 Кожебаев
# 27915367: 718 резерв
# 27916084: 787  Данчев
# 28606816: 856 Перешивкин
# 27909654: 902 Каненов
# 27911157: 908 Хасанов
# 27914983: 915 CQ Соловьев
# 27915093: 936 Муртазин
# 27911240: 957 Толеубек
# 27909272: 986 Авижич
