# %%
import geopandas as gpd
import numpy as np
# Замените на путь к вашему файлу
geojson_path = "OSMB-f1ec2d0019a5c0c4984f489cdc13d5d26a7949fd.geojson"

# Чтение GeoJSON
gdf = gpd.read_file(geojson_path)

# Посмотрим на доступные столбцы
print("Доступные столбцы:", gdf.columns)
# Out:
# Доступные столбцы: Index(['osm_id', 'name', 'name_en', 'boundary', 'admin_level',
#        'admin_centre_node_id', 'admin_centre_node_lat',
#        'admin_centre_node_lng', 'label_node_id', 'label_node_lat',
#        'label_node_lng', 'geometry'],
#       dtype='object')

# %%
# Если там есть столбец с названием региона, например 'name' или 'region', выведем уникальные значения
if 'name' in gdf.columns:
    print("Найденные регионы:")
    a = np.sort(gdf['name'].unique())
    [print(i) for i in a]
elif 'region' in gdf.columns:
    print("Найденные регионы:")
    a = np.sort(gdf['region'].unique())
    [print(i) for i in a]
else:
    print("Не удалось найти подходящий столбец с названием региона.")
# Out:
# Найденные регионы:
# Абай ауданы
# Айыртау ауданы
# Алтай ауданы
# Алтынсаринский район - Алтынсарин ауданы
# Амангелді ауданы
# Аршалы ауданы
# Арқалық Қ.Ә.
# Астана
# Астрахан ауданы
# Атбасар ауданы
# Аулиекольский район - Әулиекөл ауданы
# Аягөз ауданы
# Ақжар ауданы
# Ақкөл ауданы
# Ақсу Қ.Ә.
# Ақсуат ауданы
# Ақтоғай ауданы
# Аққайың ауданы
# Аққулы ауданы
# Баянауыл ауданы
# Бейімбет Майлин ауданы
# Бесқарағай ауданы
# Бородулиха ауданы
# Бурабай ауданы
# Біржан сал ауданы
# Бұланды ауданы
# Бұқар жырау ауданы
# Глубокое ауданы
# Денисов ауданы
# Егіндікөл ауданы
# Екібастұз Қ.Ә.
# Ерейментау ауданы
# Ертіс ауданы
# Есіл ауданы
# Жаксынский район - Жақсы ауданы
# Жамбыл ауданы
# Жангелдин ауданы
# Жарма ауданы
# Жарқайың ауданы
# Жаңасемей ауданы
# Железин ауданы
# Жітіқара ауданы
# Зеренді ауданы
# Катонқарағай ауданы
# Курчатов қалалық әкімшілігі
# Күршім ауданы
# Көкпекті ауданы
# Көкшетау Қ.Ә.
# Лисаковск Қ.Ә.
# Май ауданы
# Мамлют ауданы
# Марқакөл ауданы
# Мағжан Жұмабаев ауданы
# Мендыкаринский район - Меңдіқара ауданы
# Наурзумский район - Наурызым ауданы
# Нұра ауданы
# Осакаров ауданы
# Павлодар ауданы
# Павлодар Қ.Ә.
# Петропавл қ.а.
# Риддер қалалық әкімдігі
# Рудный Қ.Ә.
# Самар ауданы
# Сандықтау ауданы
# Саран Қ.Ә.
# Сарыкольский район - Сарыкөл ауданы
# Семей қалалық әкімшілігі
# Степногорск Қ.Ә.
# Тайынша ауданы
# Тарбағатай ауданы
# Теміртау Қ.Ә.
# Тереңкөл ауданы
# Тимирязев ауданы
# Успен ауданы
# Уәлиханов ауданы
# Федоров ауданы
# Целиноград ауданы
# Шал ақын ауданы
# Шарбақты ауданы
# Шахтинск Қ.Ә.
# Шемонаиха ауданы
# Шортанды ауданы
# Ғабит Мүсірепов ауданы
# Қамысты ауданы
# Қарабалық ауданы
# Қарасу ауданы
# Қарағанды Қ.Ә.
# Қарқаралы ауданы
# Қорғалжын ауданы
# Қостанай ауданы
# Қостанай Қ.Ә.
# Қосшы қалалық әкімдігі
# Қызылжар ауданы
# Үлкен Нарын ауданы
# Ұзынкөл ауданы
# Ұлан ауданы
# Өскемен қ.ә.

# %%
reverse_mapping = {
    "Абайский": "Абай ауданы",
    "Айыртауский": "Айыртау ауданы",
    "Есильский": "Есіл ауданы",
    "Акжарский": "Ақжар ауданы",
    "Уалихановский": "Уәлиханов ауданы",
    "Аккайынский": "Аққайың ауданы",
    "Аккольский": "Ақкөл ауданы",
    "Актогайский": "Ақтоғай ауданы",
    "Иртышский": "Ертіс ауданы",
    "Алтай": "Алтай ауданы",
    "Катон Карагай": "Катонқарағай ауданы",
    "Улкен Нарын": "Үлкен Нарын ауданы",
    "Бородулихинский": "Бородулиха ауданы",
    "Самарский": "Самар ауданы",
    "Аршалынский": "Аршалы ауданы",
    "Астраханский": "Астрахан ауданы",
    "Атбасарский": "Атбасар ауданы",
    "Беимбета Майлина": "Бейімбет Майлин ауданы",
    "Алтынсаринский": "Алтынсаринский район - Алтынсарин ауданы",
    "Бескарагайский": "Бесқарағай ауданы",
    "Шемонайхинский": "Шемонаиха ауданы",
    "Биржан Сал": "Біржан сал ауданы",
    "Буландынский": "Бұланды ауданы",
    "Бухар жырауский": "Бұқар жырау ауданы",
    "Г.Мусрепова": "Ғабит Мүсірепов ауданы",
    "Денисовский": "Денисов ауданы",
    "Житикаринский": "Жітіқара ауданы",
    "Камыстинский": "Қамысты ауданы",
    "Карасуский": "Қарасу ауданы",
    "Карасу": "Қарасу ауданы",
    "Мендыгаринский": "Мендыкаринский район - Меңдіқара ауданы",
    "Аркалыкский": "Арқалық Қ.Ә.",
    "Тарановский": "Бейімбет Майлин ауданы",
    "Егиндыкольский": "Егіндікөл ауданы",
    "Жаксынский": "Жаксынский район - Жақсы ауданы",
    "Жамбылский": "Жамбыл ауданы",
    "Жаркаинский": "Жарқайың ауданы",
    "Железинский": "Железин ауданы",
    "Зерендинский": "Зеренді ауданы",
    "Карабалыкский": "Қарабалық ауданы",
    "Костанайский": "Қостанай ауданы",
    "Коргалжынский": "Қорғалжын ауданы",
    "Кызылжарский": "Қызылжар ауданы",
    "Магжана Жумабаева": "Мағжан Жұмабаев ауданы",
    "Мамлютский": "Мамлют ауданы",
    "Сарыкольский": "Сарыкольский район - Сарыкөл ауданы",
    "Узункольский": "Ұзынкөл ауданы",
    "Нуринский": "Нұра ауданы",
    "Осакаровский": "Осакаров ауданы",
    "Павлодарская область": "Павлодар ауданы",
    "Сандыктау": "Сандықтау ауданы",
    "Бурабай ауданы": "Бурабай ауданы",
    "Тайыншинский": "Тайынша ауданы",
    "Теренкольский": "Тереңкөл ауданы",
    "Тимирязевский": "Тимирязев ауданы",
    "Шал Акына": "Шал ақын ауданы",
    "Шарбактинский": "Шарбақты ауданы",
    "Успенский": "Успен ауданы",
    "Целиноградский": "Целиноград ауданы",
    "Глубоковский": "Глубокое ауданы",
    "Шортандинский": "Шортанды ауданы",
    "Ерейментауский": "Ерейментау ауданы",
    "Аулиекольский": "Аулиекольский район - Әулиекөл ауданы",
    "Мендыкаринский": "Мендыкаринский район - Меңдіқара ауданы",
    "
    "Нургалиев Еламан Кайратович",
    "Раков Валерий Игоревич",
    "Сафронов Александр Викторович",
    "Шадрин Виталий Вячеславович"
]

# %%
import requests
import json

TOKEN = "c611c2bab48335e36a4b59be460c57d2DC99601D0C49777B24DFE07B7614A2826A62C393"
BASE_URL = "https://hst-api.wialon.host/wialon/ajax.html"

def login(token):
    r = requests.get(BASE_URL, params={
        "svc": "token/login",
        "params": json.dumps({"token": token})
    })
    return r.json().get("eid")

def get_items(sid, item_type, flags):
    r = requests.get(BASE_URL, params={
        "svc": "core/search_items",
        "params": json.dumps({
            "spec": {
                "itemsType": item_type,
                "propName": "sys_name",
                "propValueMask": "*",
                "sortType": "sys_name"
            },
            "force": 1,
            "flags": flags,
            "from": 0,
            "to": 0
        }),
        "sid": sid
    })
    return r.json().get("items", [])

if __name__ == "__main__":
    SID = login(TOKEN)
    units = get_items(SID, "avl_unit", 1)
    if not units:
        print("Юниты не найдены.")
    else:
        print("Список юнитов:")
        for unit in units:
            print(f"{unit['id']}: {unit['nm']}")
# Out:
# Список юнитов:
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27910469: 352 Балгожа
# 27910381: 354 Кабимулдин
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27914968: 377 CR Абдрахманов
# 27915302: 380 Садвакасов
# 27910721: 381 CR Винницкий Ф
# 27915499: 383 Карташов
# 27911208: 386 Рак
# 27915429: 387 Тургумбаев
# 27909430: 403 Шпаковский
# 28974245: 415 AQ Әмірбек
# 28131462: 416 Сералиев
# 28132922: 419 Абдиров
# 28014920: 428 AQ Нургалиев
# 28973928: 431 Шадрин
# 27914966: 435 Джиоев
# 28573142: 435 резерв
# 28666651: 443 AQ Кадырбек
# 28222684: 443 СО Садовский
# 28666387: 449 Темишев
# 28666526: 451 Бугаев
# 28014074: 452 BJ Сериков
# 27909458: 452 CR Аскеров
# 28131410: 452 Құрман
# 28246259: 453 Мусин
# 28606589: 458 Кабимулдин
# 28243616: 459 Жаирбаев
# 28973874: 460 CO Сундетбаев
# 27915589: 460 Егоров
# 28606693: 461 Барон
# 28974276: 463 CO Шубин
# 28399015: 464 Кабдрахманов
# 28011473: 465 Кайратов
# 27780244: 467 Раков
# 28405611: 468 Кулбулдин
# 28011028: 469 Максимов
# 27792707: 470 Вахнина
# 28243564: 471 Калиев
# 28666496: 472 CO Қойгелді
# 28222776: 473 Ескатов
# 28113524: 475 CO Адомайтис
# 28973541: 476 Бойко
# 28569265: 477 Клиновицкий
# 28573545: 478 Афанасьев
# 28973983: 479 CO Синяков
# 27780000: 480 CO  Шатохин
# 27780113: 481 CO Сейдыков
# 28574085: 482 Шаткенов
# 28113464: 483 Назарбек М
# 28014385: 484 Яцынович
# 28172278: 485 CO Солдатенков
# 28974125: 486 CO Усенов
# 28606770: 495 Мукушев
# 27916518: 522 Ниязов
# 27916552: 526 CQ Лобанова
# 27919664: 529 Григоренко
# 27919718: 536 Гаврилюк
# 28574445: 586 Нургалиев
# 27916381: 639 CQ Герасимов
# 27919696: 643 CQ Жакиенов
# 27916031: 652 Глазырин
# 27919840: 654 CQ Ключка
# 27919763: 655 Нурманов
# 27940698: 659  Мальцев
# 28014203: 667 СН Куташов
# 28974156: 668 CH Бородич
# 28172244: 673 Яковлев
# 27910072: 682 Кожебаев
# 27915367: 718 резерв
# 27909082: 726 Таукин
# 27915989: 739 Коржов
# 27916171: 759 CQ Анишкевич
# 27910284: 769 Охатов
# 27916258: 780 Турежанов
# 27916107: 783 Раимкулов
# 27916084: 787  Данчев
# 27916334: 845 Сафронов
# 28015162: 847 Есентаев
# 28014649: 848 Жанатаев
# 28973854: 853 BJ Зацепин
# 28172293: 854 BJ Кабдиев
# 28974038: 855 BJ Ибраев
# 28606816: 856 Перешивкин
# 27909654: 902 Каненов
# 27911157: 908 Хасанов
# 27914983: 915 CQ Соловьев
# 27910755: 932 Баймурзинов
# 27915093: 936 Муртазин
# 27909218: 947 Жуманазаров
# 27909147: 952 CQ Гугневич
# 27915282: 956 CQ Терещенко
# 27911240: 957 Толеубек
# 27915226: 970 CQ Шульц
# 27915747: 974 Лубянецкий
# 27909272: 986 Авижич
# 27915149: 997 Кализатов
# 27909773: Дауленов 357
# 27909883: Джексембаев 353

# %%
unit_id_to_name = {unit["id"]: unit["nm"] for unit in units}

# %%
# full_names          — список ФИО
# unit_id_to_name     — словарь {unit_id: unit_name}

name_to_unit = {}

for full in full_names:
    surname = full.split()[0]                         # берём фамилию
    # ищем любой unit_name, в котором встречается фамилия
    match = next((u for u in unit_id_to_name.values() if surname in u), None)
    name_to_unit[full] = match        # будет строка unit_name или None

# name_to_unit теперь выглядит так:
# {
#     "Иванов Иван Иванович": "Unit 123 — Иванов И.И.",
#     "Петров Пётр":          None,
#     ...
# }

# Если нужен только успешно сопоставленный под‑словарь:
matched = {k: v for k, v in name_to_unit.items() if v}
unmatched = [k for k, v in name_to_unit.items() if v is None]

# %%
import pandas as pd
df = pd.read_excel("Контакты Stratera.xlsx", sheet_name="Менеджеры по продажам районы")

df = df[['ФИО', 'Область', 'Район ']]

df.columns = ['FullName', 'Region', 'District']


import re
import pandas as pd

# регулярка: делим по ", "‑если‑она‑НЕ‑внутри‑скобок
split_pat = r',\s*(?![^()]*\))'          # negative‑lookahead: после запятой
                                         # нет закрывающей скобки до следующей открытой

df = (
    df.assign(District=df['District'].str.split(split_pat, regex=True))  # список
      .explode('District')                                               # строки
      .assign(District=lambda d: d['District'].str.strip())              # подчистить пробелы
      .reset_index(drop=True)
)

# %%
df = df[:-1]

# %%
matched
# Out:
# {'Барон Сергей Дмитриевич': '461 Барон',
#  'Бугаев Никита Сергеевич': '451 Бугаев',
#  'Кадырбек Куат': '443 AQ Кадырбек',
#  'Кайратов Батырхан Бейсенбайұлы': '465 Кайратов',
#  'Құрман Айдын Мұхитұлы': '452 Құрман',
#  'Куташов Виталий Николаевич': '667 СН Куташов',
#  'Назарбек Мәди Мейрамбекұлы': '483 Назарбек М',
#  'Сундетбаев Болат Муратбекович': '460 CO Сундетбаев',
#  'Темишев Нуржан Мейрамғалиұлы': '449 Темишев',
#  'Шаткенов Арлан Нурдаулетович': '482 Шаткенов',
#  'Яковлев Александр Александрович': '673 Яковлев',
#  'Адомайтис Евгений Валерьевич': '475 CO Адомайтис',
#  'Герасимов Виталий Валерьевич': '639 CQ Герасимов',
#  'Гугневич Евгений Павлович': '952 CQ Гугневич',
#  'Зацепин Алексей Иванович': '853 BJ Зацепин',
#  'Садовский Игорь Валерьевич': '443 СО Садовский',
#  'Турежанов Болат Агибаевич': '780 Турежанов',
#  'Усенов Асанали Асхатович': '486 CO Усенов',
#  'Шубин Глеб Владимирович': '463 CO Шубин',
#  'Шульц Николай Викторович': '970 CQ Шульц',
#  'Абдрахманов Алибек Канатович': '377 CR Абдрахманов',
#  'Есентаев Дамир Мейрамович': '847 Есентаев',
#  'Нургалиев Еламан Кайратович': '428 AQ Нургалиев',
#  'Раков Валерий Игоревич': '467 Раков',
#  'Сафронов Александр Викторович': '845 Сафронов',
#  'Шадрин Виталий Вячеславович': '431 Шадрин'}

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

# %%
df["Region_mapped"] = df["District"].apply(
    lambda name: reverse_mapping.get(name, None)   # вернёт value или None
)

# %%
df.to_csv('manager_region.csv', index=False)

# %%
df = pd.read_csv('manager_region.csv')

region_dict = (
    df.groupby('Car_numb')['Region_mapped']
    .apply(lambda x: list(set(x)))
    .to_dict()
)

# %%
pd.set_option('display.max_rows', None)
df.sort_values(by = 'Car_numb')
# Out:
#                              FullName                         Region  \
# 37         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 36         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 40         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 39         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 38         Балгожа Рауан Еркебуланулы                КСТ (Костанай)
# 13          Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 12          Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 10          Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 9           Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 11          Кабимулдин Руфат Асетович         ВКО (Усть-Каменогорск)
# 48       Абдрахманов Алибек Канатович            СКО (Петропавловск)
# 122      Садвакасов Рустам Дмитриевич                 ПВЛ (Павлодар)
# 2            Карташов Олег Валерьевич                 СКО (Кокшетау)
# 1            Карташов Олег Валерьевич                 СКО (Кокшетау)
# 104               Рак Егор Валерьевич                 ПВЛ (Павлодар)
# 46         Тургумбаев Ильяс Аскарович                  АКМ (Атбасар)
# 47         Тургумбаев Ильяс Аскарович                  АКМ (Атбасар)
# 33       Әмірбек Жанибек Адильбекович                КСТ (Костанай)
# 34       Әмірбек Жанибек Адильбекович                КСТ (Костанай)
# 35       Әмірбек Жанибек Адильбекович                КСТ (Костанай)
# 78          Сералиев Алишер Габитович                КСТ (Костанай)
# 77          Сералиев Алишер Габитович                КСТ (Костанай)
# 83        Абдиров Бекбулат Кайратович                КСТ (Костанай)
# 84        Абдиров Бекбулат Кайратович                КСТ (Костанай)
# 89        Абдиров Бекбулат Кайратович                КСТ (Костанай)
# 88        Абдиров Бекбулат Кайратович                КСТ (Костанай)
# 87        Абдиров Бекбулат Кайратович                КСТ (Костанай)
# 86        Абдиров Бекбулат Кайратович                КСТ (Костанай)
# 85        Абдиров Бекбулат Кайратович                КСТ (Костанай)
# 99       Нургалиев Данияр Рамазанович                КСТ (Костанай)
# 98       Нургалиев Данияр Рамазанович                КСТ (Костанай)
# 9                                Алтай ауданы
# 11                         Үлкен Нарын ауданы
# 48                              Жамбыл ауданы
# 122                           Шарбақты ауданы
# 2                                 Есіл ауданы
# 1                              Айыртау ауданы
# 104                           Тереңкөл ауданы
# 46            Жаксынский район - Жақсы ауданы
# 47                                Есіл ауданы
# 33                             Денисов ауданы
# 34                            Жітіқара ауданы
# 35                             Қамысты ауданы
# 78    Мендыкаринский район - Меңдіқара ауданы
# 77                            Қостанай ауданы
# 83    Мендыкаринский район - Меңдіқара ауданы
# 84        Сарыкольский район - Сарыкөл ауданы
# 89                               Арқалық Қ.Ә.
# 88                              Қарасу ауданы
# 87   Алтынсаринский район - Алтынсарин ауданы
# 86                            Қостанай ауданы
# 85                             Ұзынкөл ауданы
# 99                             Ұзынкөл ауданы
# 98        Сарыкольский район - Сарыкөл ауданы
# 79                            Қызылжар ауданы
# 80                             Аққайың ауданы
# 106                          Тимирязев ауданы
# 107                           Шал ақын ауданы
# 95                           Сандықтау ауданы
# 16                            Астрахан ауданы
# 120                           Шал ақын ауданы
# 42                           Егіндікөл ауданы
# 14                              Аршалы ауданы
# 7                              Ақтоғай ауданы
# 8                                Ертіс ауданы
# 15                              Аршалы ауданы
# 23                          Бесқарағай ауданы
# 25                           Шемонаиха ауданы
# 24                          Бородулиха ауданы
# 21                          Бесқарағай ауданы
# 22                          Бородулиха ауданы
# 41                           Егіндікөл ауданы
# 93                            Осакаров ауданы
# 32                     Ғабит Мүсірепов ауданы
# 26                          Біржан сал ауданы
# 27                             Бұланды ауданы
# 28                            Астрахан ауданы
# 105                          Тимирязев ауданы
# 108                          Уәлиханов ауданы
# 18                             Атбасар ауданы
# 103                            Тайынша ауданы
# 53                             Зеренді ауданы
# 54                             Қамысты ауданы
# 55                            Жітіқара ауданы
# 56                             Денисов ауданы
# 57                     Бейімбет Майлин ауданы
# 20   Алтынсаринский район - Алтынсарин ауданы
# 19                     Бейімбет Майлин ауданы
# 17                             Атбасар ауданы
# 124                              Успен ауданы
# 123                           Шарбақты ауданы
# 128                           Глубокое ауданы
# 127                          Шемонаиха ауданы
# 91                            Осакаров ауданы
# 50                            Жарқайың ауданы
# 0                                 Абай ауданы
# 90                                Нұра ауданы
# 75                           Қорғалжын ауданы
# 119                         Целиноград ауданы
# 92                            Осакаров ауданы
# 29                         Бұқар жырау ауданы
# 109                          Уәлиханов ауданы
# 5                              Аққайың ауданы
# 81                     Мағжан Жұмабаев ауданы
# 44                                Есіл ауданы
# 76                            Қостанай ауданы
# 69                              Қарасу ауданы
# 52                             Железин ауданы
# 130                         Ерейментау ауданы
# 129                           Шортанды ауданы
# 30                     Ғабит Мүсірепов ауданы
# 6                                Ақкөл ауданы
# 115                            Федоров ауданы
# 117     Аулиекольский район - Әулиекөл ауданы
# 118                            Ұзынкөл ауданы
# 116                    Бейімбет Майлин ауданы
# 62                           Қарабалық ауданы
# 63    Мендыкаринский район - Меңдіқара ауданы
# 74   Алтынсаринский район - Алтынсарин ауданы
# 73        Сарыкольский район - Сарыкөл ауданы
# 72                              Қарасу ауданы
# 31                     Ғабит Мүсірепов ауданы
# 4                            Уәлиханов ауданы
# 3                                Ақжар ауданы
# 60                             Қамысты ауданы
# 59                            Қостанай ауданы
# 58                           Қарабалық ауданы
# 61    Мендыкаринский район - Меңдіқара ауданы
# 82                              Мамлют ауданы
# 121                           Шал ақын ауданы
# 71      Аулиекольский район - Әулиекөл ауданы
# 70                              Қарасу ауданы
# 49                            Жарқайың ауданы
# 94                            Павлодар ауданы
# 100       Сарыкольский район - Сарыкөл ауданы
# 101                           Жітіқара ауданы
# 102                            Ұзынкөл ауданы
# 65                             Федоров ауданы
# 64                           Қарабалық ауданы
# 66   Алтынсаринский район - Алтынсарин ауданы
# 67                              Қарасу ауданы
# 68                            Қостанай ауданы
# 113                            Федоров ауданы
# 114     Аулиекольский район - Әулиекөл ауданы
# 45            Жаксынский район - Жақсы ауданы
# 51                            Жарқайың ауданы
# 43                                Есіл ауданы
# 111       Сарыкольский район - Сарыкөл ауданы
# 110                            Ұзынкөл ауданы
# 97                             Бурабай ауданы
# 96                           Сандықтау ауданы
# 112                              Успен ауданы
# 125                          Шемонаиха ауданы
# 126                           Глубокое ауданы

# %%
df[['Car_numb', 'Region_mapped']]
# Out:
#                Car_numb                             Region_mapped
# 0       480 CO  Шатохин                               Абай ауданы
# 1          383 Карташов                            Айыртау ауданы
# 2          383 Карташов                               Есіл ауданы
# 3         780 Турежанов                              Ақжар ауданы
# 4         780 Турежанов                          Уәлиханов ауданы
# 5           495 Мукушев                            Аққайың ауданы
# 6           673 Яковлев                              Ақкөл ауданы
# 7        452 BJ Сериков                            Ақтоғай ауданы
# 8        452 BJ Сериков                              Ертіс ауданы
# 9        354 Кабимулдин                              Алтай ауданы
# 10       354 Кабимулдин                       Катонқарағай ауданы
# 11       354 Кабимулдин                        Үлкен Нарын ауданы
# 12       354 Кабимулдин                         Бородулиха ауданы
# 13       354 Кабимулдин                              Самар ауданы
# 14           451 Бугаев                             Аршалы ауданы
# 15           452 Құрман                             Аршалы ауданы
# 16      443 AQ Кадырбек                           Астрахан ауданы
# 17     475 CO Адомайтис                            Атбасар ауданы
# 18         469 Максимов                            Атбасар ауданы
# 19          473 Ескатов                    Бейімбет Майлин ауданы
# 20          473 Ескатов  Алтынсаринский район - Алтынсарин ауданы
# 21         459 Жаирбаев                         Бесқарағай ауданы
# 22         459 Жаирбаев                         Бородулиха ауданы
# 23            453 Мусин                         Бесқарағай ауданы
# 24            453 Мусин                         Бородулиха ауданы
# 25            453 Мусин                          Шемонаиха ауданы
# 26     464 Кабдрахманов                         Біржан сал ауданы
# 27         465 Кайратов                            Бұланды ауданы
# 28         465 Кайратов                           Астрахан ауданы
# 29   485 CO Солдатенков                        Бұқар жырау ауданы
# 30       668 CH Бородич                    Ғабит Мүсірепов ауданы
# 31           769 Охатов                    Ғабит Мүсірепов ауданы
# 32         463 CO Шубин                    Ғабит Мүсірепов ауданы
# 33       415 AQ Әмірбек                            Денисов ауданы
# 34       415 AQ Әмірбек                           Жітіқара ауданы
# 35       415 AQ Әмірбек                            Қамысты ауданы
# 36          352 Балгожа                            Денисов ауданы
# 37          352 Балгожа                             Қарасу ауданы
# 38          352 Балгожа   Мендыкаринский район - Меңдіқара ауданы
# 39          352 Балгожа                              Арқалық Қ.Ә.
# 40          352 Балгожа                    Бейімбет Майлин ауданы
# 41    460 CO Сундетбаев                          Егіндікөл ауданы
# 42          449 Темишев                          Егіндікөл ауданы
# 43         970 CQ Шульц                               Есіл ауданы
# 44     639 CQ Герасимов                               Есіл ауданы
# 45      952 CQ Гугневич           Жаксынский район - Жақсы ауданы
# 46       387 Тургумбаев           Жаксынский район - Жақсы ауданы
# 47       387 Тургумбаев                               Есіл ауданы
# 48   377 CR Абдрахманов                             Жамбыл ауданы
# 49       853 BJ Зацепин                           Жарқайың ауданы
# 50       479 CO Синяков                           Жарқайың ауданы
# 51     956 CQ Терещенко                           Жарқайың ауданы
# 52        654 CQ Ключка                            Железин ауданы
# 53           471 Калиев                            Зеренді ауданы
# 54      472 CO Қойгелді                            Қамысты ауданы
# 55      472 CO Қойгелді                           Жітіқара ауданы
# 56      472 CO Қойгелді                            Денисов ауданы
# 57      472 CO Қойгелді                    Бейімбет Майлин ауданы
# 58        783 Раимкулов                          Қарабалық ауданы
# 59        783 Раимкулов                           Қостанай ауданы
# 60        783 Раимкулов                            Қамысты ауданы
# 61        783 Раимкулов   Мендыкаринский район - Меңдіқара ауданы
# 62           739 Коржов                          Қарабалық ауданы
# 63           739 Коржов   Мендыкаринский район - Меңдіқара ауданы
# 64      932 Баймурзинов                          Қарабалық ауданы
# 65      932 Баймурзинов                            Федоров ауданы
# 66      932 Баймурзинов  Алтынсаринский район - Алтынсарин ауданы
# 67      932 Баймурзинов                             Қарасу ауданы
# 68      932 Баймурзинов                           Қостанай ауданы
# 69         652 Глазырин                             Қарасу ауданы
# 70         848 Жанатаев                             Қарасу ауданы
# 71         848 Жанатаев     Аулиекольский район - Әулиекөл ауданы
# 72     759 CQ Анишкевич                             Қарасу ауданы
# 73     759 CQ Анишкевич       Сарыкольский район - Сарыкөл ауданы
# 74     759 CQ Анишкевич  Алтынсаринский район - Алтынсарин ауданы
# 75         482 Шаткенов                          Қорғалжын ауданы
# 76      643 CQ Жакиенов                           Қостанай ауданы
# 77         416 Сералиев                           Қостанай ауданы
# 78         416 Сералиев   Мендыкаринский район - Меңдіқара ауданы
# 79     428 AQ Нургалиев                           Қызылжар ауданы
# 80     428 AQ Нургалиев                            Аққайың ауданы
# 81         536 Гаврилюк                    Мағжан Жұмабаев ауданы
# 82         845 Сафронов                             Мамлют ауданы
# 83          419 Абдиров   Мендыкаринский район - Меңдіқара ауданы
# 84          419 Абдиров       Сарыкольский район - Сарыкөл ауданы
# 85          419 Абдиров                            Ұзынкөл ауданы
# 86          419 Абдиров                           Қостанай ауданы
# 87          419 Абдиров  Алтынсаринский район - Алтынсарин ауданы
# 88          419 Абдиров                             Қарасу ауданы
# 89          419 Абдиров                              Арқалық Қ.Ә.
# 90      481 CO Сейдыков                               Нұра ауданы
# 91        478 Афанасьев                           Осакаров ауданы
# 92         484 Яцынович                           Осакаров ауданы
# 93            461 Барон                           Осакаров ауданы
# 94       854 BJ Кабдиев                           Павлодар ауданы
# 95           435 Джиоев                          Сандықтау ауданы
# 96        997 Кализатов                          Сандықтау ауданы
# 97        997 Кализатов                            Бурабай ауданы
# 98     428 AQ Нургалиев       Сарыкольский район - Сарыкөл ауданы
# 99     428 AQ Нургалиев                            Ұзынкөл ауданы
# 100       855 BJ Ибраев       Сарыкольский район - Сарыкөл ауданы
# 101       855 BJ Ибраев                           Жітіқара ауданы
# 102       855 BJ Ибраев                            Ұзынкөл ауданы
# 103         470 Вахнина                            Тайынша ауданы
# 104             386 Рак                           Тереңкөл ауданы
# 105           467 Раков                          Тимирязев ауданы
# 106          431 Шадрин                          Тимирязев ауданы
# 107          431 Шадрин                           Шал ақын ауданы
# 108       468 Кулбулдин                          Уәлиханов ауданы
# 109       486 CO Усенов                          Уәлиханов ауданы
# 110      974 Лубянецкий                            Ұзынкөл ауданы
# 111      974 Лубянецкий       Сарыкольский район - Сарыкөл ауданы
# 112        Дауленов 357                              Успен ауданы
# 113     947 Жуманазаров                            Федоров ауданы
# 114     947 Жуманазаров     Аулиекольский район - Әулиекөл ауданы
# 115          726 Таукин                            Федоров ауданы
# 116          726 Таукин                    Бейімбет Майлин ауданы
# 117          726 Таукин     Аулиекольский район - Әулиекөл ауданы
# 118          726 Таукин                            Ұзынкөл ауданы
# 119      483 Назарбек М                         Целиноград ауданы
# 120    443 СО Садовский                           Шал ақын ауданы
# 121        847 Есентаев                           Шал ақын ауданы
# 122      380 Садвакасов                           Шарбақты ауданы
# 123           476 Бойко                           Шарбақты ауданы
# 124           476 Бойко                              Успен ауданы
# 125     Джексембаев 353                          Шемонаиха ауданы
# 126     Джексембаев 353                           Глубокое ауданы
# 127     477 Клиновицкий                          Шемонаиха ауданы
# 128     477 Клиновицкий                           Глубокое ауданы
# 129      667 СН Куташов                           Шортанды ауданы
# 130      667 СН Куташов                         Ерейментау ауданы

# %%
df['Car_numb'] = df['FullName'].apply(lambda x: matched[x])

df["Region_mapped"] = df["District"].apply(
    lambda name: reverse_mapping.get(name, None)   # вернёт value или None
)

# %%
# Извлекаем фамилии из ФИО
known_surnames = set(name.split()[0] for name in full_names)

# Юниты, у которых не найдена фамилия в списке
not_matched_units = {}

for unit_id, unit_name in unit_id_to_name.items():
    found = False
    for surname in known_surnames:
        if surname in unit_name:
            found = True
            break
    if not found:
        not_matched_units[unit_id] = unit_name

# Результат
print(f"❌ Юниты без совпадений по фамилии: {len(not_matched_units)}")
for uid, uname in not_matched_units.items():
    print(f"{uid}: {uname}")
# Out:
# ❌ Юниты без совпадений по фамилии: 25
# 28579033: 313 камри Сагадиев
# 28109396: 314 камри Нурияхметов
# 27909304: 348 CR Сейтмухамбетов
# 27909533: 358 резерв
# 27915338: 365 Темирбулатов
# 27910721: 381 CR Винницкий Ф
# 27909430: 403 Шпаковский
# 28573142: 435 резерв
# 27909458: 452 CR Аскеров
# 27915589: 460 Егоров
# 27916518: 522 Ниязов
# 27916552: 526 CQ Лобанова
# 27919664: 529 Григоренко
# 27919763: 655 Нурманов
# 27940698: 659  Мальцев
# 27910072: 682 Кожебаев
# 27915367: 718 резерв
# 27916084: 787  Данчев
# 28606816: 856 Перешивкин
# 27909654: 902 Каненов
# 27911157: 908 Хасанов
# 27914983: 915 CQ Соловьев
# 27915093: 936 Муртазин
# 27911240: 957 Толеубек
# 27909272: 986 Авижич
