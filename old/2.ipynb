# %%
# %pip install streamlit-keplergl keplergl ipywidgets
# Out:
# Collecting streamlit-keplergl
#   Using cached streamlit_keplergl-0.3.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting keplergl
#   Using cached keplergl-0.3.7-py2.py3-none-any.whl
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: streamlit>=0.79 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit-keplergl) (1.44.0)
# Collecting traittypes>=0.2.1 (from keplergl)
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from keplergl) (5.14.3)
# Collecting geopandas>=0.14.3 (from keplergl)
#   Using cached geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting Shapely>=1.6.4.post2 (from keplergl)
#   Using cached shapely-2.0.7-cp311-cp311-win_amd64.whl.metadata (7.1 kB)
# Collecting jupyter_packaging>=0.12.3 (from keplergl)
#   Using cached jupyter_packaging-0.12.3-py3-none-any.whl.metadata (7.7 kB)
# Collecting jupyter>=1.0.0 (from keplergl)
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting jupyterlab>=4.1.6 (from keplergl)
#   Using cached jupyterlab-4.3.6-py3-none-any.whl.metadata (16 kB)
# Collecting notebook>=6.0.1 (from keplergl)
#   Using cached notebook-7.3.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyarrow>=16.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from keplergl) (19.0.1)
# Collecting geoarrow-pyarrow>=0.1.2 (from keplergl)
#   Using cached geoarrow_pyarrow-0.1.2-py3-none-any.whl.metadata (613 bytes)
# Collecting geoarrow-pandas>=0.1.1 (from keplergl)
#   Using cached geoarrow_pandas-0.1.1-py3-none-any.whl.metadata (493 bytes)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipywidgets) (8.29.0)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from geoarrow-pandas>=0.1.1->keplergl) (2.2.3)
# Collecting geoarrow-c (from geoarrow-pyarrow>=0.1.2->keplergl)
#   Using cached geoarrow_c-0.1.2-cp311-cp311-win_amd64.whl.metadata (413 bytes)
# Collecting pyarrow-hotfix (from geoarrow-pyarrow>=0.1.2->keplergl)
#   Using cached pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.22 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from geopandas>=0.14.3->keplergl) (2.2.2)
# Collecting pyogrio>=0.7.2 (from geopandas>=0.14.3->keplergl)
#   Using cached pyogrio-0.10.0-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python311\site-packages (from geopandas>=0.14.3->keplergl) (24.1)
# Collecting pyproj>=3.3.0 (from geopandas>=0.14.3->keplergl)
#   Using cached pyproj-3.7.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: decorator in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Collecting jupyter-console (from jupyter>=1.0.0->keplergl)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter>=1.0.0->keplergl)
#   Using cached nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in c:\users\user\appdata\roaming\python\python311\site-packages (from jupyter>=1.0.0->keplergl) (6.29.5)
# Collecting deprecation (from jupyter_packaging>=0.12.3->keplergl)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools>=60.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (65.5.0)
# Collecting tomlkit (from jupyter_packaging>=0.12.3->keplergl)
#   Using cached tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting wheel (from jupyter_packaging>=0.12.3->keplergl)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab>=4.1.6->keplergl)
#   Using cached async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab>=4.1.6->keplergl)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (3.1.4)
# Requirement already satisfied: jupyter-core in c:\users\user\appdata\roaming\python\python311\site-packages (from jupyterlab>=4.1.6->keplergl) (5.7.2)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab>=4.1.6->keplergl)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab>=4.1.6->keplergl)
#   Using cached jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab>=4.1.6->keplergl)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab>=4.1.6->keplergl)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting tornado>=6.2.0 (from jupyterlab>=4.1.6->keplergl)
#   Using cached tornado-6.4.2-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (8.1.7)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (5.29.4)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from streamlit>=0.79->streamlit-keplergl) (0.9.1)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit>=0.79->streamlit-keplergl) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit>=0.79->streamlit-keplergl) (1.32.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.79->streamlit-keplergl) (4.0.12)
# Collecting anyio (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl)
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (3.10)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab>=4.1.6->keplergl)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.8.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (8.6.3)
# Requirement already satisfied: nest-asyncio in c:\users\user\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.6.0)
# Requirement already satisfied: psutil in c:\users\user\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (6.1.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\user\appdata\roaming\python\python311\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (26.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=3.0.3->jupyterlab>=4.1.6->keplergl) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\user\appdata\roaming\python\python311\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (308)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (5.10.4)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached pywinpty-2.0.15-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl)
#   Using cached babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl)
#   Using cached json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Collecting beautifulsoup4 (from nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached mistune-3.1.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from pandas->geoarrow-pandas>=0.1.1->keplergl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas->geoarrow-pandas>=0.1.1->keplergl) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from pandas->geoarrow-pandas>=0.1.1->keplergl) (2024.2)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit>=0.79->streamlit-keplergl) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.27->streamlit>=0.79->streamlit-keplergl) (2.2.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\user\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.25.0->jupyterlab>=4.1.6->keplergl)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.79->streamlit-keplergl) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.79->streamlit-keplergl) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.79->streamlit-keplergl) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.79->streamlit-keplergl) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.79->streamlit-keplergl) (0.21.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached PyYAML-6.0.2-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\appdata\local\programs\python\python311\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.20.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter>=1.0.0->keplergl)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl)
#   Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Using cached streamlit_keplergl-0.3.0-py3-none-any.whl (3.9 kB)
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached geoarrow_pandas-0.1.1-py3-none-any.whl (6.2 kB)
# Using cached geoarrow_pyarrow-0.1.2-py3-none-any.whl (26 kB)
# Using cached geopandas-1.0.1-py3-none-any.whl (323 kB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached jupyter_packaging-0.12.3-py3-none-any.whl (15 kB)
# Using cached jupyterlab-4.3.6-py3-none-any.whl (11.7 MB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached notebook-7.3.3-py3-none-any.whl (13.1 MB)
# Using cached shapely-2.0.7-cp311-cp311-win_amd64.whl (1.4 MB)
# Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Using cached async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached pyogrio-0.10.0-cp311-cp311-win_amd64.whl (16.2 MB)
# Using cached pyproj-3.7.1-cp311-cp311-win_amd64.whl (6.3 MB)
# Using cached tornado-6.4.2-cp38-abi3-win_amd64.whl (438 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached geoarrow_c-0.1.2-cp311-cp311-win_amd64.whl (432 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Using cached tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached babel-2.17.0-py3-none-any.whl (10.2 MB)
# Using cached bleach-6.2.0-py3-none-any.whl (163 kB)
# Using cached json5-0.10.0-py3-none-any.whl (34 kB)
# Using cached jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached mistune-3.1.3-py3-none-any.whl (53 kB)
# Using cached nbclient-0.10.2-py3-none-any.whl (25 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Using cached prometheus_client-0.21.1-py3-none-any.whl (54 kB)
# Using cached pywinpty-2.0.15-cp311-cp311-win_amd64.whl (1.4 MB)
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Using cached PyYAML-6.0.2-cp311-cp311-win_amd64.whl (161 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Installing collected packages: webencodings, widgetsnbextension, wheel, websocket-client, webcolors, uri-template, types-python-dateutil, traittypes, tornado, tomlkit, tinycss2, soupsieve, sniffio, Shapely, send2trash, rfc3986-validator, rfc3339-validator, pyyaml, pywinpty, python-json-logger, pyproj, pyogrio, pycparser, pyarrow-hotfix, prometheus-client, pandocfilters, overrides, mistune, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, h11, geoarrow-c, fqdn, deprecation, defusedxml, bleach, babel, async-lru, terminado, jupyter_packaging, httpcore, geoarrow-pyarrow, cffi, beautifulsoup4, arrow, anyio, jupyter-server-terminals, isoduration, httpx, geopandas, geoarrow-pandas, argon2-cffi-bindings, ipywidgets, argon2-cffi, nbclient, jupyter-events, jupyter-console, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, keplergl, streamlit-keplergl
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
# Successfully installed Shapely-2.0.7 anyio-4.9.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 babel-2.17.0 beautifulsoup4-4.13.3 bleach-6.2.0 cffi-1.17.1 defusedxml-0.7.1 deprecation-2.1.0 fqdn-1.5.1 geoarrow-c-0.1.2 geoarrow-pandas-0.1.1 geoarrow-pyarrow-0.1.2 geopandas-1.0.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 ipywidgets-8.1.5 isoduration-20.11.0 json5-0.10.0 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyter_packaging-0.12.3 jupyterlab-4.3.6 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-3.0.13 keplergl-0.3.7 mistune-3.1.3 nbclient-0.10.2 nbconvert-7.16.6 notebook-7.3.3 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 prometheus-client-0.21.1 pyarrow-hotfix-0.6 pycparser-2.22 pyogrio-0.10.0 pyproj-3.7.1 python-json-logger-3.3.0 pywinpty-2.0.15 pyyaml-6.0.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.6 streamlit-keplergl-0.3.0 terminado-0.18.1 tinycss2-1.4.0 tomlkit-0.13.2 tornado-6.4.2 traittypes-0.2.1 types-python-dateutil-2.9.0.20241206 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 wheel-0.45.1 widgetsnbextension-4.0.13
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wheel.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wsdump.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script send2trash.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyproj.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyjson5.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybabel.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script httpx.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-execute.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-events.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-console.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jupyter-dejavu.exe and jupyter-nbconvert.exe are installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-server.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts jlpm.exe, jupyter-lab.exe, jupyter-labextension.exe and jupyter-labhub.exe are installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-notebook.exe is installed in 'c:\Users\User\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# python-telegram-bot 13.15 requires tornado==6.1, but you have tornado 6.4.2 which is incompatible.

# %%
import streamlit as st
import pandas as pd
import numpy as np
from keplergl import KeplerGl
from streamlit_keplergl import keplergl_static

# %%
import streamlit as st
import folium
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd
import numpy as np
import tempfile
import os
import json

def load_data():
    df = pd.read_csv("data.csv")
    df["Начало"] = pd.to_datetime(df["Начало"], errors='coerce')
    df["Конец"]  = pd.to_datetime(df["Конец"],  errors='coerce')
    return df

df = load_data()

# %%
def calculate_time_spent(df_local, threshold=1e-4):
    df_copy = df_local.copy()
    df_copy.sort_values(by=["Группировка", "Начало"], inplace=True)
    df_copy["dwelling_time"] = 0.0

    for group_name, group_data in df_copy.groupby("Группировка", group_keys=False):
        idx_list = group_data.index.to_list()
        for i in range(len(idx_list) - 1):
            idx_i  = idx_list[i]
            idx_i1 = idx_list[i + 1]
            
            lat_end_i    = group_data.loc[idx_i, "latitude_конеч"]
            lon_end_i    = group_data.loc[idx_i, "longitude_конеч"]
            lat_start_i1 = group_data.loc[idx_i1, "latitude_нач"]
            lon_start_i1 = group_data.loc[idx_i1, "longitude_нач"]
            
            dist = np.sqrt((lat_end_i - lat_start_i1)**2 + (lon_end_i - lon_start_i1)**2)
            t_end   = group_data.loc[idx_i, "Конец"]
            t_start = group_data.loc[idx_i1, "Начало"]
            if pd.notnull(t_end) and pd.notnull(t_start):
                delta_sec = (t_start - t_end).total_seconds()
                if delta_sec > 0:
                    df_copy.at[idx_i, "dwelling_time"] = delta_sec
    
    return df_copy

df_time = calculate_time_spent(df, threshold=1e-4)

# Для HeatMap агрегируем по координатам конечных точек
df_time_sum = df_time.groupby(
    ["latitude_конеч", "longitude_конеч"], dropna=False
)["dwelling_time"].sum().reset_index()

# %%
df_time[df_time['dwelling_time'] == 0]
# Out:
#                 Группировка              Начало  latitude_нач  longitude_нач  \
# 130      313 камри Сагадиев 2025-03-31 10:15:33     51.130757      71.387532
# 350   314 камри Нурияхметов 2025-03-31 09:51:49     51.143920      71.361040
# 431   348 CR Сейтмухамбетов 2025-03-31 08:42:41     51.651790      72.141350
# 492             352 Балгожа 2025-03-31 09:40:20     53.222870      63.659980
# 587            358 Мамбетов 2025-03-31 09:56:55     52.905660      70.189340
# ...                     ...                 ...           ...            ...
# 7300         974 Лубянецкий 2025-03-31 08:50:49     53.230752      63.662312
# 7368             986 Авижич 2025-03-30 11:04:37     53.182630      63.588940
# 7468          997 Кализатов 2025-03-31 08:41:38     53.294943      69.394117
# 7546           Дауленов 357 2025-03-31 09:00:35     52.275267      76.974713
# 7634        Джексембаев 353 2025-03-31 09:58:35     50.073113      82.381260
#
#                    Конец  latitude_конеч  longitude_конеч  lvl1  lvl2  lvl3  \
# 130  2025-03-31 10:21:59       51.116295        71.393545     1    12     4
# 350  2025-03-31 10:06:12       51.113200        71.399990     2    12     6
# 431  2025-03-31 10:11:15       51.284120        72.829280     3    10     3
# 492  2025-03-31 10:19:53       53.486850        64.035870     4    12     3
# 587  2025-03-31 10:14:34       52.948020        70.423737     6    12     5
# ...                  ...             ...              ...   ...   ...   ...
# 7300 2025-03-31 09:10:07       53.210756        63.598391    98    11     1
# 7368 2025-03-30 11:08:50       53.182585        63.601305    99     9     5
# 7468 2025-03-31 10:18:28       52.411450        68.625260   100    11     5
# 7546 2025-03-31 09:15:34       52.294723        76.928187   101    12     2
# 7634 2025-03-31 10:04:00       50.073113        82.381260   102    12     5
#
#       dwelling_time
# 130             0.0
# 350             0.0
# 431             0.0
# 492             0.0
# 587             0.0
# ...             ...
# 7300            0.0
# 7368            0.0
# 7468            0.0
# 7546            0.0
# 7634            0.0
#
# [95 rows x 11 columns]

# %%
# 2) Слой с HeatMap (по времени пребывания)
heat_data = []
for _, row in df_time_sum.iterrows():
    lat = row["latitude_конеч"]
    lon = row["longitude_конеч"]
    weight = row["dwelling_time"]
    if pd.notnull(lat) and pd.notnull(lon):
        heat_data.append([lat, lon, weight])

# %%
df_time[7545:7548]
# Out:
#           Группировка              Начало  latitude_нач  longitude_нач  \
# 7545     Дауленов 357 2025-03-31 08:44:15     52.261676      76.984329
# 7546     Дауленов 357 2025-03-31 09:00:35     52.275267      76.974713
# 7547  Джексембаев 353 2025-03-20 08:08:01     49.905830      82.618800
#
#                    Конец  latitude_конеч  longitude_конеч  lvl1  lvl2  lvl3  \
# 7545 2025-03-31 08:50:00       52.275267        76.974713   101    12     1
# 7546 2025-03-31 09:15:34       52.294723        76.928187   101    12     2
# 7547 2025-03-20 08:12:35       49.909700        82.610950   102     1     1
#
#       dwelling_time
# 7545          635.0
# 7546            0.0
# 7547          187.0

# %%
df_time[df_time["dwelling_time"]  <= 0]
# Out:
#                 Группировка              Начало  latitude_нач  longitude_нач  \
# 130      313 камри Сагадиев 2025-03-31 10:15:33     51.130757      71.387532
# 350   314 камри Нурияхметов 2025-03-31 09:51:49     51.143920      71.361040
# 431   348 CR Сейтмухамбетов 2025-03-31 08:42:41     51.651790      72.141350
# 492             352 Балгожа 2025-03-31 09:40:20     53.222870      63.659980
# 587            358 Мамбетов 2025-03-31 09:56:55     52.905660      70.189340
# ...                     ...                 ...           ...            ...
# 7300         974 Лубянецкий 2025-03-31 08:50:49     53.230752      63.662312
# 7368             986 Авижич 2025-03-30 11:04:37     53.182630      63.588940
# 7468          997 Кализатов 2025-03-31 08:41:38     53.294943      69.394117
# 7546           Дауленов 357 2025-03-31 09:00:35     52.275267      76.974713
# 7634        Джексембаев 353 2025-03-31 09:58:35     50.073113      82.381260
#
#                    Конец  latitude_конеч  longitude_конеч  lvl1  lvl2  lvl3  \
# 130  2025-03-31 10:21:59       51.116295        71.393545     1    12     4
# 350  2025-03-31 10:06:12       51.113200        71.399990     2    12     6
# 431  2025-03-31 10:11:15       51.284120        72.829280     3    10     3
# 492  2025-03-31 10:19:53       53.486850        64.035870     4    12     3
# 587  2025-03-31 10:14:34       52.948020        70.423737     6    12     5
# ...                  ...             ...              ...   ...   ...   ...
# 7300 2025-03-31 09:10:07       53.210756        63.598391    98    11     1
# 7368 2025-03-30 11:08:50       53.182585        63.601305    99     9     5
# 7468 2025-03-31 10:18:28       52.411450        68.625260   100    11     5
# 7546 2025-03-31 09:15:34       52.294723        76.928187   101    12     2
# 7634 2025-03-31 10:04:00       50.073113        82.381260   102    12     5
#
#       dwelling_time
# 130             0.0
# 350             0.0
# 431             0.0
# 492             0.0
# 587             0.0
# ...             ...
# 7300            0.0
# 7368            0.0
# 7468            0.0
# 7546            0.0
# 7634            0.0
#
# [95 rows x 11 columns]

# %%
# Создаем DataFrame только с событиями, где dwelling_time > 0
df_dwell_events = df_time[df_time["dwelling_time"] > 0].copy()
df_dwell_events["Прибытие"] = df_dwell_events["Конец"] + pd.to_timedelta(df_dwell_events["dwelling_time"], unit="s")
df_dwell_events["Конец_str"] = df_dwell_events["Конец"].dt.strftime("%Y-%m-%d %H:%M:%S")
df_dwell_events["Прибытие_str"] = df_dwell_events["Прибытие"].dt.strftime("%Y-%m-%d %H:%M:%S")


grouped_events = df_dwell_events.groupby(["latitude_конеч", "longitude_конеч"])
popup_texts = {}
popup_texts_1 = []  # Здесь будем сохранять информацию по каждому событию отдельно
agent_tooltips = {}

for (lat, lon), group in grouped_events:
    # Собираем уникальные имена агентов в этой точке
    agents = group["Группировка"].unique()
    agent_names = ", ".join(agents)
    
    # Формируем popup-текст для этой группы (если нужно для отображения на карте)
    lines = [f"Агент: {agent_names}"]
    
    for _, row in group.iterrows():
        # Добавляем строку с временем прибытия и отъезда для popup
        lines.append(f"Прибытие: {row['Прибытие_str']}<br>Отъезд: {row['Конец_str']}")
        # Сохраняем отдельное событие: агент, широта, долгота, время прибытия, время отъезда
        popup_texts_1.append([agent_names, lat, lon, row['Прибытие_str'], row['Конец_str']])
    
    popup_text = "<hr>".join(lines)
    popup_texts[(lat, lon)] = popup_text
    agent_tooltips[(lat, lon)] = agent_names

# %%
df_time_sum[df_time_sum['dwelling_time']!= 0]
# Out:
#       latitude_конеч  longitude_конеч  dwelling_time
# 0          48.362385        85.607955        69380.0
# 1          48.692750        83.431360          272.0
# 2          48.743520        82.692510         2733.0
# 3          48.754310        82.384610         1412.0
# 4          48.755350        82.379780          632.0
# ...              ...              ...            ...
# 4740       54.944496        69.180802       105654.0
# 4741       54.951710        69.236820          512.0
# 4742       54.952020        68.526170         1172.0
# 4743       54.952340        69.140730          516.0
# 4744       54.953190        69.243690         2732.0
#
# [4689 rows x 3 columns]

# %%
grouped_events.size()
# Out:
# latitude_конеч  longitude_конеч
# 48.362385       85.607955          1
# 48.692750       83.431360          1
# 48.743520       82.692510          1
# 48.754310       82.384610          1
# 48.755350       82.379780          1
#                                   ..
# 54.944496       69.180802          9
# 54.951710       69.236820          1
# 54.952020       68.526170          1
# 54.952340       69.140730          1
# 54.953190       69.243690          1
# Length: 4689, dtype: int64

# %%
df_time
# Out:
#              Группировка              Начало  latitude_нач  longitude_нач  \
# 0     313 камри Сагадиев 2025-03-20 09:55:13     51.111071      71.394976
# 1     313 камри Сагадиев 2025-03-20 10:03:04     51.103013      71.404198
# 2     313 камри Сагадиев 2025-03-20 10:18:41     51.130757      71.387532
# 3     313 камри Сагадиев 2025-03-20 11:23:48     51.111071      71.394976
# 4     313 камри Сагадиев 2025-03-20 11:39:22     51.128940      71.391480
# ...                  ...                 ...           ...            ...
# 7630     Джексембаев 353 2025-03-31 08:21:54     49.906150      82.619970
# 7631     Джексембаев 353 2025-03-31 09:13:33     50.026680      82.495940
# 7632     Джексембаев 353 2025-03-31 09:29:28     50.076130      82.383270
# 7633     Джексембаев 353 2025-03-31 09:51:18     50.077467      82.386153
# 7634     Джексембаев 353 2025-03-31 09:58:35     50.073113      82.381260
#
#                    Конец  latitude_конеч  longitude_конеч  lvl1  lvl2  lvl3  \
# 0    2025-03-20 09:59:10       51.103013        71.404198     1     1     1
# 1    2025-03-20 10:15:56       51.130757        71.387532     1     1     2
# 2    2025-03-20 10:28:15       51.111071        71.394976     1     1     3
# 3    2025-03-20 11:33:39       51.128940        71.391480     1     1     4
# 4    2025-03-20 11:40:59       51.130305        71.388520     1     1     5
# ...                  ...             ...              ...   ...   ...   ...
# 7630 2025-03-31 09:11:01       50.026680        82.495940   102    12     1
# 7631 2025-03-31 09:26:56       50.076130        82.383270   102    12     2
# 7632 2025-03-31 09:31:40       50.077467        82.386153   102    12     3
# 7633 2025-03-31 09:55:02       50.073113        82.381260   102    12     4
# 7634 2025-03-31 10:04:00       50.073113        82.381260   102    12     5
#
#       dwelling_time
# 0             234.0
# 1             165.0
# 2            3333.0
# 3             343.0
# 4            3984.0
# ...             ...
# 7630          152.0
# 7631          152.0
# 7632         1178.0
# 7633          213.0
# 7634            0.0
#
# [7635 rows x 11 columns]

# %%
pd.DataFrame(popup_texts_1)
# Out:
#                     0          1          2                    3  \
# 0        459 Жаирбаев  48.362385  85.607955  2025-03-30 07:14:24
# 1        459 Жаирбаев  48.692750  83.431360  2025-03-30 09:42:47
# 2     Джексембаев 353  48.743520  82.692510  2025-03-27 09:48:02
# 3     Джексембаев 353  48.754310  82.384610  2025-03-27 10:50:12
# 4     Джексембаев 353  48.755350  82.379780  2025-03-27 10:23:55
# ...               ...        ...        ...                  ...
# 7535       460 Егоров  54.944496  69.180802  2025-03-30 14:42:11
# 7536     536 Гаврилюк  54.951710  69.236820  2025-03-28 17:11:39
# 7537   452 CR Аскеров  54.952020  68.526170  2025-03-31 10:19:03
# 7538       431 Шадрин  54.952340  69.140730  2025-03-28 19:52:17
# 7539    586 Нургалиев  54.953190  69.243690  2025-03-27 15:13:19
#
#                         4
# 0     2025-03-29 11:58:04
# 1     2025-03-30 09:38:15
# 2     2025-03-27 09:02:29
# 3     2025-03-27 10:26:40
# 4     2025-03-27 10:13:23
# ...                   ...
# 7535  2025-03-30 12:25:39
# 7536  2025-03-28 17:03:07
# 7537  2025-03-31 09:59:31
# 7538  2025-03-28 19:43:41
# 7539  2025-03-27 14:27:47
#
# [7540 rows x 5 columns]

# %%
df_2 = pd.DataFrame(heat_data)

# %%
import requests
import json
import pandas as pd
import datetime

TOKEN = "c611c2bab48335e36a4b59be460c57d2DC99601D0C49777B24DFE07B7614A2826A62C393"
BASE_URL = "https://hst-api.wialon.host/wialon/ajax.html"

def login(token):
    params = {"svc": "token/login", "params": json.dumps({"token": token})}
    resp = requests.get(BASE_URL, params=params).json()
    return resp.get("eid")

SID = login(TOKEN)

def get_items(sid, item_type, flags):
    params = {
        "svc": "core/search_items",
        "params": json.dumps({
            "spec": {
                "itemsType": item_type,
                "propName": "sys_name",
                "propValueMask": "*",
                "sortType": "sys_name",
                "propType": "property"
            },
            "force": 1,
            "flags": flags,
            "from": 0,
            "to": 0
        }),
        "sid": sid
    }
    return requests.get(BASE_URL, params=params).json().get("items", [])

units = get_items(SID, "avl_unit", 1)
resources = get_items(SID, "avl_resource", 8193)

if not units or not resources:
    print("Нет данных для отображения.")
    exit()

# Для простоты выбираем первый ресурс и первый шаблон отчёта, а также первый юнит
res = resources[0]
tpl_id = list(res["rep"].values())[0]["id"]
unit = units[0]
unit_id = unit["id"]

# Задаем период отчёта: последний день (от вчера до сегодня)
today = datetime.date.today()
date_from = today - datetime.timedelta(days=1)
date_to = today

from_ts = int(datetime.datetime.combine(date_from, datetime.time.min).timestamp())
to_ts = int(datetime.datetime.combine(date_to, datetime.time.max).timestamp())

def execute_report(sid, res_id, tpl_id, unit_id, from_ts, to_ts):
    params = {
        "svc": "report/exec_report",
        "params": json.dumps({
            "reportResourceId": res_id,
            "reportTemplateId": tpl_id,
            "reportObjectId": unit_id,
            "reportObjectSecId": 0,
            "interval": {"from": from_ts, "to": to_ts, "flags": 0}
        }),
        "sid": sid
    }
    return requests.get(BASE_URL, params=params).json()

print("Выполняется отчёт...")
report_result = execute_report(SID, res["id"], tpl_id, unit_id, from_ts, to_ts)

if "reportResult" in report_result:
    for table_index, table in enumerate(report_result["reportResult"]["tables"]):
        print(f"\nТаблица: {table['label']}")
        row_count = table["rows"]
        row_resp = requests.get(
            BASE_URL,
            params={
                "svc": "report/get_result_rows",
                "params": json.dumps({
                    "tableIndex": table_index,
                    "indexFrom": 0,
                    "indexTo": row_count
                }),
                "sid": SID
            }
        ).json()
        
        # Обработка структуры ответа (либо список, либо словарь с ключом "rows")
        if isinstance(row_resp, list):
            rows = row_resp
        elif isinstance(row_resp, dict) and "rows" in row_resp:
            rows = row_resp["rows"]
        else:
            print("❌ Ошибка при получении строк отчёта")
            print(row_resp)
            continue

        headers = table["header"]
        parsed_rows = []
        for row in rows:
            parsed_row = []
            for cell in row["c"]:
                if isinstance(cell, dict) and "t" in cell:
                    parsed_row.append(cell["t"])
                else:
                    parsed_row.append(cell)
            parsed_rows.append(parsed_row)

        df = pd.DataFrame(parsed_rows, columns=headers)
        display(df)
else:
    print("❌ Ошибка при выполнении отчёта")
    display(report_result)
# Out:
# Выполняется отчёт...
#
# Таблица: Отчет по дням
#    №    Grouping Пробег в поездках Ср. скорость Макс. скорость  \
# 0  1  2025-03-31           0.00 km       0 km/h         0 km/h
# 1  2  2025-04-01          87.55 km       4 km/h        99 km/h
# 2  3  2025-04-02          51.45 km       4 km/h       150 km/h
#
#   Время в движении Моточасы   Стоянки Потрачено по нормам Ср. расход по нормам
# 0          0:00:00  0:00:00   4:59:00              0.00 l        0.00 l/100 km
# 1          3:00:08  7:58:40  20:58:54              0.00 l        0.00 l/100 km
# 2          2:11:05  3:40:32  10:01:19              0.00 l        0.00 l/100 km
# Таблица: Качество вождения
#    №             Grouping      Время нарушения  \
# 0  1      Поворот: резкий  2025-04-01 02:28:15
# 1  2  Торможение: опасное  2025-04-01 02:28:15
#
#                            Положение Значение Ср. скорость Макс. скорость  \
# 0  Астана, Розы Баглановой ул., 12/2               27 km/h        29 km/h
# 1  Астана, Розы Баглановой ул., 12/2               27 km/h        16 km/h
#
#   Оценка Кол-во Водитель
# 0    9.3      3
# 1    9.1      1
# Таблица: Качество вождения (new)
#    №             Grouping      Время нарушения                Положение  \
# 0  1      Поворот: резкий  2025-04-01 08:27:05    Астана, Тұран Даңғылы
# 1  2  Торможение: опасное  2025-04-02 10:04:20  Астана, Тауелсыздык пр.
#
#   Значение Ср. скорость Макс. скорость Оценка Кол-во Водитель
# 0               27 km/h        29 km/h    9.7      3
# 1               27 km/h        16 km/h    9.6      1
# Таблица: Поездки
#    №    Grouping    Начало     Конец                     Нач. положение  \
# 0  1  2025-04-01  02:28:15  12:53:28  Астана, Розы Баглановой ул., 12/2
# 1  2  2025-04-02  02:28:17  11:59:28  Астана, Розы Баглановой ул., 12/2
#
#                     Конеч. положение Длительность    Пробег  \
# 0  Астана, Розы Баглановой ул., 12/2      3:00:08  87.55 km
# 1                Астана, Толе Би, 46      2:11:05  51.45 km
#
#   Потрачено по нормам Ср. расход по нормам Количество поездок Ср. скорость  \
# 0              0.00 l        0.00 l/100 km                 16      29 km/h
# 1              0.00 l        0.00 l/100 km                 13      24 km/h
#
#   Макс. скорость
# 0        99 km/h
# 1       150 km/h
# Таблица: Моточасы
#    №    Grouping    Начало                     Нач. положение     Конец  \
# 0  1  2025-04-01  02:04:15  Астана, Розы Баглановой ул., 12/2  13:22:17
# 1  2  2025-04-02  02:21:17  Астана, Розы Баглановой ул., 12/2  11:59:58
#
#                     Конеч. положение В движении Холостой ход Моточасы
# 0  Астана, Розы Баглановой ул., 12/2    3:07:19      4:51:21  7:58:40
# 1                Астана, Толе Би, 46    2:13:02      1:22:30  3:40:32
# Таблица: Остановки менее 5 минут
#    №    Grouping    Начало     Конец Длительность                 Положение  \
# 0  1  2025-04-01  02:41:23  12:52:32      0:10:43    Астана, Орынбор Көшесі
# 1  2  2025-04-02  02:30:20  11:38:20      0:06:55  Астана, Туран пр., 55/10
#
#   Кол-во
# 0     17
# 1     13
# Таблица: Стоянки менее 30 минут
#    №    Grouping    Начало     Конец Длительность  \
# 0  1  2025-04-01  02:31:19  12:49:55      1:33:58
# 1  2  2025-04-02  02:32:12  12:12:41      1:06:11
#
#                               Положение Кол-во
# 0  Астана, Қабанбай Батыр Даңғылы, 43кВ      7
# 1                Астана, Орынбор Көшесі      5
# Таблица: Стоянки свыше 30 минут
#    №    Grouping    Начало                Конец Длительность  \
# 0  1  2025-03-31  19:00:15  2025-04-01 02:28:15      7:28:00
# 1  2  2025-04-01  02:55:49  2025-04-02 02:28:17     19:13:58
# 2  3  2025-04-02  02:55:30             11:26:03      6:17:50
#
#                            Положение Кол-во
# 0  Астана, Розы Баглановой ул., 12/2      1
# 1  Астана, Розы Баглановой ул., 12/1      4
# 2  Астана, Розы Баглановой ул., 12/1      4
